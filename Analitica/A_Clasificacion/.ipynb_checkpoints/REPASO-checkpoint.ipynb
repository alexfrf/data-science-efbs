# %% [markdown]
# ## Repaso Clasificación

# %% [markdown]
# ### Clasificación ABC

# %%
import pandas as pd
import numpy as np

pd.options.display.max_rows = 999
pd.options.display.max_columns = 999

# Leemos el dataframe, no tiene excesivos datos, pero para este ejemplo, es suficiente.
df = pd.read_csv('Datos/Ecommerce.csv',decimal = '.')

df.drop(columns=['Unnamed: 8'], inplace=True)

df.head(4)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
#
#   InvoiceDate  UnitPrice  CustomerID         Country
# 0   29-Nov-16       2.55     17850.0  United Kingdom
# 1   29-Nov-16       3.39     17850.0  United Kingdom
# 2   29-Nov-16       2.75     17850.0  United Kingdom
# 3   29-Nov-16       3.39     17850.0  United Kingdom

# %%
# Agrupamos las ventas por descriptivo de producto (también podría ser por código)
agrupado_prod = df.groupby(by='CustomerID')['Quantity'].sum().reset_index()

# Eliminamos las devoluciones (mezclar ventas con devolución no es una buena idea cuando queremos calcular porcentajes)
agrupado_prod = agrupado_prod.loc[agrupado_prod['Quantity'] > 0]

# Calculamos el porcentaje de venta que supone cada producto
agrupado_prod['PCT'] = (agrupado_prod['Quantity'] / agrupado_prod['Quantity'].sum()) * 100

# Ordenamos de forma descendente por la cantidad de venta
agrupado_prod = agrupado_prod.sort_values(by='Quantity', ascending=False)

# Apuntamos el porcentaje de venta acumulado cuando vmaos avanzando por los productos.
agrupado_prod['PCT_ACUMULADO'] = agrupado_prod['PCT'].cumsum()

agrupado_prod.head(10)
# Out:
#       CustomerID  Quantity       PCT  PCT_ACUMULADO
# 1703     14646.0    196719  4.007558       4.007558
# 55       12415.0     77242  1.573573       5.581131
# 1895     14911.0     77180  1.572310       7.153442
# 3758     17450.0     69029  1.406258       8.559700
# 4233     18102.0     64122  1.306293       9.865993
# 3801     17511.0     63012  1.283680      11.149673
# 1005     13694.0     61803  1.259050      12.408723
# 1447     14298.0     58021  1.182003      13.590727
# 1345     14156.0     57025  1.161713      14.752440
# 3202     16684.0     49390  1.006173      15.758612

# %%
(agrupado_prod[agrupado_prod['PCT_ACUMULADO'] < 80].shape[0] / agrupado_prod.shape[0]) * 100
# Out:
# 26.39499884232461

# %%
# Agrupamos las ventas por cliente
agrupado_cl = df.groupby(by='CustomerID')['Quantity'].sum().reset_index()

# Eliminamos las devoluciones (mezclar ventas con devolución no es una buena idea cuando queremos calcular porcentajes)
agrupado_cl = agrupado_cl.loc[agrupado_cl['Quantity'] > 0]

# Calculamos el porcentaje de venta que supone cada producto
agrupado_cl['PCT'] = (agrupado_cl['Quantity'] / agrupado_cl['Quantity'].sum()) * 100

# Ordenamos de forma descendente por la cantidad de venta
agrupado_cl = agrupado_cl.sort_values(by='Quantity', ascending=False)

# Apuntamos el porcentaje de venta acumulado cuando vmaos avanzando por los productos.
agrupado_cl['PCT_ACUMULADO'] = agrupado_cl['PCT'].cumsum()

# Porcentaje de productos que clientes el 80% de la venta:
(agrupado_cl[agrupado_cl['PCT_ACUMULADO'] < 80].shape[0] / agrupado_cl.shape[0]) * 100
# Out:
# 26.39499884232461

# %%
def check_pareto(df, nivel_agregacion, campo_agregacion):
    ag = df.groupby(by=nivel_agregacion)[campo_agregacion].sum().reset_index()
    ag = ag.loc[ag[campo_agregacion] > 0]
    ag['PCT'] = (ag[campo_agregacion] / ag[campo_agregacion].sum()) * 100
    ag = ag.sort_values(by=campo_agregacion, ascending=False)
    ag['PCT_ACUMULADO'] = ag['PCT'].cumsum()
    pct = (ag[ag['PCT_ACUMULADO'] < 80].shape[0] / ag.shape[0]) * 100
    print(f'PCT de {nivel_agregacion} necesario para cubrir el 80% de la {campo_agregacion}: {pct} %')

# %%
df['Total'] = df['Quantity'] * df['UnitPrice']

check_pareto(df,'Description', 'Quantity')
check_pareto(df,'Description', 'UnitPrice')
check_pareto(df,'Description', 'Total')
check_pareto(df,'CustomerID', 'Quantity')
check_pareto(df,'CustomerID', 'UnitPrice')
check_pareto(df,'CustomerID', 'Total')
# Out:
# PCT de Description necesario para cubrir el 80% de la Quantity: 22.898693615972395 %
# PCT de Description necesario para cubrir el 80% de la UnitPrice: 17.0007423904974 %
# PCT de Description necesario para cubrir el 80% de la Total: 21.136590229312063 %
# PCT de CustomerID necesario para cubrir el 80% de la Quantity: 26.39499884232461 %
# PCT de CustomerID necesario para cubrir el 80% de la UnitPrice: 30.3363074811256 %
# PCT de CustomerID necesario para cubrir el 80% de la Total: 27.23276260990282 %

# %%
def categoriza_ABC(df,nivel_agregacion,campo_agregacion):
    ag = df.groupby(by=nivel_agregacion)[campo_agregacion].sum().reset_index()
    ag = ag[ag[nivel_agregacion].isna()==False]
    ag = ag.loc[ag[campo_agregacion] > 0]
    ag['PCT'] = (ag[campo_agregacion] / ag[campo_agregacion].sum()) * 100
    ag = ag.sort_values(by=campo_agregacion, ascending=False)
    ag['PCT_ACUMULADO'] = ag['PCT'].cumsum()
    
    ag['Clase_ABC'] = 'C'
    
    ag['Clase_ABC'] = np.where(ag['PCT_ACUMULADO'] < 96,'B', ag.Clase_ABC)
    ag['Clase_ABC'] = np.where(ag['PCT_ACUMULADO'] < 80,'A', ag.Clase_ABC)
    
    return ag

df = categoriza_ABC(df, 'StockCode', 'Quantity')

# %%
df.groupby(by='Clase_ABC')['Quantity'].agg(['sum', 'min', 'max'])
# Out:
#                sum   min    max
# Clase_ABC
# A          4204664  1575  56450
# B           841669   408   1575
# C           210651     1    407

# %%
df[df['PCT_ACUMULADO']<80].shape[0]/df.shape[0]
# Out:
# 0.23321836030777396

# %% [markdown]
# ### Regresión Logística

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.options.display.max_columns=999
plt.rcParams['figure.figsize'] = (16,6)

# %%
x = np.arange(-10, 10, .01)
y = 1 / (1 + np.exp(-x))

# %%
sns.scatterplot(x=x, y=y)
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (16,6)
pd.options.display.max_columns=999

# Leemos el CSV (está separado con ;)
df = pd.read_csv('./Datos/student-mat.csv', sep=';')

# Tenemos que cambiar todos los valores tipo texto por valores numéricos
df.replace({'F':0, 'M': 1, 'yes':1, 'no':0 , 'mother':0, 'father':1, 'other':2, 'T': 1, 'A': 0}, inplace=True)

# Otras columnas que son más complejas de cambiar por valores numéricos 
# (necesitaríamos utilizar un método de codificación tipo OneHot) las eliminamos
df.drop(columns=['school', 'address', 'famsize', 'Mjob', 'Fjob', 'reason'], inplace=True)

# El aspecto final del dataframe es el siguiente
df
# Out:
#      sex  age  Pstatus  Medu  Fedu  guardian  traveltime  studytime  failures  \
# 0      0   18        0     4     4         0           2          2         0
# 1      0   17        1     1     1         1           1          2         0
# 2      0   15        1     1     1         0           1          2         3
# 3      0   15        1     4     2         0           1          3         0
# 4      0   16        1     3     3         1           1          2         0
# 5      1   16        1     4     3         0           1          2         0
# 6      1   16        1     2     2         0           1          2         0
# 7      0   17        0     4     4         0           2          2         0
# 8      1   15        0     3     2         0           1          2         0
# 9      1   15        1     3     4         0           1          2         0
# 10     0   15        1     4     4         0           1          2         0
# ...

# %%
y = np.array(df['G3'] > 10)
df.drop(columns=['G3'], inplace=True)

# %%
print(sum(y)/len(y))
# Out:
# 0.529113924050633

# %%
from sklearn.preprocessing import StandardScaler

ss = StandardScaler()
df_transf = ss.fit_transform(df)

# %%
df_transf
# Out:
# array([[-0.94817639,  1.02304645, -2.9383918 , ...,  0.03642446,
#         -1.78246688, -1.25479105],
#        [-0.94817639,  0.23837976,  0.34032221, ..., -0.21379577,
#         -1.78246688, -1.52097927],
#        [-0.94817639, -1.33095364,  0.34032221, ...,  0.53686493,
#         -1.1791469 , -0.72241461],
#        ...,
#        [ 1.05465609,  3.37704655,  0.34032221, ..., -0.33890588,
#         -0.27416693, -0.72241461],
#        [ 1.05465609,  1.02304645,  0.34032221, ..., -0.71423623,
#          0.02749306,  0.34233827],
#        [ 1.05465609,  1.80771315,  0.34032221, ..., -0.08868565,
#         -0.87748691, -0.45622639]])

# %%
sns.histplot(df.G2)
# Out:
# <AxesSubplot:xlabel='G2', ylabel='Count'>

# %%
sns.histplot([x[-1] for x in df_transf])
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
# Traemos el modelo de regresión logística

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
lr = LogisticRegression()

# Ajustamos el modelo dándole todo el conjunto como test
lr.fit(df_transf, y)

# Y obtenemos sus resulados.
res = lr.predict(df_transf)

# Vemos que, con las dos variables de los parciales, el regresor es capaz de acertar en una gran cantidad de casos
accuracy_score(res,y)
# Out:
# 0.9392405063291139

# %%
results = pd.DataFrame(y,columns=['Real'])
results['pred'] = res
results.head()
# Out:
#     Real   pred
# 0  False  False
# 1  False  False
# 2  False  False
# 3   True   True
# 4  False  False

# %%
print('% de acierto: {:.3f}'.format(100*round(accuracy_score(res,y),3)))
print('Error tipo 1: {:.3f}%'.format(100*(results[(results['Real']==False) & (results.pred==True)].shape[0])/len(y)))
print('Error tipo 2: {:.3f}%'.format(100*(results[(results['Real']==True) & (results.pred==False)].shape[0])/len(y)))
# Out:
# % de acierto: 93.900
# Error tipo 1: 3.038%
# Error tipo 2: 3.038%

# %%
lr.coef_
# Out:
# array([[-0.03832873, -0.58001235, -0.27907525, -0.21853824,  0.18080008,
#         -0.18376292, -0.26738077, -0.07923138, -0.31957045,  0.11033835,
#          0.25685834, -0.08430076, -0.15982666, -0.57448708,  0.13870894,
#          0.10793155,  0.39898334, -0.05205425,  0.00894918, -0.04166271,
#          0.38612734, -0.59920428,  0.04198056, -0.02270617,  2.00825159,
#          4.00977673]])

# %%
(df_transf[0]*lr.coef_).sum()
# Out:
# -8.54678062846317

# %%
x = np.array([(df_transf[i]*lr.coef_).sum() + lr.intercept_[0] for i in range(len(df_transf))])
y_pred = 1 / (1 + np.exp(-x))

# %%
sns.scatterplot(x=x,y=y_pred)
# Out:
# <AxesSubplot:>

# %%
lr.predict_proba([df_transf[0]])
# Out:
# array([[9.99689654e-01, 3.10345639e-04]])

# %%
sns.scatterplot(data= 1 / (1 + np.exp(-np.sum(df_transf * lr.coef_, axis=1))))
# Out:
# <AxesSubplot:>

# %%
lr.predict_proba(df_transf)
# Out:
# array([[9.99689654e-01, 3.10345639e-04],
#        [9.99455720e-01, 5.44280444e-04],
#        [9.95509238e-01, 4.49076222e-03],
#        [3.46680410e-04, 9.99653320e-01],
#        [9.66946808e-01, 3.30531918e-02],
#        [6.54886623e-04, 9.99345113e-01],
#        [5.10331612e-02, 9.48966839e-01],
#        [9.99517032e-01, 4.82968191e-04],
#        [1.71666253e-06, 9.99998283e-01],
#        [3.07528743e-04, 9.99692471e-01],
#        [8.95170349e-01, 1.04829651e-01],
#        [2.40607734e-01, 7.59392266e-01],
#        [3.50099239e-03, 9.96499008e-01],
#        [6.72529102e-01, 3.27470898e-01],
#        [2.60523761e-05, 9.99973948e-01],
#        [1.66992441e-03, 9.98330076e-01],
#        [5.58806408e-03, 9.94411936e-01],
#        [8.89480003e-01, 1.10519997e-01],
#        [9.99980833e-01, 1.91672555e-05],
#        [9.66667401e-01, 3.33325989e-02],
#        [2.63278409e-03, 9.97367216e-01],
#        [1.16678645e-03, 9.98833214e-01],
#        [1.55084794e-03, 9.98449152e-01],
# ...

# %%
lr.predict_proba([df_transf[0]])
# Out:
# array([[9.99689654e-01, 3.10345639e-04]])

# %%
lr.predict_proba([df_transf[142]])
# Out:
# array([[0.36387425, 0.63612575]])

# %%
y[142]
# Out:
# True

# %%
pd.DataFrame(lr.coef_, columns=df.columns).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df_x = df.drop(columns=['G1', 'G2'])
X = ss.fit_transform(df_x)
lr.fit(X, y)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X)
accuracy_score(y_pred,y)
# Out:
# 0.7088607594936709

# %%
lr.coef_
# Out:
# array([[ 2.33205496e-01, -2.31135232e-01, -1.42151790e-01,
#          1.67837797e-02,  2.48505787e-01,  6.43797489e-02,
#         -1.94966739e-01,  1.98581893e-01, -7.84103518e-01,
#         -3.67813733e-01, -1.77717242e-01, -1.59517374e-02,
#         -1.17323835e-01, -2.00552752e-01,  1.94971423e-01,
#          1.31804899e-01,  6.60842067e-02, -1.33796949e-01,
#          1.30126481e-01, -2.63776421e-01,  1.19692621e-01,
#         -2.65399268e-01, -8.77992168e-03,  1.51114126e-04]])

# %%
pd.DataFrame(lr.coef_, columns=df.columns[:24]).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Ejercicio regresión logística
#
# Aplica la técnica de regresión logística al conjunto de datos 'students-por.csv' ubicado en el directorio Datos
#
# 1. ¿Cuál es la predicción a batir?
# 2. ¿Cuál es el porcentaje de éxito con las variables G1 y G2?
# 3. ¿Y sin ellas?

# %%
df = pd.read_csv('./Datos/student-por.csv',sep=';',decimal=',')
pd.options.display.max_columns=999
plt.rcParams['figure.figsize'] = (16,6)


# Tenemos que cambiar todos los valores tipo texto por valores numéricos
df.replace({'F':0, 'M': 1, 'yes':1, 'no':0 , 'mother':0, 'father':1, 'other':2, 'T': 1, 'A': 0}, inplace=True)

# Otras columnas que son más complejas de cambiar por valores numéricos 
# (necesitaríamos utilizar un método de codificación tipo OneHot) las eliminamos
df.drop(columns=['school', 'address', 'famsize', 'Mjob', 'Fjob', 'reason'], inplace=True)

df.info()

y = np.array(df['G3'] > 10)
X = df.drop(columns=['G3'])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 27 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   sex         649 non-null    int64
#  1   age         649 non-null    int64
#  2   Pstatus     649 non-null    int64
#  3   Medu        649 non-null    int64
#  4   Fedu        649 non-null    int64
#  5   guardian    649 non-null    int64
#  6   traveltime  649 non-null    int64
#  7   studytime   649 non-null    int64
#  8   failures    649 non-null    int64
#  9   schoolsup   649 non-null    int64
#  10  famsup      649 non-null    int64
#  11  paid        649 non-null    int64
#  12  activities  649 non-null    int64
#  13  nursery     649 non-null    int64
#  14  higher      649 non-null    int64
#  15  internet    649 non-null    int64
#  16  romantic    649 non-null    int64
#  17  famrel      649 non-null    int64
#  18  freetime    649 non-null    int64
# ...

# %%
y = np.array(df['G3'] > 10)
X = df.drop(columns=['G3'])

# %%
sum(y)/len(y)
# Out:
# 0.6964560862865947

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

lr = LogisticRegression()
ss = StandardScaler()

X_t = ss.fit_transform(X)

lr.fit(X_t,y)
y_pred = lr.predict(X_t)

# % éxito con G1 y G2
accuracy_score(y_pred,y)
# Out:
# 0.9198767334360555

# %%
pd.DataFrame(lr.coef_, columns=X.columns).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
X2 = X.drop(['G1','G2'],axis=1)
X2_t = ss.fit_transform(X2)

lr.fit(X2_t,y)
y_pred = lr.predict(X2_t)
accuracy_score(y_pred,y)
# Out:
# 0.810477657935285

# %%
pd.DataFrame(lr.coef_, columns=X2.columns).plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
coefs = pd.DataFrame(lr.coef_,columns=X2.columns).T
coefs
# Out:
#                    0
# sex        -0.209240
# age         0.022591
# Pstatus    -0.041064
# Medu        0.190403
# Fedu        0.263213
# guardian    0.375031
# traveltime -0.055438
# studytime   0.189414
# failures   -1.076179
# schoolsup  -0.214572
# famsup     -0.057956
# paid        0.004550
# activities  0.153264
# nursery    -0.094217
# higher      0.454688
# internet    0.122837
# romantic   -0.200951
# famrel      0.024813
# freetime   -0.168725
# goout       0.017611
# Dalc       -0.103249
# Walc       -0.100356
# health     -0.015812
# absences   -0.201539

# %% [markdown]
# ## K-fold cross-validation

# %%
from sklearn import metrics
from sklearn.model_selection import KFold

df = pd.read_csv('./Datos/student-por.csv',sep=';',decimal=',')
pd.options.display.max_columns=999
plt.rcParams['figure.figsize'] = (16,6)


# Tenemos que cambiar todos los valores tipo texto por valores numéricos
df.replace({'F':0, 'M': 1, 'yes':1, 'no':0 , 'mother':0, 'father':1, 'other':2, 'T': 1, 'A': 0}, inplace=True)

# Otras columnas que son más complejas de cambiar por valores numéricos 
# (necesitaríamos utilizar un método de codificación tipo OneHot) las eliminamos
df.drop(columns=['school', 'address', 'famsize', 'Mjob', 'Fjob', 'reason'], inplace=True)

y = np.array(df['G3'] > 10)
X = df.drop(columns=['G3'])

ss = StandardScaler()

X_t = ss.fit_transform(X)

kf = KFold(int(0.1*len(X_t)), shuffle=True)

puntuaciones = []
for train_index, test_index in kf.split(df_transf):
    X_t = df_transf[train_index]
    y_t = y[train_index]
    
    lr.fit(X_t, y_t)
    
    X_prueba = df_transf[test_index]
    
    y_pred = lr.predict(X_prueba)
    
    puntuacion = metrics.accuracy_score(y[test_index], y_pred)
    print(puntuacion)
    
    puntuaciones.append(puntuacion)
    
print('\nMedia Score: {:.3f}% en {} particiones'.format(100*(np.mean(puntuaciones)),int(0.1*len(df_transf))))
# Out:
# 0.8571428571428571
# 0.8571428571428571
# 1.0
# 0.42857142857142855
# 0.5714285714285714
# 0.7142857142857143
# 0.5714285714285714
# 0.7142857142857143
# 0.7142857142857143
# 0.8571428571428571
# 0.8571428571428571
# 0.8333333333333334
# 0.6666666666666666
# 0.8333333333333334
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 0.8333333333333334
# 0.8333333333333334
# 0.6666666666666666
# 1.0
# 0.5
# 0.3333333333333333
# 0.5
# 1.0
# 0.8333333333333334
# 0.8333333333333334
# 0.6666666666666666
# 1.0
# 0.8333333333333334
# 1.0
# 1.0
# 1.0
# 0.8333333333333334
# 0.6666666666666666
# 1.0
# 0.6666666666666666
# 0.5
# 0.6666666666666666
# 0.6666666666666666
# 0.6666666666666666
# 1.0
# 1.0
# 0.8333333333333334
# 0.8333333333333334
# 1.0
# 0.6666666666666666
# 0.8333333333333334
# 0.5
# 0.5
# 0.6666666666666666
# 1.0
# 0.6666666666666666
# 1.0
# 0.8333333333333334
# 0.8333333333333334
# 0.6666666666666666
# 1.0
# 0.5
# 1.0
# 1.0
# 0.6666666666666666
# 1.0
# 0.6666666666666666
# ...

# %% [markdown]
# ## Naive Bayes

# %%
df = pd.read_csv('./Datos/student-por.csv',sep=';',decimal=',')
pd.options.display.max_columns=999
plt.rcParams['figure.figsize'] = (16,6)


# Tenemos que cambiar todos los valores tipo texto por valores numéricos
df.replace({'F':0, 'M': 1, 'yes':1, 'no':0 , 'mother':0, 'father':1, 'other':2, 'T': 1, 'A': 0}, inplace=True)

# Otras columnas que son más complejas de cambiar por valores numéricos 
# (necesitaríamos utilizar un método de codificación tipo OneHot) las eliminamos
df.drop(columns=['school', 'address', 'famsize', 'Mjob', 'Fjob', 'reason'], inplace=True)

y = np.array(df['G3'] > 10)
X = df.drop(columns=['G3'])

ss = StandardScaler()

X_t = ss.fit_transform(X)

# %%
from sklearn.naive_bayes import GaussianNB

gnb = GaussianNB()

gnb.fit(X_t, y)

y_pred = gnb.predict(X_t)

print(metrics.accuracy_score(y_pred,y))
# Out:
# 0.8582434514637904

# %%
from sklearn.datasets import load_iris

iris = load_iris()

X = iris.data
y = iris.target

gnb.fit(X, y)

res = gnb.predict(X)

print(metrics.accuracy_score(res,y))
# Out:
# 0.96

# %%
gnb.theta_ #media
# Out:
# array([[5.006, 3.428, 1.462, 0.246],
#        [5.936, 2.77 , 4.26 , 1.326],
#        [6.588, 2.974, 5.552, 2.026]])

# %%
gnb.sigma_ #std
# Out:
# array([[0.121764, 0.140816, 0.029556, 0.010884],
#        [0.261104, 0.0965  , 0.2164  , 0.038324],
#        [0.396256, 0.101924, 0.298496, 0.073924]])

# %%
# Ejemplo de entrenamiento parcial de Naive Bayes

from sklearn import metrics
from sklearn.model_selection import KFold
from sklearn.datasets import load_iris

iris = load_iris()

X = iris.data
y = iris.target

kf = KFold(20, shuffle=True)

gnb = GaussianNB()

puntuaciones = []
for train_index, test_index in kf.split(X):
    gnb.partial_fit(X[train_index], y[train_index], list(set(y)))
    
    y_pred = gnb.predict(X[test_index])
    
    puntuaciones.append(metrics.accuracy_score(y[test_index], y_pred))
    
print(f'puntación media del regresor bayesiano: {int(np.mean(puntuaciones) * 10000) / 100} %')
# Out:
# puntación media del regresor bayesiano: 95.26 %

# %% [markdown]
# ## Árboles de Decisión

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

plt.rcParams['figure.figsize'] = (16,12)

iris = load_iris()
labels = iris.target_names
variables = iris.feature_names
X = iris.data
y = iris.target

# Creamos un clasificador de árbol
dtc = DecisionTreeClassifier()

dtc.fit(X,y)
y_pred = dtc.predict(X)
tree.plot_tree(dtc,feature_names = variables, class_names = labels, filled=True, rounded = True, impurity = False);

# %%
accuracy_score(y,y_pred)
# Out:
# 1.0

# %%
print(tree.export_text(dtc, feature_names=iris.feature_names ))
# Out:
# |--- petal width (cm) <= 0.80
# |   |--- class: 0
# |--- petal width (cm) >  0.80
# |   |--- petal width (cm) <= 1.75
# |   |   |--- petal length (cm) <= 4.95
# |   |   |   |--- petal width (cm) <= 1.65
# |   |   |   |   |--- class: 1
# |   |   |   |--- petal width (cm) >  1.65
# |   |   |   |   |--- class: 2
# |   |   |--- petal length (cm) >  4.95
# |   |   |   |--- petal width (cm) <= 1.55
# |   |   |   |   |--- class: 2
# |   |   |   |--- petal width (cm) >  1.55
# |   |   |   |   |--- sepal length (cm) <= 6.95
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- sepal length (cm) >  6.95
# |   |   |   |   |   |--- class: 2
# |   |--- petal width (cm) >  1.75
# |   |   |--- petal length (cm) <= 4.85
# |   |   |   |--- sepal width (cm) <= 3.10
# |   |   |   |   |--- class: 2
# |   |   |   |--- sepal width (cm) >  3.10
# |   |   |   |   |--- class: 1
# |   |   |--- petal length (cm) >  4.85
# |   |   |   |--- class: 2

# %% [markdown]
# #### Construcción de árboles sin overfitting

# %%
### Maximizar profundidad

dtc = DecisionTreeClassifier(max_depth=3)
    
dtc.fit(X, y)
tree.plot_tree(dtc, feature_names=iris.feature_names, class_names=iris.target_names, filled=True, rounded=True, impurity=True);

# %%
metrics.accuracy_score(y, dtc.predict(X))
# Out:
# 0.9733333333333334

# %%
### Maximizar nº de hojas

dtc = DecisionTreeClassifier(max_leaf_nodes=4)
    
dtc.fit(X, y)

texto = tree.plot_tree(dtc, feature_names=iris.feature_names, class_names=iris.target_names, filled=True, rounded=True, impurity=True);

print(metrics.accuracy_score(y, dtc.predict(X)))
# Out:
# 0.9733333333333334

# %%
dtc = DecisionTreeClassifier(min_samples_leaf=3)
    
dtc.fit(X, y)

texto = tree.plot_tree(dtc, feature_names=iris.feature_names, class_names=iris.target_names, filled=True, rounded=True, impurity=True)

print(metrics.accuracy_score(y, dtc.predict(X)))
# Out:
# 0.98

# %%
dtc = DecisionTreeClassifier(min_impurity_decrease=.01)
    
dtc.fit(X, y)

texto = tree.plot_tree(dtc, feature_names=iris.feature_names, class_names=iris.target_names, filled=True, rounded=True, impurity=True)

print(metrics.accuracy_score(y, dtc.predict(X)))
# Out:
# 0.98

# %%
dtc = DecisionTreeClassifier(min_impurity_decrease=.01, min_samples_leaf=3)
    
dtc.fit(X, y)

texto = tree.plot_tree(dtc, feature_names=iris.feature_names, class_names=iris.target_names, filled=True, rounded=True, impurity=True)

print(metrics.accuracy_score(y, dtc.predict(X)))
# Out:
# 0.9733333333333334

# %%
from dtreeviz.trees import dtreeviz
dtc = DecisionTreeClassifier(min_impurity_decrease = .01, max_depth=3)
    
dtc.fit(X, y)

dtreeviz(dtc, X, y, scale=1.5, feature_names=iris.feature_names )

# %% [markdown]
# ## CART - Classification and Regression Trees

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.datasets import load_boston

# %%
x = load_boston()
dtc = DecisionTreeRegressor(max_depth=5)

dtc.fit(x.data, x.target)

print(metrics.mean_squared_error(x.target, dtc.predict(x.data)))
print(metrics.mean_absolute_error(x.target, dtc.predict(x.data)))

plt.rcParams['figure.figsize'] = (40,30)

texto = tree.plot_tree(dtc, feature_names=x.feature_names, class_names='precio', filled=True, rounded=True, impurity=True)


plt.rcParams['figure.figsize'] = (16,12)
# Out:
# 6.840250706636063
# 1.9696971657575506

# %%
dtreeviz(dtc, x.data, x.target, scale=1.7, feature_names=x.feature_names )

# %% [markdown]
# ### Mejorando Árboles de Clasificación -  Ensemble Random Forests

# %%
from sklearn.ensemble import RandomForestClassifier

iris = load_iris()

rfc = RandomForestClassifier(bootstrap=True, max_depth=3, min_samples_leaf=3)

rfc.fit(iris.data, iris.target)

metrics.accuracy_score(iris.target, rfc.predict(iris.data))
# Out:
# 0.9666666666666667

# %%
len(rfc.estimators_)
# Out:
# 100
