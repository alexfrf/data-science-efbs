# %% [markdown]
# ![Logo](images/logo_mds.png)
#
# # Importación/Exportación de datos en Python
#
# Hasta ahora hemos utilizado de forma indiferente datos leídos desde ficheros Excel y desde ficheros CSV pero, de forma habitual, tendremos que trabajar con otros tipos de orígenes de información como pueden ser:
#  - Bases de datos
#  - Formatos específicos de fichero (como los de otras aplicaciones de procesado de datos: Stata, SAS, SPSS)
#  - Formatos específicos de almacenamiento (HDF, Feather, Parquet, pickle, json, XML)
#  - Páginas web
#
# En esta sesión trataremos los casos de las bases de datos, páginas web y los formatos específicos de almacenamiento.
#
# El cuarto grupo, los formatos de fichero, no se suele utilizar ya que lo más habitual al transferir datos entre aplicaciones es hacerlo en un formato lo más universal posible (por ejemplo, Excel o CSV), se tratan únicamente los formatos de almacenamiento ya que pueden tener ventajas a la hora de trabajar con analítica de datos en python.
#
# El uso de datos externos es, cada vez, más habitual en analítica de datos. Utilizar únicamente información propia puede hacernos llegar a conclusiones incorrectas en diferentes horizontes temporales:
#  - Descriptiva: por ejemplo, la venta insuficiente de un producto puede achacarse a un mal posicionamiento en tienda sin tener en cuenta que un competidor ha tenido una oferta vigente.
#  - Predictiva: por ejemplo, no tener en cuenta la predicción meteorológica puede afectar a nuestra capacidad de predecir cuánta cerveza se venderá en una cafetería
#  - Prescriptiva: por ejemplo, no incluir el incremento o decremento del precio de las materias primas en un proceso de optimización.
#
#
# ## Leer datos provenientes de Internet
#
# Nos referimos a datos provenientes de Internet como aquellos a los que podemos acceder desde una página web o desde un servicio de transferencia de datos que disponga de una API (interfaz de programación de aplicaciones).
#
# Vamos a tratar tres casos, de dificultad creciente, de forma separada:
# - Los datos están en una página web y están en una tabla
# - Los datos están en un servicio accesible mediante un API
# - Los datos están en una página web pero no están en una tabla
#
#
#
# # Los datos están en una tabla
# Nos referimos en este caso a las tablas más "aburridas" de las que podemos encontrar por Internet, por ejemplo [de la wikipedia](https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_por_superficie):
#
# ![Tabla_wikipedia](./images/tabla_wikipedia.png)
#
# o las tablas habituales de [los periódicos económicos](https://www.elconfidencial.com/mercados/indice/ibex35/):
#
# ![Tabla_cotizalia](./images/tabla_cotizalia.png)
#
# En estos casos, **pandas** nos proporciona una forma extremadamente sencilla de leer las tablas, no tenemos más que llamar al método ```read_html``` y, automáticamente, lee todas las tablas que contenga la página y las convierte en DataFrames.
#
# Pandas siempre devuelve una **lista** de DataFrames, cada DataFrame es una tabla en la página web, incluso aunque solo encuentre una tabla:

# %%
import pandas as pd
wiki = pd.read_html('https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_por_superficie')
wiki[0]
# Out:
#     Puesto               Territorio Superficie (km²)  \
# 0        -           Planeta Tierra      510 072 000
# 1        -                  Océanos      359 685 360
# 2        -              Continentes      150 386 640
# 3        1                    Rusia       17 098 242
# 4        -                Antártida       14 000 000
# ..     ...                      ...              ...
# 249      -  Islas Ashmore y Cartier                5
# 250      -            Islas Spratly                5
# 251      -  Islas del Mar del Coral                3
# 252    194                   Mónaco                2
# 253    195      Ciudad del Vaticano              044
#
#                                                  Datos
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    País más extenso del mundo. País más grande de...
# 4    Con territorios reclamados por Argentina,[5]​ ...
# ..                                                 ...
# 249                   Administradas por Australia.[6]​
# 250                         Territorio disputado.[43]​
# 251                    Administrado por Australia.[6]​
# 252      País con salida al mar más pequeño del mundo.
# 253     País más pequeño del mundo. Sin salida al mar.
#
# [254 rows x 4 columns]

# %% [markdown]
# ## Ejercicio 1. Cotizalia
#
# Accede a los datos de la web de Cotizalia en: https://www.elconfidencial.com/mercados/indice/ibex35/ y localiza las cinco acciones que tienen mayor valor de capitalización.

# %%
ibex = pd.read_html('https://www.elconfidencial.com/mercados/indice/ibex35/')[0]
ibex = ibex.sort_values(by='Capitalización',ascending=False).head(5)
ibex
# Out:
#        Nombre  Último  Dif%. Máx. Intradía Mín. Intradía Acci. Efect.  \
# 20    INDITEX  280400      0             -             -     -      -
# 19  IBERDROLA   99440      0             -             -     -      -
# 31  SANTANDER   28155      0             -             -     -      -
# 9        BBVA   50970      0             -             -     -      -
# 11    CELLNEX  488800      0             -             -     -      -
#
#     Capitalización      Hora
# 20          87.391  17:38:00
# 19          63.304  17:38:00
# 31          48.823  17:38:00
# 9           33.986  17:38:00
# 11          33.205  17:38:00

# %% [markdown]
# ## Páginas web que no contienen tablas (o que no responden a pandas)
#
# Sin embargo, no todas las páginas que parece que contienen una tabla pueden ser leídas por pandas. Cada vez es más habitual que las páginas web contengan elementos que bloquean la navegación hasta que se acepten las cookies o cuyo contenido no sea una tabla a pesar de parecerlo.
#
# Por ejemplo, Yahoo nos da datos de la cotización del bitcoin en: [https://finance.yahoo.com/quote/BTC-USD/history/](https://finance.yahoo.com/quote/BTC-USD/history/)
# ![Htco_bitcoin](./images/htco_bitcoin.png)
#
# Pero, si pedimos los datos desde **pandas** no son tan colaborativos:

# %%
#bitcoin = pd.read_html('https://finance.yahoo.com/quote/BTC-USD/history/')

# %% [markdown]
# De la misma forma, la información en algunas páginas web puede no ser ni siquiera una tabla:
#
# ![Zalando](./images/zalando.png)

# %% [markdown]
# # Uso de APIs para obtener información externa
#
# En programación, se llama API, a una interfaz de comunicación que se deja abierta para que terceros puedan interactuar con una aplicación.
#
# Las APIs pueden servir para enviar y recibir datos, comandos... es habitual que muchos servicios, a partir de la web 2.0 (~2005), proporcionen tanto una interfaz gráfica (página web) como una API para interactuar con ellos.
#
# Por ejemplo, en las aplicaciones de la suite Zoho (aplicaciones empresariales en formato web: CRM, ERP,...) el uso de APIs permite interactuar con el sistema sin utilizar su web; mediante ellas, podríamos, por ejemplo, crear una entrada en el CRM cuando recibamos un correo electrónico de determinadas direcciones o cambiando el estado de pago de una factura cuando veamos el apunte en el banco.
#
# En analítica de datos, utilizaremos las API, principalmente, como mecanismo para obtener datos externos de **servicios web**, estos datos pueden ser tanto gratuitos como de pago.
#
# Algunos ejemplos de datos provenientes de API pueden ser:
#  - Servicios meteorológicos (AEMET, Accuweaher - este último de pago)
#  - Servicios financieros (yahoo finance, quandl - de pago)
#  - Redes sociales (twitter principalmente, Instagram y Facebook han bloqueado el acceso a sus APIs salvo para casos excepcionales).
#
# Puesto que el proceso de conexión a Twitter es excesivamente laborioso (tienen que autorizar el acceso y proporcionar una clave de uso), haremos un ejemplo de conexión para AEMET.
#
# Recordad que, aunque un servicio gratuito puede parece más atractivo inicialmente, no nos da ninguna garantía en cuánto a plazos, disponibilidad, continuidad... por lo tanto, antes de usar servicios gratuitos tendremos que evaluar pros y contras y el coste de alternativas de pago si las hubiese (sesión 1, tipología de datos).
#
#
# ## Acceso al API de AEMET
#
# La agencia española de meteorología ofrece acceso a los datos de observaciones y predicciones de cientos de estaciones meteorológicas distribuidas por España mediante una API que podemos encontrar en: [AEMET Open Data](https://opendata.aemet.es/centrodedescargas/inicio)
#
# En esta web podemos registrarnos en Obtención de API Key

# %% [markdown]
# ### Ejercicio 3: Obtén una Key de AEMET (utiliza la dirección de correo del máster)

# %%
key = "eyJhbGciOiJIUzI1NiJ9.eyJzdWIiOiJhbGVqYW5kcm8uZmVybmFuZGV6QGVmYnMuZWR1LmVzIiwianRpIjoiZGVmOTI0N2QtYWQyZS00OTEzLTk3NDEtOWRjNmI4ZmZjMDYyIiwiaXNzIjoiQUVNRVQiLCJpYXQiOjE2MzkxNTQ1MjQsInVzZXJJZCI6ImRlZjkyNDdkLWFkMmUtNDkxMy05NzQxLTlkYzZiOGZmYzA2MiIsInJvbGUiOiIifQ.5urxSmy-vYj-NLNwvtZtu8epRl8Q73Kb4rKmtsTGMmE"

# %% [markdown]
# ## Evaluando qué podemos hacer con un servicio web
#
# Si vemos la documentación que hay en [opendada.aemet.es](https://opendata.aemet.es/dist/index.html?#/) veremos que hace mención a muchos tipos de datos (Predicciones específicas, Valores Climatológicos...) explorar todas ellas requiere mucho tiempo.
#
# Para poder realizar una práctica más o menos acotada, utilizaremos únicamente tress métodos de los muchos que ofrece la AEMET:
#  - Municipios [Maestro -> /api/maestro/municipios](https://opendata.aemet.es/dist/index.html?#/maestro)
#  - Observación [Observación Convencional -> /api/observacion/convencional/todas](https://opendata.aemet.es/dist/index.html?#!/observacion-convencional/Datos_de_observaci%C3%B3n_Tiempo_actual)
#  - Prediccion [Predicciones Específicas -> /api/prediccion/especifica/municipio/diaria/{municipio}](https://opendata.aemet.es/dist/index.html?#!/predicciones-especificas/Predicci%C3%B3n_por_municipios_horaria_Tiempo_actual)
#
# El primero muestra una forma de interactuar sencilla con una API, simplemente le pedimos un maestro de todos los municipios que conoce la aplicación.
#
# El segundo servicio nos devuelve datos observados de todas las estaciones.
#
# El último nos dal a predicción para un municipio.
#
# Para acceder a cada uno de ellos necesitamos realizar **peticiones** a un servidor web. Estas peticiones son como las que realiza nuestro navegador cuando pedimos una página, para poder hacerlas desde Python necesitamos utilizar una herramienta que sea capaz de hablar con servidores de páginas web.
#
# En nuestro caso utilizaremos la librería **requests** que es muy sencilla de utilizar:

# %%
import requests

google = requests.get('https://www.google.com')

# %% [markdown]
# La clave es la palabra **get** que es un **verbo** admitido por los servidores de páginas web (la lista, incompleta, de verbos que puede llegar a aceptar un servidor web está formada por: GET, POST, PUT, PATCH y DELETE, y todos juntos forman lo que se llama una interfaz RESTful)
#
# En nuestro caso nos preocupa únicamente ```get``` que simplemente "obtiene" esa página del servidor.
#
# Este código pide la página "www.google.com" al servidor de páginas web de google y almacena el resultado en una variable llamada google.
#
# Esa variable tiene varias cosas dentro, pero, la más importante es el contenido:

# %%
google.content[:1000] # Mostramos los primeros 1000 caracteres de la página de google tal como los lee el navegador
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="es"><head><meta content="Google.es permite acceder a la informaci\xf3n mundial en castellano, catal\xe1n, gallego, euskara e ingl\xe9s." name="description"><meta content="noodp" name="robots"><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/logos/doodles/2021/seasonal-holidays-2021-6753651837109324-6752733080595605-cst.gif" itemprop="image"><meta content="Felices fiestas 2021" property="twitter:title"><meta content="Felices fiestas 2021 #GoogleDoodle" property="twitter:description"><meta content="Felices fiestas 2021 #GoogleDoodle" property="og:description"><meta content="summary_large_image" property="twitter:card"><meta content="@GoogleDoodles" property="twitter:site"><meta content="https://www.google.com/logos/doodles/2021/seasonal-holidays-2021-6753651837109324-2xa.gif" property="twitter:image"><meta content="https://www.google.com/logos/doodles/2021/seasonal-holidays-2021-67536518'

# %% [markdown]
# Como curiosidad, podemos ver la cantidad de texto que hace falta para hacer la página inicial de google:

# %%
len(google.content) / 1000
# Out:
# 16.137

# %% [markdown]
# Para mostrar la página inicial de Google, necesitamos más de 16.000 letras, unas 5 páginas de texto.
#
# Si leemos el contenido de la web de países que utilizamos antes de la wikipedia con Requests obtenemos:

# %%
html_paises = requests.get('https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_por_superficie')

html_paises.content[:1000]
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="es" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Anexo:Pa\xc3\xadses por superficie - Wikipedia, la enciclopedia libre</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":false,"wgSeparatorTransformTable":[",\\t.","\xc2\xa0\\t,"],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","enero","febrero","marzo","abril","mayo","junio","julio","agosto","septiembre","octubre","noviembre","diciembre"],"wgRequestId":"117130e6-2d7d-4104-a40e-42aaf4f384db","wgCSPNonce":false,"wgCanonicalNamespace":"Anexo","wgCanonicalSpecialPageName":false,"wgNamespaceNumber":104,"wgPageName":"Anexo:Pa\xc3\xadses_por_superficie","wgTitle":"Pa\xc3\xadses por superficie","wgCurRevisionId":140540589,"wgRevisionId":140540589,"wgArticleId":4474,"wgIsArticle":true,"wgIsRedirect":false,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia:P\xc3\xa1ginas con plantillas con argumentos duplicados","Anexos:Comparat'

# %%
print(f'La lista de países de la wikipedia, requeriría, si se imprimiese en papel, unas {int(len(html_paises.content) / 3000)} páginas')
# Out:
# La lista de países de la wikipedia, requeriría, si se imprimiese en papel, unas 105 páginas

# %% [markdown]
# ### Solicitando datos a la  AEMET
#
# Si ahora intentamos pedir los datos de la AEMET veremos que tenemos varias dudas, primero vemos que nos habla de algo que parecen páginas (/api/prediccion/especial/municipio/horaria) pero no nos dice la ruta base a utilizar.
#
# En este caso la ruta base será: https://opendata.aemet.es/opendata
#
# Es una buena costumbre crear una variable con la ruta base de la API a la que accedemos:

# %%
ruta_base_aemet = 'https://opendata.aemet.es/opendata'

# %% [markdown]
# Esto lee la página web inicial de Google y guarda toda la respuesta del servidor en la variable ```google```.
#
# En ella podemos ver diferentes parámetros de respuesta del servidor (si todo fue bien,...) pero, lo más importante, podemos ver el **contenido** de la web:

# %% [markdown]
# Ahora, podríamos pedir los datos de las diferentes páginas:
# - Municipios: /api/maestro/municipios
# - Observación: /api/observacion/convencional/todas
# - Predicción: /api/prediccion/especifica/municipio/diaria/{municipio}
#
# Para pedirlas tenemos que concatener la ruta base con la ruta del servicio especificado pero, si lo hacemos, no recibiremos ninguna respuesta:

# %%
res = requests.get(ruta_base_aemet + '/api/maestro/municipios')

res.content
# Out:
# b''

# %% [markdown]
# Esto es porque el API de AEMET exige que le pasemos la key que nos ha llegado al correo electrónico, para ello tenemos que hacer uso de las "cabeceras" de las peticiones en las que podemos pasar información especial al servidor que procesa la petición:

# %%
headers = {'api_key': key}

res = requests.get(ruta_base_aemet + '/api/maestro/municipios', headers=headers)

print(f'Recibidos {len(res.content)} caracteres, los primeros 10000 son: \n{res.content[:10000]}')
# Out:
# Recibidos 3008591 caracteres, los primeros 10000 son:
# b'[ {\n  "latitud" : "40\xba32\'54.450744\\"",\n  "id_old" : "44004",\n  "url" : "ababuj-id44001",\n  "latitud_dec" : "40.54845854",\n  "altitud" : "1372",\n  "capital" : "Ababuj",\n  "num_hab" : "65",\n  "zona_comarcal" : "624401",\n  "destacada" : "0",\n  "nombre" : "Ababuj",\n  "longitud_dec" : "-0.80780117",\n  "id" : "id44001",\n  "longitud" : "-0\xba48\'28.084212\\""\n}, {\n  "latitud" : "40\xba54\'58.824504\\"",\n  "id_old" : "40004",\n  "url" : "abades-id40001",\n  "latitud_dec" : "40.91634014",\n  "altitud" : "971",\n  "capital" : "Abades",\n  "num_hab" : "873",\n  "zona_comarcal" : "674001",\n  "destacada" : "0",\n  "nombre" : "Abades",\n  "longitud_dec" : "-4.26787389",\n  "id" : "id40001",\n  "longitud" : "-4\xba16\'4.346004\\""\n}, {\n  "latitud" : "43\xba8\'51.525564\\"",\n  "id_old" : "48010",\n  "url" : "abadino-abadino-zelaieta-id48001",\n  "latitud_dec" : "43.14764599",\n  "altitud" : "144",\n  "capital" : "Abadi\xf1o-Zelaieta",\n  "num_hab" : "7504",\n  "zona_comarcal" : "754802",\n  "destacada" : "0",\n  "nombre" : "Abadi\xf1o",\n  "longitud_dec" : "-2.60687319",\n  "id" : "id48001",\n  "longitud" : "-2\xba36\'24.743484\\""\n}, {\n  "latitud" : "40\xba15\'34.315272\\"",\n  "id_old" : "10004",\n  "url" : "abadia-id10001",\n  "latitud_dec" : "40.25953202",\n  "altitud" : "451",\n  "capital" : "Abad\xeda",\n  "num_hab" : "324",\n  "zona_comarcal" : "701001",\n  "destacada" : "0",\n  "nombre" : "Abad\xeda",\n  "longitud_dec" : "-5.97785806",\n  "id" : "id10001",\n  "longitud" : "-5\xba58\'40.289016\\""\n}, {\n  "latitud" : "43\xba21\'46.874736\\"",\n  "id_old" : "27010",\n  "url" : "abadin-abadin-o-provecende-id27001",\n  "latitud_dec" : "43.36302076",\n  "altitud" : "515",\n  "capital" : "Abad\xedn o Provecende",\n  "num_hab" : "2646",\n  "zona_comarcal" : "712702",\n  "destacada" : "0",\n  "nombre" : "Abad\xedn",\n  "longitud_dec" : "-7.47214495",\n  "id" : "id27001",\n  "longitud" : "-7\xba28\'19.72182\\""\n}, {\n  "latitud" : "42\xba37\'23.69766\\"",\n  "id_old" : "09004",\n  "url" : "abajas-id09001",\n  "latitud_dec" : "42.62324935",\n  "altitud" : "839",\n  "capital" : "Abajas",\n  "num_hab" : "29",\n  "zona_comarcal" : "670902",\n  "destacada" : "0",\n  "nombre" : "Abajas",\n  "longitud_dec" : "-3.58176303",\n  "id" : "id09001",\n  "longitud" : "-3\xba34\'54.346908\\""\n}, {\n  "latitud" : "43\xba2\'48.186348\\"",\n  "id_old" : "20010",\n  "url" : "abaltzisketa-id20001",\n  "latitud_dec" : "43.04671843",\n  "altitud" : "374",\n  "capital" : "Abaltzisketa",\n  "num_hab" : "329",\n  "zona_comarcal" : "752002",\n  "destacada" : "0",\n  "nombre" : "Abaltzisketa",\n  "longitud_dec" : "-2.10562430",\n  "id" : "id20001",\n  "longitud" : "-2\xba6\'20.24748\\""\n}, {\n  "latitud" : "38\xba12\'28.401012\\"",\n  "id_old" : "30010",\n  "url" : "abanilla-id30001",\n  "latitud_dec" : "38.20788917",\n  "altitud" : "222",\n  "capital" : "Abanilla",\n  "num_hab" : "6435",\n  "zona_comarcal" : "733003",\n  "destacada" : "0",\n  "nombre" : "Abanilla",\n  "longitud_dec" : "-1.04259775",\n  "id" : "id30001",\n  "longitud" : "-1\xba2\'33.3519\\""\n}, {\n  "latitud" : "41\xba8\'17.648448\\"",\n  "id_old" : "50003",\n  "url" : "abanto-id50001",\n  "latitud_dec" : "41.13823568",\n  "altitud" : "929",\n  "capital" : "Abanto",\n  "num_hab" : "113",\n  "zona_comarcal" : "625002",\n  "destacada" : "0",\n  "nombre" : "Abanto",\n  "longitud_dec" : "-1.69921759",\n  "id" : "id50001",\n  "longitud" : "-1\xba41\'57.183324\\""\n}, {\n  "latitud" : "43\xba18\'38.977164\\"",\n  "id_old" : "48020",\n  "url" : "abanto-y-ciervana-abanto-zierbena-gallarta-id48002",\n  "latitud_dec" : "43.31082699",\n  "altitud" : "100",\n  "capital" : "Gallarta",\n  "num_hab" : "9688",\n  "zona_comarcal" : "754802",\n  "destacada" : "0",\n  "nombre" : "Abanto y Ci\xe9rvana-Abanto Zierbena",\n  "longitud_dec" : "-3.07319265",\n  "id" : "id48002",\n  "longitud" : "-3\xba4\'23.49354\\""\n}, {\n  "latitud" : "42\xba3\'48.311352\\"",\n  "id_old" : "34004",\n  "url"  ...

# %% [markdown]
# Podemos ver que, hemos recibido 3 Mb de datos (1000 páginas de texto)
#
# La información recibida, tal como está viene en un formato denominado ```json``` que es un formato de intercambio de datos muy utilizado para transferir el equivalente a nuestros diccionarios y listas de python.
#
# Podemos ver ese contenido json utilizando el método ```json```de la respuesta de requests:

# %%
res.json()[:5]
# Out:
# [{'latitud': '40º32\'54.450744"',
#   'id_old': '44004',
#   'url': 'ababuj-id44001',
#   'latitud_dec': '40.54845854',
#   'altitud': '1372',
#   'capital': 'Ababuj',
#   'num_hab': '65',
#   'zona_comarcal': '624401',
#   'destacada': '0',
#   'nombre': 'Ababuj',
#   'longitud_dec': '-0.80780117',
#   'id': 'id44001',
#   'longitud': '-0º48\'28.084212"'},
#  {'latitud': '40º54\'58.824504"',
#   'id_old': '40004',
#   'url': 'abades-id40001',
#   'latitud_dec': '40.91634014',
#   'altitud': '971',
#   'capital': 'Abades',
#   'num_hab': '873',
#   'zona_comarcal': '674001',
#   'destacada': '0',
#   'nombre': 'Abades',
#   'longitud_dec': '-4.26787389',
#   'id': 'id40001',
#   'longitud': '-4º16\'4.346004"'},
#  {'latitud': '43º8\'51.525564"',
#   'id_old': '48010',
#   'url': 'abadino-abadino-zelaieta-id48001',
#   'latitud_dec': '43.14764599',
#   'altitud': '144',
#   'capital': 'Abadiño-Zelaieta',
#   'num_hab': '7504',
#   'zona_comarcal': '754802',
#   'destacada': '0',
#   'nombre': 'Abadiño',
#   'longitud_dec': '-2.60687319',
#   'id': 'id48001',
#   'longitud': '-2º36\'24.743484"'},
#  {'latitud': '40º15\'34.315272"',
#   'id_old': '10004',
#   'url': 'abadia-id10001',
#   'latitud_dec': '40.25953202',
#   'altitud': '451',
#   'capital': 'Abadía',
#   'num_hab': '324',
#   'zona_comarcal': '701001',
#   'destacada': '0',
#   'nombre': 'Abadía',
#   'longitud_dec': '-5.97785806',
#   'id': 'id10001',
#   'longitud': '-5º58\'40.289016"'},
#  {'latitud': '43º21\'46.874736"',
#   'id_old': '27010',
#   'url': 'abadin-abadin-o-provecende-id27001',
#   'latitud_dec': '43.36302076',
#   'altitud': '515',
#   'capital': 'Abadín o Provecende',
#   'num_hab': '2646',
#   'zona_comarcal': '712702',
#   'destacada': '0',
#   'nombre': 'Abadín',
#   'longitud_dec': '-7.47214495',
#   'id': 'id27001',
#   'longitud': '-7º28\'19.72182"'}]

# %% [markdown]
# Esta respuesta está formada por una lista de diccionarios, que podemos utilizar como cualquier otro diccionario de Python:

# %%
primer_municipio = res.json()[0]

primer_municipio['capital']
# Out:
# 'Ababuj'

# %% [markdown]
# Pero, como trabajar con diccionarios y json no es muy operativo, lo normal es pasar este contenido a un DataFrame de Pandas:

# %%
df = pd.DataFrame(res.json())

df.head()
# Out:
#             latitud id_old                                 url  latitud_dec  \
# 0  40º32'54.450744"  44004                      ababuj-id44001  40.54845854
# 1  40º54'58.824504"  40004                      abades-id40001  40.91634014
# 2   43º8'51.525564"  48010    abadino-abadino-zelaieta-id48001  43.14764599
# 3  40º15'34.315272"  10004                      abadia-id10001  40.25953202
# 4  43º21'46.874736"  27010  abadin-abadin-o-provecende-id27001  43.36302076
#
#   altitud              capital num_hab zona_comarcal destacada   nombre  \
# 0    1372               Ababuj      65        624401         0   Ababuj
# 1     971               Abades     873        674001         0   Abades
# 2     144     Abadiño-Zelaieta    7504        754802         0  Abadiño
# 3     451               Abadía     324        701001         0   Abadía
# 4     515  Abadín o Provecende    2646        712702         0   Abadín
#
#   longitud_dec       id          longitud
# 0  -0.80780117  id44001  -0º48'28.084212"
# 1  -4.26787389  id40001   -4º16'4.346004"
# 2  -2.60687319  id48001  -2º36'24.743484"
# 3  -5.97785806  id10001  -5º58'40.289016"
# 4  -7.47214495  id27001   -7º28'19.72182"

# %% [markdown]
# ### Ejercicio 4: Obtén la información de la observación convencional

# %%
headers = {'api_key': key}

res = requests.get(ruta_base_aemet + '/api/observacion/convencional/todas', headers=headers)

# %%
res.json()
# Out:
# {'descripcion': 'exito',
#  'estado': 200,
#  'datos': 'https://opendata.aemet.es/opendata/sh/c6ad3b7e',
#  'metadatos': 'https://opendata.aemet.es/opendata/sh/55c2971b'}

# %% [markdown]
# En este caso vemos que AEMET nos ha engañado y, en lugar de darnos los datos, nos ha enviado a buscarlos a otros sitio, concretamente a la página indicada en "datos".
#
# Si obtenemos esa página:

# %%
res.json()['datos']
# Out:
# 'https://opendata.aemet.es/opendata/sh/c6ad3b7e'

# %%
resultado = res.json()

resultado_real = requests.get(resultado['datos'])

resultado_real.content[:100]
# Out:
# b'[ {\n  "idema" : "0009X",\n  "lon" : 0.963335,\n  "fint" : "2021-12-28T02:00:00",\n  "prec" : 0.0,\n  "al'

# %%
resultado_real.json()
# Out:
# [{'idema': '0009X',
#   'lon': 0.963335,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 406.0,
#   'vmax': 12.3,
#   'vv': 5.4,
#   'dv': 272.0,
#   'lat': 41.213894,
#   'dmax': 257.0,
#   'ubi': 'ALFORJA',
#   'hr': 65.0,
#   'tamin': 13.1,
#   'ta': 13.2,
#   'tamax': 13.3},
#  {'idema': '0016A',
#   'lon': 1.178894,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 71.0,
#   'vmax': 13.4,
#   'vv': 7.7,
#   'dv': 270.0,
#   'lat': 41.14972,
#   'dmax': 270.0,
#   'ubi': 'REUS/AEROPUERTO',
#   'pres': 1003.7,
#   'hr': 54.0,
#   'stdvv': 0.9,
#   'ts': 15.5,
#   'pres_nmar': 1012.7,
#   'tamin': 14.7,
#   'ta': 15.3,
#   'tamax': 15.5,
#   'tpr': 6.1,
#   'vis': 30.0,
#   'stddv': 5.0,
#   'inso': 0.0},
#  {'idema': '0034X',
#   'lon': 1.260838,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 233.0,
#   'lat': 41.293053,
#   'ubi': 'VALLS',
#   'hr': 66.0,
#   'tamin': 12.9,
#   'ta': 13.6,
#   'tamax': 13.6},
#  {'idema': '0042Y',
#   'lon': 1.249167,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 55.0,
#   'vmax': 9.2,
#   'vv': 3.3,
#   'dv': 274.0,
#   'lat': 41.123894,
#   'dmax': 260.0,
#   'ubi': 'TARRAGONA  FAC. GEOGRAFIA',
#   'hr': 57.0,
#   'tamin': 15.8,
#   'ta': 16.3,
#   'tamax': 16.3},
#  {'idema': '0061X',
#   'lon': 1.519269,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 632.0,
#   'vmax': 14.9,
#   'vv': 9.2,
#   'dv': 281.0,
#   'lat': 41.417053,
#   'dmax': 277.0,
#   'ubi': 'PONTONS',
#   'hr': 64.0,
#   'tamin': 10.8,
#   'ta': 11.1,
#   'tamax': 11.1},
#  {'idema': '0066X',
#   'lon': 1.676942,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 177.0,
#   'vmax': 7.5,
#   'vv': 3.4,
#   'dv': 252.0,
#   'lat': 41.33028,
#   'dmax': 267.0,
#   'ubi': 'VILAFRANCA DEL PENEDÈS',
#   'hr': 68.0,
#   'tamin': 10.1,
#   'ta': 13.7,
#   'tamax': 13.7},
#  {'idema': '0073X',
#   'lon': 1.852626,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 58.0,
#   'vmax': 7.7,
#   'vv': 3.4,
#   'dv': 343.0,
#   'lat': 41.243786,
#   'dmax': 322.0,
#   'ubi': 'SITGES-VALLCARCA',
#   'hr': 60.0,
#   'tamin': 15.6,
#   'ta': 15.7,
#   'tamax': 15.9},
#  {'idema': '0076',
#   'lon': 2.069995,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 4.0,
#   'vmax': 8.8,
#   'vv': 6.6,
#   'dv': 260.0,
#   'lat': 41.29278,
#   'dmax': 260.0,
#   'ubi': 'BARCELONA/AEROPUERTO',
#   'pres': 1011.4,
#   'hr': 64.0,
#   'stdvv': 0.3,
#   'ts': 14.3,
#   'pres_nmar': 1012.0,
#   'tamin': 15.1,
#   'ta': 15.5,
#   'tamax': 15.7,
#   'tpr': 8.7,
#   'vis': 24.7,
#   'stddv': 2.0,
#   'inso': 0.0},
#  {'idema': '0092X',
#   'lon': 1.857494,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 682.0,
#   'vmax': 3.5,
#   'vv': 2.0,
#   'dv': 78.0,
#   'lat': 42.101387,
#   'dmax': 90.0,
#   'ubi': 'BERGA  INSTITUTO',
#   'hr': 85.0,
#   'tamin': 4.5,
#   'ta': 4.5,
#   'tamax': 4.9},
#  {'idema': '0106X',
#   'lon': 1.872504,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 361.0,
#   'vmax': 3.7,
#   'vv': 1.0,
#   'dv': 183.0,
#   'lat': 41.866386,
#   'dmax': 210.0,
#   'ubi': 'BALSARENY',
#   'hr': 86.0,
#   'tamin': 7.6,
#   'ta': 8.8,
#   'tamax': 9.1},
#  {'idema': '0114X',
#   'lon': 2.026561,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 700.0,
#   'vmax': 1.9,
#   'vv': 0.4,
#   'dv': 259.0,
#   'lat': 42.007057,
#   'dmax': 325.0,
#   'ubi': 'PRATS DE LLUÇANÈS',
#   'hr': 97.0,
#   'tamin': 3.7,
#   'ta': 3.7,
#   'tamax': 3.9},
#  {'idema': '0120X',
#   'lon': 2.09539,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 742.0,
#   'vmax': 6.3,
#   'vv': 2.9,
#   'dv': 281.0,
#   'lat': 41.81328,
#   'dmax': 260.0,
#   'ubi': 'MOIÀ',
#   'hr': 86.0,
#   'tamin': 8.0,
#   'ta': 8.1,
#   'tamax': 8.2},
#  {'idema': '0149X',
#   'lon': 1.84028,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 291.0,
#   'vmax': 3.4,
#   'vv': 0.8,
#   'dv': 247.0,
#   'lat': 41.71988,
#   'dmax': 242.0,
#   'ubi': 'MANRESA',
#   'pres': 978.1,
#   'hr': 73.0,
#   'ts': 6.6,
#   'pres_nmar': 1012.7,
#   'tamin': 9.8,
#   'ta': 10.7,
#   'tamax': 10.7,
#   'tpr': 6.1,
#   'vis': 20.0,
#   'inso': 0.0,
#   'tss5cm': 8.7,
#   'psoltp': 0.0,
#   'pliqt': 0.0},
#  {'idema': '0158X',
#   'lon': 1.839223,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 738.0,
#   'lat': 41.594444,
#   'ubi': 'MONTSERRAT',
#   'hr': 68.0,
#   'tamin': 11.1,
#   'ta': 11.2,
#   'tamax': 11.3},
#  {'idema': '0171X',
#   'lon': 1.617778,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 313.0,
#   'vmax': 4.7,
#   'vv': 1.9,
#   'dv': 285.0,
#   'lat': 41.578888,
#   'dmax': 238.0,
#   'ubi': 'IGUALADA',
#   'hr': 65.0,
#   'tamin': 11.4,
#   'ta': 12.6,
#   'tamax': 12.6,
#   'tpr': 6.2,
#   'rviento': 63.0},
#  {'idema': '0194D',
#   'lon': 1.885,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 647.0,
#   'lat': 41.40819,
#   'ubi': 'CORBERA  PIC D?AGULLES ',
#   'hr': 74.0,
#   'tamin': 10.4,
#   'ta': 10.9,
#   'tamax': 10.9},
#  {'idema': '0201D',
#   'lon': 2.200001,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 6.0,
#   'vmax': 8.5,
#   'vv': 4.2,
#   'dv': 254.0,
#   'lat': 41.390556,
#   'dmax': 253.0,
#   'ubi': 'BARCELONA CMT',
#   'hr': 65.0,
#   'tamin': 14.8,
#   'ta': 15.6,
#   'tamax': 15.7,
#   'tpr': 9.0,
#   'rviento': 144.0},
#  {'idema': '0201X',
#   'lon': 2.173886,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 5.0,
#   'vmax': 2.6,
#   'vv': 1.2,
#   'dv': 231.0,
#   'lat': 41.374996,
#   'dmax': 272.0,
#   'ubi': 'BARCELONA  DRASSANES',
#   'hr': 62.0,
#   'tamin': 14.7,
#   'ta': 14.7,
#   'tamax': 14.9},
#  {'idema': '0222X',
#   'lon': 2.168412,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 175.0,
#   'vmax': 3.2,
#   'vv': 1.3,
#   'dv': 300.0,
#   'lat': 41.612663,
#   'dmax': 345.0,
#   'ubi': 'CALDES DE MONTBUI',
#   'hr': 86.0,
#   'tamin': 8.2,
#   'ta': 8.7,
#   'tamax': 8.8},
#  {'idema': '0244X',
#   'lon': 2.362637,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 56.0,
#   'vmax': 10.0,
#   'vv': 5.2,
#   'dv': 259.0,
#   'lat': 41.504894,
#   'dmax': 287.0,
#   'ubi': 'VILASSAR DE DALT',
#   'hr': 59.0,
#   'tamin': 15.5,
#   'ta': 15.6,
#   'tamax': 15.9},
#  {'idema': '0252D',
#   'lon': 2.54,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 74.0,
#   'vmax': 7.2,
#   'vv': 1.2,
#   'dv': 290.0,
#   'lat': 41.587223,
#   'dmax': 266.0,
#   'ubi': 'ARENYS DE MAR',
#   'hr': 53.0,
#   'tamin': 14.1,
#   'ta': 14.3,
#   'tamax': 14.6,
#   'tpr': 4.8,
#   'rviento': 70.0},
#  {'idema': '0255B',
#   'lon': 2.696949,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 40.0,
#   'vmax': 8.0,
#   'vv': 2.7,
#   'dv': 247.0,
#   'lat': 41.650833,
#   'dmax': 250.0,
#   'ubi': 'SANTA SUSANA',
#   'hr': 59.0,
#   'tamin': 7.9,
#   'ta': 14.0,
#   'tamax': 14.9,
#   'tpr': 6.1,
#   'rviento': 86.0},
#  {'idema': '0260X',
#   'lon': 2.431023,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 936.0,
#   'lat': 41.760063,
#   'ubi': 'FONTMARTINA',
#   'hr': 78.0,
#   'tamin': 7.7,
#   'ta': 8.0,
#   'tamax': 8.0},
#  {'idema': '0281Y',
#   'lon': 2.805112,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 45.0,
#   'vmax': 3.3,
#   'vv': 1.2,
#   'dv': 238.0,
#   'lat': 41.677055,
#   'dmax': 240.0,
#   'ubi': 'BLANES JARDIN BOTANICO',
#   'hr': 71.0,
#   'tamin': 12.2,
#   'ta': 12.4,
#   'tamax': 12.4},
#  {'idema': '0284X',
#   'lon': 3.030933,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 14.0,
#   'vmax': 4.2,
#   'vv': 1.8,
#   'dv': 276.0,
#   'lat': 41.807816,
#   'dmax': 270.0,
#   'ubi': 'CASTELL PLATJA D?ARO',
#   'hr': 96.0,
#   'tamin': 7.5,
#   'ta': 7.5,
#   'tamax': 7.8},
#  {'idema': '0312X',
#   'lon': 2.364353,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 851.0,
#   'vmax': 9.3,
#   'vv': 1.8,
#   'dv': 202.0,
#   'lat': 42.258446,
#   'dmax': 257.0,
#   'ubi': 'SANT PAU DE SEGURIES',
#   'hr': 100.0,
#   'tamin': 2.6,
#   'ta': 2.9,
#   'tamax': 2.9},
#  {'idema': '0320I',
#   'lon': 2.102774,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 1151.0,
#   'vmax': 7.2,
#   'vv': 1.2,
#   'dv': 280.0,
#   'lat': 42.31688,
#   'dmax': 210.0,
#   'ubi': 'PLANOLES',
#   'hr': 70.0,
#   'tamin': 6.1,
#   'ta': 6.8,
#   'tamax': 6.8},
#  {'idema': '0324A',
#   'lon': 2.196187,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 675.0,
#   'lat': 42.191387,
#   'ubi': 'RIPOLL',
#   'hr': 98.0,
#   'tamin': 1.0,
#   'ta': 1.2,
#   'tamax': 1.4,
#   'tpr': 0.9,
#   'rviento': 0.0},
#  {'idema': '0360X',
#   'lon': 2.551007,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 337.0,
#   'vmax': 4.9,
#   'vv': 0.7,
#   'dv': 66.0,
#   'lat': 42.052837,
#   'dmax': 40.0,
#   'ubi': 'LES PLANES D?HOSTOLES',
#   'hr': 99.0,
#   'tamin': 3.5,
#   'ta': 5.4,
#   'tamax': 5.4},
#  {'idema': '0363X',
#   'lon': 2.513329,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 810.0,
#   'vmax': 10.5,
#   'vv': 6.4,
#   'dv': 329.0,
#   'lat': 41.880833,
#   'dmax': 315.0,
#   'ubi': 'SANT HILARI',
#   'hr': 74.0,
#   'tamin': 8.8,
#   'ta': 8.8,
#   'tamax': 8.9},
#  {'idema': '0367',
#   'lon': 2.763329,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 143.0,
#   'vmax': 2.1,
#   'vv': 1.1,
#   'dv': 30.0,
#   'lat': 41.911667,
#   'dmax': 30.0,
#   'ubi': 'GIRONA/COSTA BRAVA',
#   'pres': 994.5,
#   'hr': 98.0,
#   'stdvv': 0.4,
#   'ts': 10.1,
#   'pres_nmar': 1010.3,
#   'tamin': 5.3,
#   'ta': 5.4,
#   'tamax': 6.5,
#   'tpr': 5.1,
#   'stddv': 100.0,
#   'inso': 0.0},
#  {'idema': '0370E',
#   'lon': 2.819442,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 76.0,
#   'vmax': 2.2,
#   'vv': 0.4,
#   'dv': 51.0,
#   'lat': 41.972332,
#   'dmax': 57.0,
#   'ubi': 'GIRONA-PARC MIGDIA',
#   'hr': 95.0,
#   'tamin': 7.1,
#   'ta': 7.2,
#   'tamax': 7.4},
#  {'idema': '0372C',
#   'lon': 2.763611,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 157.0,
#   'vmax': 2.5,
#   'vv': 1.2,
#   'dv': 304.0,
#   'lat': 42.104443,
#   'dmax': 308.0,
#   'ubi': 'PORQUERES',
#   'hr': 92.0,
#   'tamin': 5.3,
#   'ta': 5.6,
#   'tamax': 6.1,
#   'tpr': 4.5,
#   'rviento': 45.0},
#  {'idema': '0385X',
#   'lon': 3.201389,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 1.0,
#   'vmax': 3.5,
#   'vv': 2.1,
#   'dv': 327.0,
#   'lat': 42.053886,
#   'dmax': 315.0,
#   'ubi': 'L?ESTARTIT',
#   'hr': 91.0,
#   'tamin': 8.6,
#   'ta': 9.2,
#   'tamax': 9.2},
#  {'idema': '0394X',
#   'lon': 2.471827,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 350.0,
#   'vmax': 2.6,
#   'vv': 1.6,
#   'dv': 285.0,
#   'lat': 42.210556,
#   'dmax': 265.0,
#   'ubi': 'VALL DE BIANYA',
#   'hr': 99.0,
#   'tamin': 2.2,
#   'ta': 2.3,
#   'tamax': 2.6},
#  {'idema': '0411X',
#   'lon': 3.093053,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 2.0,
#   'vmax': 2.3,
#   'vv': 0.5,
#   'dv': 254.0,
#   'lat': 42.224834,
#   'dmax': 295.0,
#   'ubi': 'CASTELLO D?EMPURIES',
#   'hr': 100.0,
#   'tamin': 5.3,
#   'ta': 5.7,
#   'tamax': 5.7},
#  {'idema': '0413A',
#   'lon': 2.75558,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 355.0,
#   'vmax': 2.2,
#   'vv': 1.0,
#   'dv': 266.0,
#   'lat': 42.386925,
#   'dmax': 307.0,
#   'ubi': 'MAÇANET DE CABRENYS',
#   'hr': 97.0,
#   'tamin': 6.6,
#   'ta': 7.0,
#   'tamax': 7.1},
#  {'idema': '0421X',
#   'lon': 3.006114,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 100.0,
#   'vmax': 4.8,
#   'vv': 1.5,
#   'dv': 6.0,
#   'lat': 42.38988,
#   'dmax': 42.0,
#   'ubi': 'ESPOLLA  LES ALBERES',
#   'hr': 87.0,
#   'tamin': 8.1,
#   'ta': 9.1,
#   'tamax': 9.2},
#  {'idema': '0429X',
#   'lon': 2.960328,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 45.0,
#   'vmax': 2.6,
#   'vv': 0.4,
#   'dv': 64.0,
#   'lat': 42.259083,
#   'dmax': 347.0,
#   'ubi': 'FIGUERES  LES ASPRES',
#   'hr': 93.0,
#   'tamin': 8.0,
#   'ta': 8.5,
#   'tamax': 8.5},
#  {'idema': '0433D',
#   'lon': 3.315831,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 76.0,
#   'vv': 0.8,
#   'dv': 228.0,
#   'lat': 42.31904,
#   'ubi': 'EVC_CABO DE CREUS',
#   'pres': 998.0,
#   'hr': 79.0,
#   'tamin': 13.5,
#   'ta': 14.4,
#   'tamax': 14.4,
#   'tpr': 10.8,
#   'rviento': 43.0},
#  {'idema': '1002Y',
#   'lon': -1.542961,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 183.0,
#   'vmax': 9.9,
#   'vv': 3.6,
#   'dv': 247.0,
#   'lat': 43.135723,
#   'dmax': 295.0,
#   'ubi': 'BAZTÁN  IRURITA',
#   'hr': 53.0,
#   'stdvv': 1.4,
#   'tamin': 16.5,
#   'ta': 16.5,
#   'tamax': 17.1,
#   'tpr': 6.8,
#   'stddv': 33.0},
#  {'idema': '1010X',
#   'lon': -1.675786,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 54.0,
#   'vmax': 7.1,
#   'vv': 1.8,
#   'dv': 198.0,
#   'lat': 43.27869,
#   'dmax': 230.0,
#   'ubi': 'BERA',
#   'hr': 54.0,
#   'tamin': 17.5,
#   'ta': 17.5,
#   'tamax': 17.7},
#  {'idema': '1012P',
#   'lon': -1.796536,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 120.0,
#   'vmax': 13.2,
#   'vv': 3.0,
#   'dv': 250.0,
#   'lat': 43.32641,
#   'dmax': 247.0,
#   'ubi': 'IRUN-LAPIZE',
#   'hr': 54.0,
#   'tamin': 17.0,
#   'ta': 17.0,
#   'tamax': 17.4},
#  {'idema': '1014A',
#   'lon': -1.792116,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 4.0,
#   'vmax': 10.3,
#   'vv': 4.7,
#   'dv': 250.0,
#   'lat': 43.357075,
#   'dmax': 230.0,
#   'ubi': 'SAN SEBASTIÁN/FUENTERRABIA',
#   'pres': 1010.5,
#   'hr': 49.0,
#   'stdvv': 1.1,
#   'ts': 11.8,
#   'pres_nmar': 1011.4,
#   'tamin': 18.3,
#   'ta': 18.4,
#   'tamax': 18.7,
#   'tpr': 7.4,
#   'stddv': 7.0},
#  {'idema': '1021X',
#   'lon': -1.878823,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 165.0,
#   'vmax': 11.2,
#   'vv': 2.4,
#   'dv': 160.0,
#   'lat': 43.213833,
#   'dmax': 217.0,
#   'ubi': 'RENTERIA (PRESA DEL AÑARBE)',
#   'hr': 56.0,
#   'tamin': 16.7,
#   'ta': 16.7,
#   'tamax': 17.1},
#  {'idema': '1025A',
#   'lon': -2.256663,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 255.0,
#   'vmax': 7.7,
#   'vv': 2.6,
#   'dv': 167.0,
#   'lat': 43.015553,
#   'dmax': 172.0,
#   'ubi': 'SEGURA LASTALA',
#   'hr': 62.0,
#   'tamin': 14.8,
#   'ta': 14.8,
#   'tamax': 15.1},
#  {'idema': '1025X',
#   'lon': -2.232037,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 255.0,
#   'vmax': 8.3,
#   'vv': 3.0,
#   'dv': 137.0,
#   'lat': 43.054634,
#   'dmax': 97.0,
#   'ubi': 'ARRIARAN',
#   'hr': 60.0,
#   'tamin': 15.2,
#   'ta': 15.2,
#   'tamax': 15.5},
#  {'idema': '1026X',
#   'lon': -2.184273,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 290.0,
#   'vmax': 7.5,
#   'vv': 3.6,
#   'dv': 259.0,
#   'lat': 43.05816,
#   'dmax': 270.0,
#   'ubi': 'ORDIZIA-ARETA',
#   'hr': 64.0,
#   'tamin': 14.5,
#   'ta': 14.6,
#   'tamax': 15.1},
#  {'idema': '1033X',
#   'lon': -1.950836,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 520.0,
#   'vmax': 8.7,
#   'vv': 3.2,
#   'dv': 225.0,
#   'lat': 43.085,
#   'dmax': 285.0,
#   'ubi': 'ARESO ',
#   'hr': 63.0,
#   'tamin': 13.5,
#   'ta': 13.5,
#   'tamax': 13.9},
#  {'idema': '1037X',
#   'lon': -2.337095,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 460.0,
#   'lat': 43.051796,
#   'ubi': 'LEGAZPIA',
#   'hr': 68.0,
#   'tamin': 12.7,
#   'ta': 12.7,
#   'tamax': 12.9},
#  {'idema': '1037Y',
#   'lon': -2.3175,
#   'fint': '2021-12-28T02:00:00',
#   'alt': 420.0,
#   'vmax': 10.1,
#   'vv': 0.9,
#   'dv': 164.0,
#   'lat': 43.079918,
#   'dmax': 197.0,
#   'ubi': 'ZUMARRAGA-URZABALETA',
#   'pres': 962.5,
#   'hr': 58.0,
#   'pres_nmar': 1011.7,
#   'tamin': 12.0,
#   'ta': 12.2,
#   'tamax': 12.5,
#   'tpr': 4.1,
#   'rviento': 84.0},
#  {'idema': '1038X',
#   'lon': -2.267175,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 180.0,
#   'vmax': 9.2,
#   'vv': 4.2,
#   'dv': 212.0,
#   'lat': 43.172577,
#   'dmax': 182.0,
#   'ubi': 'AZPEITIA-IBAIEDER',
#   'hr': 59.0,
#   'tamin': 15.6,
#   'ta': 15.6,
#   'tamax': 15.8},
#  {'idema': '1041A',
#   'lon': -2.251035,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 28.0,
#   'vmax': 8.0,
#   'vv': 4.0,
#   'dv': 198.0,
#   'lat': 43.30214,
#   'dmax': 192.0,
#   'ubi': 'ZUMAYA FARO',
#   'hr': 55.0,
#   'tamin': 16.8,
#   'ta': 16.8,
#   'tamax': 17.7,
#   'tpr': 7.7,
#   'rviento': 148.0},
#  {'idema': '1044X',
#   'lon': -2.589645,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 617.0,
#   'lat': 43.057835,
#   'ubi': 'ARAMAYONA ECHAGÜEN',
#   'hr': 76.0,
#   'tamin': 10.4,
#   'ta': 10.4,
#   'tamax': 11.1},
#  {'idema': '1048X',
#   'lon': -2.465715,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 308.0,
#   'lat': 43.02505,
#   'ubi': 'ARETXABALETA-EMBALSE URKULU',
#   'hr': 64.0,
#   'tamin': 14.0,
#   'ta': 14.0,
#   'tamax': 14.2},
#  {'idema': '1049N',
#   'lon': -2.495827,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 470.0,
#   'vmax': 6.5,
#   'vv': 1.3,
#   'dv': 57.0,
#   'lat': 43.138332,
#   'dmax': 327.0,
#   'ubi': 'ELGETA',
#   'hr': 65.0,
#   'tamin': 12.9,
#   'ta': 12.9,
#   'tamax': 13.6},
#  {'idema': '1050J',
#   'lon': -2.413218,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 119.0,
#   'vmax': 10.6,
#   'vv': 3.0,
#   'dv': 353.0,
#   'lat': 43.209293,
#   'dmax': 344.0,
#   'ubi': 'ELGOIBAR IBERDROLA',
#   'pres': 997.3,
#   'hr': 53.0,
#   'pres_nmar': 1011.4,
#   'tamin': 15.2,
#   'ta': 15.4,
#   'tamax': 15.8,
#   'tpr': 5.9,
#   'rviento': 171.0},
#  {'idema': '1052A',
#   'lon': -2.397148,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 150.0,
#   'vmax': 9.4,
#   'vv': 5.5,
#   'dv': 253.0,
#   'lat': 43.31722,
#   'dmax': 260.0,
#   'ubi': 'MUTRIKU-GALDONAMENDI',
#   'hr': 50.0,
#   'tamin': 16.8,
#   'ta': 16.8,
#   'tamax': 17.1},
#  {'idema': '1056K',
#   'lon': -2.671184,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 45.0,
#   'vmax': 9.1,
#   'vv': 4.1,
#   'dv': 264.0,
#   'lat': 43.34239,
#   'dmax': 310.0,
#   'ubi': 'FORUA-GAITOKA',
#   'hr': 57.0,
#   'tamin': 16.9,
#   'ta': 16.9,
#   'tamax': 17.1},
#  {'idema': '1057B',
#   'lon': -2.752762,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 93.0,
#   'vmax': 13.2,
#   'vv': 6.8,
#   'dv': 202.0,
#   'lat': 43.453907,
#   'dmax': 220.0,
#   'ubi': 'MACHICHACO FARO',
#   'hr': 52.0,
#   'tamin': 17.1,
#   'ta': 17.2,
#   'tamax': 17.2},
#  {'idema': '1059X',
#   'lon': -3.021602,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 90.0,
#   'vmax': 10.5,
#   'vv': 3.9,
#   'dv': 217.0,
#   'lat': 43.375088,
#   'dmax': 230.0,
#   'ubi': 'PUNTA GALEA ',
#   'hr': 50.0,
#   'rviento': 149.0},
#  {'idema': '1060X',
#   'lon': -3.005452,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 240.0,
#   'vmax': 11.5,
#   'vv': 3.9,
#   'dv': 225.0,
#   'lat': 43.05024,
#   'dmax': 217.0,
#   'ubi': 'AMURRIO (INSTITUTO)',
#   'hr': 60.0,
#   'tamin': 15.1,
#   'ta': 15.1,
#   'tamax': 15.4},
#  {'idema': '1064L',
#   'lon': -2.860274,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 270.0,
#   'vmax': 10.1,
#   'vv': 2.6,
#   'dv': 348.0,
#   'lat': 43.096333,
#   'dmax': 357.0,
#   'ubi': 'OROZCO- IBARRA',
#   'hr': 55.0,
#   'tamin': 15.0,
#   'ta': 15.0,
#   'tamax': 15.2},
#  {'idema': '1069Y',
#   'lon': -2.644187,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 747.0,
#   'lat': 43.09923,
#   'ubi': 'URKIOLA (SANTUARIO)',
#   'hr': 74.0,
#   'tamin': 9.9,
#   'ta': 9.9,
#   'tamax': 10.5},
#  {'idema': '1074C',
#   'lon': -2.706153,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 100.0,
#   'vmax': 15.1,
#   'vv': 6.5,
#   'dv': 219.0,
#   'lat': 43.202892,
#   'dmax': 192.0,
#   'ubi': 'AMOREBIETA-SAN MIGUEL DUDEA',
#   'hr': 56.0,
#   'tamin': 16.8,
#   'ta': 16.9,
#   'tamax': 16.9},
#  {'idema': '1078C',
#   'lon': -3.209649,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 210.0,
#   'lat': 43.180576,
#   'ubi': 'BALMASEDA-SALINILLAS',
#   'hr': 63.0,
#   'tamin': 14.6,
#   'ta': 14.7,
#   'tamax': 14.8},
#  {'idema': '1078I',
#   'lon': -3.104777,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 208.0,
#   'vmax': 14.7,
#   'vv': 5.5,
#   'dv': 224.0,
#   'lat': 43.203384,
#   'dmax': 225.0,
#   'ubi': 'GÜEÑES',
#   'pres': 987.4,
#   'hr': 45.0,
#   'pres_nmar': 1011.9,
#   'tamin': 14.7,
#   'ta': 15.1,
#   'tamax': 15.1,
#   'tpr': 3.2,
#   'rviento': 213.0},
#  {'idema': '1082',
#   'lon': -2.906304,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 42.0,
#   'vmax': 17.0,
#   'vv': 8.4,
#   'dv': 220.0,
#   'lat': 43.29795,
#   'dmax': 220.0,
#   'ubi': 'BILBAO/AEROPUERTO',
#   'pres': 1006.8,
#   'hr': 50.0,
#   'stdvv': 1.5,
#   'ts': 15.5,
#   'pres_nmar': 1011.4,
#   'tamin': 17.6,
#   'ta': 17.7,
#   'tamax': 17.8,
#   'tpr': 7.1,
#   'stddv': 4.0,
#   'inso': 0.0},
#  {'idema': '1083B',
#   'lon': -3.168615,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 177.0,
#   'vmax': 9.3,
#   'vv': 5.3,
#   'dv': 250.0,
#   'lat': 43.27972,
#   'dmax': 237.0,
#   'ubi': 'SOPUERTA-JARRALTA',
#   'hr': 60.0,
#   'tamin': 16.0,
#   'ta': 16.0,
#   'tamax': 16.1},
#  {'idema': '1083L',
#   'lon': -3.233884,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 45.0,
#   'vmax': 9.8,
#   'vv': 5.5,
#   'dv': 193.0,
#   'lat': 43.39473,
#   'dmax': 185.0,
#   'ubi': 'CASTRO URDIALES-EDAR',
#   'hr': 59.0,
#   'tamin': 16.8,
#   'ta': 17.4,
#   'tamax': 17.5,
#   'tpr': 9.3,
#   'rviento': 167.0},
#  {'idema': '1089U',
#   'lon': -3.47083,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 80.0,
#   'vmax': 8.7,
#   'vv': 1.4,
#   'dv': 305.0,
#   'lat': 43.255833,
#   'dmax': 162.0,
#   'ubi': 'RAMALES DE LA VICTORIA-ETAP',
#   'hr': 54.0,
#   'tamin': 17.4,
#   'ta': 17.4,
#   'tamax': 17.6},
#  {'idema': '1096X',
#   'lon': -3.469721,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 10.0,
#   'vmax': 2.1,
#   'vv': 0.5,
#   'dv': 116.0,
#   'lat': 43.39667,
#   'dmax': 142.0,
#   'ubi': 'TRETO',
#   'hr': 59.0,
#   'tamin': 15.8,
#   'ta': 15.8,
#   'tamax': 16.5},
#  {'idema': '1102D',
#   'lon': -3.685906,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 700.0,
#   'vmax': 8.8,
#   'vv': 3.7,
#   'dv': 167.0,
#   'lat': 43.19065,
#   'dmax': 185.0,
#   'ubi': 'SOBA-ALTO MIERA',
#   'hr': 65.0,
#   'tamin': 12.4,
#   'ta': 12.4,
#   'tamax': 12.7},
#  {'idema': '1109X',
#   'lon': -3.831385,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 3.0,
#   'vmax': 10.8,
#   'vv': 5.5,
#   'dv': 180.0,
#   'lat': 43.42861,
#   'dmax': 160.0,
#   'ubi': 'SANTANDER AEROPUERTO',
#   'pres': 1010.0,
#   'hr': 55.0,
#   'stdvv': 0.5,
#   'ts': 12.9,
#   'pres_nmar': 1010.7,
#   'tamin': 17.1,
#   'ta': 17.2,
#   'tamax': 17.3,
#   'tpr': 8.1,
#   'stddv': 2.0,
#   'inso': 0.0},
#  {'idema': '1111X',
#   'lon': -3.800431,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 52.0,
#   'vmax': 11.6,
#   'vv': 7.1,
#   'dv': 195.0,
#   'lat': 43.491055,
#   'dmax': 188.0,
#   'ubi': 'SANTANDER CMT',
#   'pres': 1003.0,
#   'hr': 55.0,
#   'stdvv': 1.2,
#   'ts': 16.4,
#   'pres_nmar': 1009.9,
#   'tamin': 16.9,
#   'ta': 17.0,
#   'tamax': 17.0,
#   'tpr': 7.8,
#   'vis': 18.4,
#   'stddv': 9.0,
#   'inso': 0.0,
#   'tss5cm': 12.1,
#   'vmaxu': 11.5,
#   'dvu': 191.0,
#   'pacutp': 0.0,
#   'vvu': 7.1,
#   'stdvvu': 1.6,
#   'stddvu': 9.0,
#   'dmaxu': 191.0,
#   'tss20cm': 12.0},
#  {'idema': '1124E',
#   'lon': -3.849351,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 195.7,
#   'vmax': 10.7,
#   'vv': 6.8,
#   'dv': 200.0,
#   'lat': 43.2456,
#   'dmax': 220.0,
#   'ubi': 'VILLACARRIEDO - SANTIBAÑEZ',
#   'hr': 59.0,
#   'tamin': 15.5,
#   'ta': 15.6,
#   'tamax': 15.8},
#  {'idema': '1135C',
#   'lon': -4.214141,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 460.0,
#   'vmax': 1.7,
#   'vv': 0.1,
#   'dv': 203.0,
#   'lat': 43.146942,
#   'dmax': 292.0,
#   'ubi': 'BÁRCENA MAYOR-TORIZ',
#   'hr': 84.0,
#   'tamin': 9.3,
#   'ta': 9.3,
#   'tamax': 11.0},
#  {'idema': '1152C',
#   'lon': -4.048612,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 105.0,
#   'vmax': 8.9,
#   'vv': 4.7,
#   'dv': 225.0,
#   'lat': 43.271942,
#   'dmax': 227.0,
#   'ubi': 'SAN FELICES DE BUELNA-TARRIBA',
#   'hr': 55.0,
#   'tamin': 16.7,
#   'ta': 16.9,
#   'tamax': 16.9},
#  {'idema': '1154H',
#   'lon': -4.027419,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 110.0,
#   'vmax': 9.2,
#   'vv': 3.2,
#   'dv': 248.0,
#   'lat': 43.358517,
#   'dmax': 227.0,
#   'ubi': 'TORRELAVEGA-SIERRAPANDO',
#   'hr': 56.0,
#   'tamin': 16.6,
#   'ta': 16.6,
#   'tamax': 17.3},
#  {'idema': '1159',
#   'lon': -4.392103,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 38.0,
#   'vmax': 5.4,
#   'vv': 1.2,
#   'dv': 203.0,
#   'lat': 43.393456,
#   'dmax': 200.0,
#   'ubi': 'SAN VICENTE  FARO',
#   'pres': 1004.6,
#   'hr': 53.0,
#   'pres_nmar': 1009.2,
#   'tamin': 15.2,
#   'ta': 16.7,
#   'tamax': 16.8,
#   'tpr': 7.1,
#   'rviento': 49.0},
#  {'idema': '1167B',
#   'lon': -4.812779,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 1100.0,
#   'vmax': 7.9,
#   'vv': 2.0,
#   'dv': 221.0,
#   'lat': 43.143894,
#   'dmax': 227.0,
#   'ubi': 'FUENTE DÉ-TELEFÉRICO',
#   'hr': 73.0,
#   'tamin': 8.8,
#   'ta': 9.1,
#   'tamax': 9.1},
#  {'idema': '1174I',
#   'lon': -4.601783,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 250.0,
#   'vmax': 4.7,
#   'vv': 1.8,
#   'dv': 195.0,
#   'lat': 43.18286,
#   'dmax': 165.0,
#   'ubi': 'TAMA',
#   'hr': 57.0,
#   'tamin': 14.5,
#   'ta': 14.5,
#   'tamax': 16.2},
#  {'idema': '1176A',
#   'lon': -4.668234,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 940.0,
#   'vmax': 5.6,
#   'vv': 1.7,
#   'dv': 24.0,
#   'lat': 43.255714,
#   'dmax': 27.0,
#   'ubi': 'TRESVISO',
#   'hr': 66.0,
#   'tamin': 10.0,
#   'ta': 10.1,
#   'tamax': 10.4},
#  {'idema': '1178Y',
#   'lon': -4.931762,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 953.0,
#   'lat': 43.145374,
#   'ubi': 'SOTO DE VALDEÓN (AUTOMATICA)',
#   'hr': 95.0,
#   'tamin': 4.3,
#   'ta': 4.3,
#   'tamax': 5.1},
#  {'idema': '1179B',
#   'lon': -4.852774,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 458.0,
#   'vmax': 6.7,
#   'vv': 3.3,
#   'dv': 58.0,
#   'lat': 43.31111,
#   'dmax': 90.0,
#   'ubi': 'CARREÑA DE CABRALES',
#   'hr': 55.0,
#   'tamin': 15.6,
#   'ta': 15.6,
#   'tamax': 16.2},
#  {'idema': '1183X',
#   'lon': -4.748056,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 10.0,
#   'vmax': 4.2,
#   'vv': 2.1,
#   'dv': 244.0,
#   'lat': 43.420277,
#   'dmax': 217.0,
#   'ubi': 'LLANES',
#   'pres': 1008.2,
#   'hr': 62.0,
#   'ts': 11.0,
#   'pres_nmar': 1009.4,
#   'tamin': 13.5,
#   'ta': 14.1,
#   'tamax': 14.2,
#   'tpr': 7.0,
#   'vis': 20.0,
#   'inso': 0.0,
#   'tss5cm': 11.1,
#   'psoltp': 0.0,
#   'pliqt': 0.0},
#  {'idema': '1186P',
#   'lon': -5.119247,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 370.0,
#   'vmax': 18.8,
#   'vv': 7.4,
#   'dv': 130.0,
#   'lat': 43.266632,
#   'dmax': 175.0,
#   'ubi': 'AMIEVA  PANIZALES',
#   'hr': 55.0,
#   'tamin': 15.6,
#   'ta': 16.0,
#   'tamax': 16.0},
#  {'idema': '1199X',
#   'lon': -5.396674,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 280.0,
#   'vmax': 1.6,
#   'vv': 0.6,
#   'dv': 341.0,
#   'lat': 43.377834,
#   'dmax': 300.0,
#   'ubi': 'BARGAÉU PILOÑA',
#   'hr': 61.0,
#   'tamin': 14.3,
#   'ta': 15.3,
#   'tamax': 15.3},
#  {'idema': '1203D',
#   'lon': -5.247153,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 30.0,
#   'vmax': 2.6,
#   'vv': 0.1,
#   'dv': 245.0,
#   'lat': 43.49235,
#   'dmax': 287.0,
#   'ubi': 'COLUNGA',
#   'hr': 74.0,
#   'tamin': 13.2,
#   'ta': 13.2,
#   'tamax': 16.0},
#  {'idema': '1207U',
#   'lon': -5.621111,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 26.0,
#   'vmax': 3.6,
#   'vv': 1.1,
#   'dv': 223.0,
#   'lat': 43.523056,
#   'dmax': 205.0,
#   'ubi': 'GIJÓN-CAMPUS',
#   'pres': 1006.4,
#   'hr': 57.0,
#   'stdvv': 0.5,
#   'ts': 11.9,
#   'pres_nmar': 1010.2,
#   'tamin': 16.9,
#   'ta': 16.9,
#   'tamax': 18.0,
#   'tpr': 8.4,
#   'vis': 17.9,
#   'stddv': 35.0,
#   'inso': 0.0,
#   'tss5cm': 12.2,
#   'pacutp': 0.0,
#   'tss20cm': 12.1},
#  {'idema': '1208H',
#   'lon': -5.700833,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 5.0,
#   'vmax': 7.5,
#   'vv': 3.2,
#   'dv': 220.0,
#   'lat': 43.559723,
#   'dmax': 225.0,
#   'ubi': 'GIJÓN  MUSEL',
#   'pres': 1009.1,
#   'hr': 52.0,
#   'tamin': 19.0,
#   'ta': 19.0,
#   'tamax': 19.5,
#   'rviento': 124.0},
#  {'idema': '1210X',
#   'lon': -5.848572,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 100.0,
#   'vmax': 10.8,
#   'vv': 7.7,
#   'dv': 265.0,
#   'lat': 43.655926,
#   'dmax': 258.0,
#   'ubi': 'CABO PEÑAS',
#   'hr': 67.0,
#   'tamin': 16.1,
#   'ta': 17.4,
#   'tamax': 17.5,
#   'tpr': 11.2,
#   'rviento': 231.0},
#  {'idema': '1212E',
#   'lon': -6.044173,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 127.0,
#   'vmax': 13.9,
#   'vv': 8.6,
#   'dv': 250.0,
#   'lat': 43.56694,
#   'dmax': 220.0,
#   'ubi': 'ASTURIAS/AVILÉS',
#   'pres': 994.9,
#   'hr': 58.0,
#   'stdvv': 0.7,
#   'ts': 14.1,
#   'pres_nmar': 1024.1,
#   'tamin': 17.9,
#   'ta': 18.2,
#   'tamax': 18.4,
#   'tpr': 9.8,
#   'stddv': 4.0,
#   'inso': 0.0},
#  {'idema': '1221D',
#   'lon': -5.776392,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 1480.0,
#   'vmax': 8.1,
#   'vv': 3.5,
#   'dv': 188.0,
#   'lat': 42.978607,
#   'dmax': 204.0,
#   'ubi': 'PAJARES - VALGRANDE',
#   'hr': 76.0,
#   'tamin': 5.8,
#   'ta': 5.8,
#   'tamax': 6.8,
#   'tpr': 1.9,
#   'rviento': 136.0},
#  {'idema': '1223P',
#   'lon': -5.822748,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 370.0,
#   'vmax': 8.3,
#   'vv': 3.5,
#   'dv': 201.0,
#   'lat': 43.132706,
#   'dmax': 162.0,
#   'ubi': 'RONZÓN',
#   'hr': 58.0,
#   'tamin': 16.5,
#   'ta': 16.7,
#   'tamax': 16.8},
#  {'idema': '1226X',
#   'lon': -5.476919,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 750.0,
#   'vmax': 3.0,
#   'vv': 1.2,
#   'dv': 125.0,
#   'lat': 43.095177,
#   'dmax': 152.0,
#   'ubi': 'CUEVAS DE FELECHOSA',
#   'hr': 76.0,
#   'tamin': 9.7,
#   'ta': 9.7,
#   'tamax': 12.3},
#  {'idema': '1234P',
#   'lon': -5.819274,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 170.0,
#   'vmax': 8.1,
#   'vv': 2.6,
#   'dv': 122.0,
#   'lat': 43.274883,
#   'dmax': 112.0,
#   'ubi': 'MIERES-BAÍÑA',
#   'hr': 51.0,
#   'tamin': 18.4,
#   'ta': 18.8,
#   'tamax': 18.8},
#  {'idema': '1249X',
#   'lon': -5.873889,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 336.0,
#   'vmax': 3.5,
#   'vv': 2.1,
#   'dv': 306.0,
#   'lat': 43.353333,
#   'dmax': 320.0,
#   'ubi': 'OVIEDO',
#   'pres': 970.8,
#   'hr': 59.0,
#   'stdvv': 0.6,
#   'ts': 14.6,
#   'pres_nmar': 1010.1,
#   'tamin': 16.1,
#   'ta': 16.5,
#   'tamax': 16.6,
#   'tpr': 8.5,
#   'vis': 20.0,
#   'stddv': 18.0,
#   'inso': 0.0,
#   'tss5cm': 9.4,
#   'pacutp': 0.0,
#   'tss20cm': 9.4},
#  {'idema': '1272B',
#   'lon': -6.386539,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 280.0,
#   'vmax': 11.0,
#   'vv': 2.1,
#   'dv': 117.0,
#   'lat': 43.290276,
#   'dmax': 192.0,
#   'ubi': 'SOUTU  LA BARCA',
#   'hr': 66.0,
#   'tamin': 16.7,
#   'ta': 16.7,
#   'tamax': 17.0},
#  {'idema': '1276F',
#   'lon': -6.256944,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 670.0,
#   'vmax': 6.8,
#   'vv': 3.1,
#   'dv': 218.0,
#   'lat': 43.1,
#   'dmax': 222.0,
#   'ubi': 'POLA DE SOMIEDO-DEPURADORA',
#   'hr': 65.0,
#   'tamin': 14.7,
#   'ta': 14.8,
#   'tamax': 14.9},
#  {'idema': '1279X',
#   'lon': -6.230729,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 240.0,
#   'vmax': 13.5,
#   'vv': 6.5,
#   'dv': 216.0,
#   'lat': 43.425,
#   'dmax': 205.0,
#   'ubi': 'CAMUÑO',
#   'hr': 66.0,
#   'tamin': 16.9,
#   'ta': 16.9,
#   'tamax': 17.0},
#  {'idema': '1283U',
#   'lon': -6.469998,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 60.0,
#   'vmax': 22.3,
#   'vv': 15.2,
#   'dv': 256.0,
#   'lat': 43.569164,
#   'dmax': 254.0,
#   'ubi': 'CABO BUSTO',
#   'pres': 1001.7,
#   'hr': 60.0,
#   'ts': 15.9,
#   'pres_nmar': 1008.7,
#   'tamin': 17.6,
#   'ta': 17.9,
#   'tamax': 17.9,
#   'tpr': 10.0,
#   'vis': 20.0,
#   'inso': 0.0,
#   'tss5cm': 12.1,
#   'psoltp': 0.0},
#  {'idema': '1297E',
#   'lon': -7.017618,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.2,
#   'alt': 1020.0,
#   'vmax': 6.6,
#   'vv': 1.9,
#   'dv': 144.0,
#   'lat': 42.768578,
#   'dmax': 185.0,
#   'ubi': 'CERVANTES-BAZAL',
#   'hr': 87.0,
#   'tamin': 8.4,
#   'ta': 8.6,
#   'tamax': 8.6},
#  {'idema': '1302F',
#   'lon': -6.472407,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 1.0,
#   'alt': 1310.0,
#   'vmax': 3.7,
#   'vv': 0.5,
#   'dv': 330.0,
#   'lat': 42.95527,
#   'dmax': 320.0,
#   'ubi': 'DEGAÑA  COTO CORTÉS',
#   'hr': 97.0,
#   'tamin': 6.9,
#   'ta': 6.9,
#   'tamax': 7.0},
#  {'idema': '1309C',
#   'lon': -6.884876,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.2,
#   'alt': 780.0,
#   'vmax': 15.8,
#   'vv': 9.5,
#   'dv': 222.0,
#   'lat': 43.027412,
#   'dmax': 217.0,
#   'ubi': 'SAN ANTOLIN DE IBIAS-LINARES',
#   'hr': 94.0,
#   'tamin': 10.6,
#   'ta': 10.9,
#   'tamax': 10.9},
#  {'idema': '1327A',
#   'lon': -6.673332,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 410.0,
#   'vmax': 18.4,
#   'vv': 5.0,
#   'dv': 287.0,
#   'lat': 43.465553,
#   'dmax': 210.0,
#   'ubi': 'ONETA',
#   'hr': 81.0,
#   'tamin': 13.7,
#   'ta': 13.8,
#   'tamax': 13.8},
#  {'idema': '1331A',
#   'lon': -7.031388,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 40.0,
#   'vmax': 15.7,
#   'vv': 6.6,
#   'dv': 222.0,
#   'lat': 43.524723,
#   'dmax': 193.0,
#   'ubi': 'CASTROPOL',
#   'hr': 75.0,
#   'tamin': 15.5,
#   'ta': 15.5,
#   'tamax': 15.7,
#   'tpr': 11.1,
#   'rviento': 235.0},
#  {'idema': '1341B',
#   'lon': -7.06098,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 340.0,
#   'vmax': 23.5,
#   'vv': 12.4,
#   'dv': 190.0,
#   'lat': 43.415546,
#   'dmax': 182.0,
#   'ubi': 'OURIA DE TARAMUNDI',
#   'hr': 84.0,
#   'tamin': 14.7,
#   'ta': 14.8,
#   'tamax': 14.9},
#  {'idema': '1342X',
#   'lon': -7.082971,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 43.0,
#   'vmax': 14.9,
#   'vv': 7.1,
#   'dv': 206.0,
#   'lat': 43.540653,
#   'dmax': 182.0,
#   'ubi': 'RIBADEO  VILAFRAMIL',
#   'hr': 81.0,
#   'tamin': 15.8,
#   'ta': 15.8,
#   'tamax': 15.9},
#  {'idema': '1344X',
#   'lon': -7.361736,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.2,
#   'alt': 125.0,
#   'lat': 43.43133,
#   'ubi': 'MONDOÑEDO',
#   'hr': 91.0,
#   'tamin': 14.1,
#   'ta': 14.1,
#   'tamax': 14.2},
#  {'idema': '1347T',
#   'lon': -7.357091,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 80.0,
#   'lat': 43.651047,
#   'ubi': 'BURELA',
#   'hr': 75.0,
#   'tamin': 17.2,
#   'ta': 17.4,
#   'tamax': 17.4},
#  {'idema': '1351',
#   'lon': -7.684722,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 80.0,
#   'vmax': 21.8,
#   'vv': 16.2,
#   'dv': 256.0,
#   'lat': 43.78611,
#   'dmax': 256.0,
#   'ubi': 'ESTACA DE BARES',
#   'pres': 998.6,
#   'hr': 94.0,
#   'ts': 15.3,
#   'tamin': 14.4,
#   'ta': 14.5,
#   'tamax': 14.6,
#   'inso': 0.0,
#   'tss5cm': 12.6,
#   'psoltp': 0.0,
#   'pliqt': 0.0},
#  {'idema': '1354C',
#   'lon': -8.262222,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 4.0,
#   'vmax': 13.1,
#   'vv': 8.1,
#   'dv': 220.0,
#   'lat': 43.47639,
#   'dmax': 224.0,
#   'ubi': 'FERROL-LA GRAÑA',
#   'pres': 1011.6,
#   'hr': 87.0,
#   'pres_nmar': 1012.1,
#   'tamin': 15.6,
#   'ta': 15.6,
#   'tamax': 16.1,
#   'tpr': 13.5,
#   'rviento': 277.0},
#  {'idema': '1363X',
#   'lon': -7.861476,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 343.0,
#   'lat': 43.44597,
#   'ubi': 'AS PONTES A AEROSA',
#   'hr': 92.0,
#   'tamin': 13.9,
#   'ta': 13.9,
#   'tamax': 14.1},
#  {'idema': '1387',
#   'lon': -8.421517,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 58.0,
#   'vmax': 11.6,
#   'vv': 5.3,
#   'dv': 222.0,
#   'lat': 43.36597,
#   'dmax': 230.0,
#   'ubi': 'A CORUÑA',
#   'pres': 1005.2,
#   'hr': 89.0,
#   'stdvv': 1.6,
#   'ts': 15.6,
#   'pres_nmar': 1013.0,
#   'tamin': 16.1,
#   'ta': 16.1,
#   'tamax': 16.4,
#   'tpr': 14.2,
#   'vis': 17.7,
#   'stddv': 23.0,
#   'inso': 0.0,
#   'tss5cm': 13.6,
#   'pacutp': 0.05,
#   'tss20cm': 13.4},
#  {'idema': '1387D',
#   'lon': -8.4418,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 132.0,
#   'vmax': 10.7,
#   'vv': 7.2,
#   'dv': 225.0,
#   'lat': 43.363308,
#   'dmax': 233.0,
#   'ubi': 'BENS-A CORUÑA',
#   'pres': 997.0,
#   'hr': 91.0,
#   'stdvv': 0.9,
#   'pres_nmar': 1028.4,
#   'tamin': 15.2,
#   'ta': 15.3,
#   'tamax': 15.7,
#   'tpr': 13.9,
#   'stddv': 2.7},
#  {'idema': '1387E',
#   'lon': -8.371975,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 98.0,
#   'vmax': 9.3,
#   'vv': 4.1,
#   'dv': 190.0,
#   'lat': 43.306953,
#   'dmax': 220.0,
#   'ubi': 'A CORUÑA/ALVEDRO',
#   'pres': 1000.7,
#   'hr': 88.0,
#   'stdvv': 0.3,
#   'ts': 14.9,
#   'pres_nmar': 1012.9,
#   'tamin': 15.4,
#   'ta': 15.4,
#   'tamax': 16.2,
#   'tpr': 13.5,
#   'vis': 10.8,
#   'stddv': 3.0,
#   'inso': 0.0},
#  {'idema': '1390X',
#   'lon': -8.711001,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.2,
#   'alt': 98.0,
#   'lat': 43.203583,
#   'ubi': 'CARBALLO',
#   'hr': 96.0,
#   'tamin': 15.1,
#   'ta': 15.2,
#   'tamax': 15.2},
#  {'idema': '1393',
#   'lon': -9.210829,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 50.0,
#   'vmax': 16.8,
#   'vv': 12.4,
#   'dv': 211.0,
#   'lat': 43.160557,
#   'dmax': 221.0,
#   'ubi': 'CABO VILAN',
#   'hr': 89.0,
#   'tamin': 13.9,
#   'ta': 14.1,
#   'tamax': 14.2,
#   'tpr': 12.3,
#   'rviento': 449.0},
#  {'idema': '1399',
#   'lon': -9.046929,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 1.0,
#   'alt': 287.0,
#   'lat': 43.057446,
#   'ubi': 'VIMIANZO-CASTRELO',
#   'hr': 100.0,
#   'tamin': 13.5,
#   'ta': 13.8,
#   'tamax': 13.8},
#  {'idema': '1400',
#   'lon': -9.291434,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.2,
#   'alt': 230.0,
#   'vmax': 18.2,
#   'vv': 14.4,
#   'dv': 228.0,
#   'lat': 42.924828,
#   'dmax': 229.0,
#   'ubi': 'FISTERRA',
#   'pres': 986.4,
#   'hr': 99.0,
#   'ts': 13.4,
#   'pres_nmar': 1013.5,
#   'tamin': 13.6,
#   'ta': 13.8,
#   'tamax': 13.8,
#   'tpr': 13.7,
#   'vis': 0.4,
#   'inso': 0.0,
#   'tss5cm': 12.6,
#   'psoltp': 0.0,
#   'pliqt': 0.0},
#  {'idema': '1406X',
#   'lon': -8.99369,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 2.0,
#   'alt': 340.0,
#   'lat': 42.93525,
#   'ubi': 'MAZARICOS-A PICOTA',
#   'hr': 100.0,
#   'tamin': 13.1,
#   'ta': 13.2,
#   'tamax': 13.2},
#  {'idema': '1410X',
#   'lon': -8.022249,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.4,
#   'alt': 500.0,
#   'lat': 43.037876,
#   'ubi': 'SOBRADO DOS MONXES',
#   'hr': 100.0,
#   'tamin': 12.2,
#   'ta': 12.5,
#   'tamax': 12.5},
#  {'idema': '1428',
#   'lon': -8.410515,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.8,
#   'alt': 370.0,
#   'vmax': 15.4,
#   'vv': 6.7,
#   'dv': 230.0,
#   'lat': 42.888012,
#   'dmax': 210.0,
#   'ubi': 'SANTIAGO DE COMPOSTELA/LABACOLLA',
#   'pres': 971.5,
#   'hr': 99.0,
#   'stdvv': 1.1,
#   'ts': 13.6,
#   'pres_nmar': 1014.5,
#   'tamin': 13.2,
#   'ta': 13.4,
#   'tamax': 13.4,
#   'tpr': 13.3,
#   'vis': 3.1,
#   'stddv': 5.0,
#   'inso': 0.0,
#   'tss5cm': 11.8,
#   'tss20cm': 10.3},
#  {'idema': '1435C',
#   'lon': -8.876227,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 128.0,
#   'vmax': 10.9,
#   'vv': 2.2,
#   'dv': 288.0,
#   'lat': 42.80014,
#   'dmax': 230.0,
#   'ubi': 'NOIA',
#   'hr': 100.0,
#   'tamin': 15.0,
#   'ta': 15.1,
#   'tamax': 15.1},
#  {'idema': '1437P',
#   'lon': -8.923611,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.4,
#   'alt': 685.0,
#   'vv': 17.1,
#   'dv': 275.0,
#   'lat': 42.720554,
#   'ubi': 'EVC_NOIA',
#   'pres': 936.0,
#   'hr': 99.0,
#   'tamin': 11.8,
#   'ta': 12.1,
#   'tamax': 12.1,
#   'tpr': 12.0,
#   'rviento': 596.0},
#  {'idema': '1442U',
#   'lon': -8.892333,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.2,
#   'alt': 10.0,
#   'lat': 42.643887,
#   'ubi': 'BOIRO',
#   'hr': 93.0,
#   'tamin': 14.8,
#   'ta': 15.2,
#   'tamax': 15.2},
#  {'idema': '1446X',
#   'lon': -7.768333,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 680.0,
#   'lat': 42.809723,
#   'ubi': 'MONTERROSO',
#   'hr': 99.0,
#   'tamin': 10.9,
#   'ta': 11.0,
#   'tamax': 11.0},
#  {'idema': '1466A',
#   'lon': -8.257892,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.6,
#   'alt': 435.0,
#   'vmax': 7.0,
#   'vv': 2.5,
#   'dv': 260.0,
#   'lat': 42.700886,
#   'dmax': 255.0,
#   'ubi': 'SILLEDA',
#   'hr': 100.0,
#   'tamin': 12.4,
#   'ta': 12.5,
#   'tamax': 12.5},
#  {'idema': '1468X',
#   'lon': -8.501806,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 269.0,
#   'lat': 42.69361,
#   'ubi': 'A ESTRADA',
#   'hr': 100.0,
#   'tamin': 13.8,
#   'ta': 13.9,
#   'tamax': 13.9},
#  {'idema': '1473A',
#   'lon': -8.627222,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.7,
#   'alt': 100.0,
#   'vmax': 10.1,
#   'vv': 3.4,
#   'dv': 275.0,
#   'lat': 42.738335,
#   'dmax': 260.0,
#   'ubi': 'PADRÓN',
#   'hr': 93.0,
#   'tamin': 14.0,
#   'ta': 14.2,
#   'tamax': 14.2,
#   'tpr': 13.1,
#   'rviento': 138.0},
#  {'idema': '1475X',
#   'lon': -8.555833,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 1.1,
#   'alt': 240.0,
#   'vmax': 9.1,
#   'vv': 2.8,
#   'dv': 222.0,
#   'lat': 42.87611,
#   'dmax': 224.0,
#   'ubi': 'SANTIAGO DE COMPOSTELA',
#   'hr': 96.0,
#   'tamin': 13.7,
#   'ta': 13.9,
#   'tamax': 13.9,
#   'tpr': 13.3,
#   'rviento': 117.0},
#  {'idema': '1476R',
#   'lon': -8.714807,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 5.8,
#   'alt': 210.0,
#   'lat': 42.749836,
#   'ubi': 'CASAS DO PORTO',
#   'hr': 100.0,
#   'tamin': 13.5,
#   'ta': 13.7,
#   'tamax': 13.7},
#  {'idema': '1477V',
#   'lon': -8.774642,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 32.0,
#   'vmax': 10.9,
#   'vv': 5.6,
#   'dv': 230.0,
#   'lat': 42.584843,
#   'dmax': 222.0,
#   'ubi': 'VILAGARCIA DE AROUSA',
#   'hr': 97.0,
#   'tamin': 14.9,
#   'ta': 14.9,
#   'tamax': 15.2},
#  {'idema': '1484C',
#   'lon': -8.615833,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.8,
#   'alt': 108.0,
#   'vmax': 10.0,
#   'vv': 2.8,
#   'dv': 185.0,
#   'lat': 42.43833,
#   'dmax': 183.0,
#   'ubi': 'PONTEVEDRA',
#   'pres': 1001.7,
#   'hr': 97.0,
#   'stdvv': 1.2,
#   'ts': 14.5,
#   'pres_nmar': 1015.1,
#   'tamin': 14.6,
#   'ta': 14.8,
#   'tamax': 14.8,
#   'tpr': 14.3,
#   'vis': 3.7,
#   'stddv': 36.0,
#   'inso': 0.0,
#   'tss5cm': 13.6,
#   'pacutp': 0.98,
#   'tss20cm': 13.1},
#  {'idema': '1489A',
#   'lon': -8.451243,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 4.4,
#   'alt': 395.0,
#   'vmax': 8.9,
#   'vv': 3.8,
#   'dv': 241.0,
#   'lat': 42.40705,
#   'dmax': 237.0,
#   'ubi': 'A LAMA',
#   'hr': 96.0,
#   'tamin': 12.6,
#   'ta': 12.9,
#   'tamax': 12.9},
#  {'idema': '1495',
#   'lon': -8.623765,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.6,
#   'alt': 261.0,
#   'vmax': 12.9,
#   'vv': 6.5,
#   'dv': 190.0,
#   'lat': 42.238617,
#   'dmax': 190.0,
#   'ubi': 'VIGO/PEINADOR',
#   'pres': 986.1,
#   'hr': 95.0,
#   'stdvv': 0.7,
#   'ts': 14.0,
#   'pres_nmar': 1016.5,
#   'tamin': 13.5,
#   'ta': 14.2,
#   'tamax': 14.2,
#   'tpr': 13.5,
#   'stddv': 4.0,
#   'inso': 0.0},
#  {'idema': '1496X',
#   'lon': -8.724167,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 120.0,
#   'vmax': 9.2,
#   'vv': 3.2,
#   'dv': 220.0,
#   'lat': 42.230556,
#   'dmax': 217.0,
#   'ubi': 'VIGO-O CASTRO',
#   'hr': 95.0,
#   'tamin': 15.0,
#   'ta': 15.1,
#   'tamax': 15.1},
#  {'idema': '1505',
#   'lon': -7.457222,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.2,
#   'alt': 445.0,
#   'vmax': 8.7,
#   'vv': 3.6,
#   'dv': 216.0,
#   'lat': 43.11139,
#   'dmax': 208.0,
#   'ubi': 'LUGO/ROZAS',
#   'pres': 962.0,
#   'hr': 96.0,
#   'stdvv': 1.0,
#   'ts': 11.6,
#   'pres_nmar': 1014.3,
#   'tamin': 11.7,
#   'ta': 11.8,
#   'tamax': 11.8,
#   'tpr': 11.2,
#   'vis': 2.3,
#   'stddv': 15.0,
#   'inso': 0.0,
#   'tss5cm': 10.4,
#   'pacutp': 0.48,
#   'tss20cm': 10.2},
#  {'idema': '1518A',
#   'lon': -7.5525,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.6,
#   'alt': 442.0,
#   'vmax': 4.7,
#   'vv': 1.1,
#   'dv': 189.0,
#   'lat': 42.998333,
#   'dmax': 160.0,
#   'ubi': 'LUGO-COL.FINGOI',
#   'hr': 96.0,
#   'tamin': 11.6,
#   'ta': 11.7,
#   'tamax': 11.7},
#  {'idema': '1521I',
#   'lon': -7.499579,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 403.0,
#   'lat': 42.845276,
#   'ubi': 'O PARAMO',
#   'hr': 85.0,
#   'tamin': 13.6,
#   'ta': 13.7,
#   'tamax': 13.8},
#  {'idema': '1521X',
#   'lon': -7.18517,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 1080.0,
#   'vmax': 11.7,
#   'vv': 4.3,
#   'dv': 194.0,
#   'lat': 42.86377,
#   'dmax': 220.0,
#   'ubi': 'BECERREA-PENAMAIOR',
#   'hr': 100.0,
#   'tamin': 8.4,
#   'ta': 8.6,
#   'tamax': 8.6},
#  {'idema': '1535I',
#   'lon': -7.704599,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 552.0,
#   'vv': 7.1,
#   'dv': 226.0,
#   'lat': 42.63472,
#   'ubi': 'EVC_O SAVIÑAO',
#   'pres': 951.0,
#   'hr': 99.0,
#   'tamin': 11.5,
#   'ta': 11.6,
#   'tamax': 11.6,
#   'tpr': 11.4,
#   'rviento': 235.0},
#  {'idema': '1541B',
#   'lon': -6.333886,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.2,
#   'alt': 958.0,
#   'vmax': 11.9,
#   'vv': 7.3,
#   'dv': 202.0,
#   'lat': 42.928886,
#   'dmax': 202.0,
#   'ubi': 'VILLABLINO',
#   'hr': 93.0,
#   'tamin': 8.6,
#   'ta': 8.7,
#   'tamax': 8.8},
#  {'idema': '1542',
#   'lon': -6.414164,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.2,
#   'alt': 1530.0,
#   'vmax': 12.3,
#   'vv': 4.5,
#   'dv': 273.0,
#   'lat': 42.994164,
#   'dmax': 261.0,
#   'ubi': 'PUERTO DE LEITARIEGOS',
#   'pres': 845.4,
#   'hr': 86.0,
#   'ts': 1.0,
#   'tamin': 6.1,
#   'ta': 7.4,
#   'tamax': 7.4,
#   'tpr': 5.1,
#   'vis': 9.0,
#   'inso': 0.0,
#   'tss5cm': 1.7,
#   'geo850': {'value': 1486.2, 'present': True}},
#  {'idema': '1549',
#   'lon': -6.6,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 534.0,
#   'vmax': 3.9,
#   'vv': 0.8,
#   'dv': 333.0,
#   'lat': 42.56389,
#   'dmax': 308.0,
#   'ubi': 'PONFERRADA',
#   'pres': 953.7,
#   'hr': 77.0,
#   'stdvv': 0.3,
#   'ts': 11.3,
#   'pres_nmar': 1016.3,
#   'tamin': 12.0,
#   'ta': 12.0,
#   'tamax': 12.6,
#   'tpr': 8.1,
#   'vis': 20.0,
#   'stddv': 85.0,
#   'inso': 0.0,
#   'tss5cm': 9.9,
#   'pacutp': 0.0,
#   'tss20cm': 10.0},
#  {'idema': '1561I',
#   'lon': -6.673564,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.4,
#   'alt': 770.0,
#   'lat': 42.76604,
#   'ubi': 'VILLAR DE OTERO (LOS TROBOS)',
#   'hr': 93.0,
#   'tamin': 9.3,
#   'ta': 9.3,
#   'tamax': 9.5},
#  {'idema': '1583X',
#   'lon': -6.99314,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 315.0,
#   'lat': 42.41562,
#   'ubi': 'O BARCO DE VALDEORRAS',
#   'hr': 65.0,
#   'tamin': 14.8,
#   'ta': 14.8,
#   'tamax': 14.9},
#  {'idema': '1631E',
#   'lon': -7.282498,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 840.0,
#   'vmax': 11.8,
#   'vv': 5.1,
#   'dv': 247.0,
#   'lat': 42.339447,
#   'dmax': 242.0,
#   'ubi': 'POBRA DE TRIVES SAN MAMEDE',
#   'pres': 919.6,
#   'hr': 78.0,
#   'ts': 10.2,
#   'tamin': 11.0,
#   'ta': 11.1,
#   'tamax': 11.1,
#   'tpr': 7.4,
#   'inso': 0.0,
#   'tss5cm': 8.5,
#   'psoltp': 0.0,
#   'pliqt': 0.0,
#   'geo925': 791.1},
#  {'idema': '1639X',
#   'lon': -7.383609,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 990.0,
#   'vmax': 15.4,
#   'vv': 8.4,
#   'dv': 195.0,
#   'lat': 42.260277,
#   'dmax': 207.0,
#   'ubi': 'CHANDREXA DE QUEIXA',
#   'hr': 90.0,
#   'tamin': 9.5,
#   'ta': 9.5,
#   'tamax': 9.5},
#  {'idema': '1658',
#   'lon': -7.191741,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.6,
#   'alt': 612.0,
#   'lat': 42.58853,
#   'ubi': 'FOLGOSO DO COUREL',
#   'hr': 93.0,
#   'tamin': 10.8,
#   'ta': 10.8,
#   'tamax': 10.8},
#  {'idema': '1679A',
#   'lon': -7.510804,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.4,
#   'alt': 291.0,
#   'vmax': 1.3,
#   'vv': 0.3,
#   'dv': 139.0,
#   'lat': 42.53177,
#   'dmax': 52.0,
#   'ubi': 'MONFORTE DE LEMOS',
#   'hr': 93.0,
#   'tamin': 12.4,
#   'ta': 12.4,
#   'tamax': 12.9},
#  {'idema': '1690A',
#   'lon': -7.859722,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 143.0,
#   'vmax': 3.5,
#   'vv': 0.9,
#   'dv': 199.0,
#   'lat': 42.32528,
#   'dmax': 305.0,
#   'ubi': 'OURENSE',
#   'pres': 997.9,
#   'hr': 79.0,
#   'stdvv': 0.4,
#   'ts': 12.9,
#   'pres_nmar': 1015.5,
#   'tamin': 15.1,
#   'ta': 15.1,
#   'tamax': 15.4,
#   'tpr': 11.4,
#   'vis': 20.0,
#   'stddv': 44.0,
#   'inso': 0.0,
#   'tss5cm': 12.7,
#   'pacutp': 0.0,
#   'tss20cm': 12.6},
#  {'idema': '1696O',
#   'lon': -8.277961,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 1.8,
#   'alt': 610.0,
#   'lat': 42.468056,
#   'ubi': 'BEARIZ',
#   'hr': 100.0,
#   'tamin': 11.5,
#   'ta': 11.6,
#   'tamax': 11.6},
#  {'idema': '1700X',
#   'lon': -8.0925,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.4,
#   'alt': 400.0,
#   'vmax': 1.8,
#   'vv': 0.2,
#   'dv': 181.0,
#   'lat': 42.42139,
#   'dmax': 218.0,
#   'ubi': 'O CARBALLIÑO',
#   'hr': 97.0,
#   'tamin': 12.4,
#   'ta': 12.4,
#   'tamax': 12.5,
#   'tpr': 11.9,
#   'rviento': 3.0},
#  {'idema': '1701X',
#   'lon': -8.129121,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.4,
#   'alt': 112.0,
#   'vmax': 7.6,
#   'vv': 3.2,
#   'dv': 261.0,
#   'lat': 42.29988,
#   'dmax': 220.0,
#   'ubi': 'RIBADAVIA',
#   'hr': 100.0,
#   'tamin': 13.6,
#   'ta': 13.7,
#   'tamax': 13.8},
#  {'idema': '1706A',
#   'lon': -7.796051,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 492.0,
#   'lat': 42.182903,
#   'ubi': 'ALLARIZ-RIMELO',
#   'hr': 83.0,
#   'tamin': 12.6,
#   'ta': 12.7,
#   'tamax': 12.7},
#  {'idema': '1719',
#   'lon': -8.281009,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 2.6,
#   'alt': 560.0,
#   'lat': 42.217995,
#   'ubi': 'A CAÑIZA',
#   'hr': 100.0,
#   'tamin': 11.3,
#   'ta': 11.5,
#   'tamax': 11.5},
#  {'idema': '1723X',
#   'lon': -8.4927,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 90.0,
#   'lat': 42.182224,
#   'ubi': 'PONTEAREAS-CANEDO',
#   'tamin': 14.4,
#   'ta': 14.4,
#   'tamax': 14.7},
#  {'idema': '1730E',
#   'lon': -8.847444,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 55.0,
#   'lat': 41.94398,
#   'ubi': 'O ROSAL',
#   'hr': 94.0,
#   'tamin': 14.9,
#   'ta': 14.9,
#   'tamax': 15.0},
#  {'idema': '1735X',
#   'lon': -7.733611,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 616.0,
#   'vmax': 4.7,
#   'vv': 2.0,
#   'dv': 185.0,
#   'lat': 42.079166,
#   'dmax': 183.0,
#   'ubi': 'XINZO DE LIMIA',
#   'hr': 82.0,
#   'tamin': 10.6,
#   'ta': 10.8,
#   'tamax': 10.9,
#   'tpr': 7.8,
#   'rviento': 75.0},
#  {'idema': '1738U',
#   'lon': -7.988838,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 1.2,
#   'alt': 730.0,
#   'lat': 41.934116,
#   'ubi': 'MUIÑOS-PRADO',
#   'hr': 95.0,
#   'tamin': 10.5,
#   'ta': 10.7,
#   'tamax': 10.7},
#  {'idema': '1740',
#   'lon': -4.12433,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 150.0,
#   'vmax': 2.3,
#   'vv': 1.7,
#   'dv': 176.0,
#   'lat': 43.37724,
#   'dmax': 167.0,
#   'ubi': 'ALTAMIRA',
#   'hr': 50.0,
#   'tamin': 14.6,
#   'ta': 14.6,
#   'tamax': 15.1},
#  {'idema': '2005Y',
#   'lon': -2.782777,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 1197.0,
#   'lat': 41.967773,
#   'ubi': 'VINUESA',
#   'hr': 84.0,
#   'tamin': 7.1,
#   'ta': 7.1,
#   'tamax': 7.2},
#  {'idema': '2017Y',
#   'lon': -2.494163,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
#   'alt': 1260.0,
#   'vmax': 15.3,
#   'vv': 7.4,
#   'dv': 255.0,
#   'lat': 41.99583,
#   'dmax': 252.0,
#   'ubi': 'BARRIOMARTIN-EL ROBLEDO',
#   'hr': 78.0,
#   'tamin': 6.8,
#   'ta': 6.8,
#   'tamax': 7.1},
#  {'idema': '2030',
#   'lon': -2.483063,
#   'fint': '2021-12-28T02:00:00',
#   'prec': 0.0,
# ...
#   'dmax': 256.0,
#   'ubi': 'PADRÓN',
#   'hr': 93.0,
#   'tamin': 14.1,
#   'ta': 14.3,
#   'tamax': 14.3,
#   'tpr': 13.2,
#   'rviento': 124.0},
#  {'idema': '1475X',
#   'lon': -8.555833,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 1.4,
#   'alt': 240.0,
#   'vmax': 9.9,
#   'vv': 1.8,
#   'dv': 217.0,
#   'lat': 42.87611,
#   'dmax': 224.0,
#   'ubi': 'SANTIAGO DE COMPOSTELA',
#   'hr': 96.0,
#   'tamin': 13.8,
#   'ta': 14.1,
#   'tamax': 14.1,
#   'tpr': 13.5,
#   'rviento': 118.0},
#  {'idema': '1476R',
#   'lon': -8.714807,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 1.8,
#   'alt': 210.0,
#   'lat': 42.749836,
#   'ubi': 'CASAS DO PORTO',
#   'hr': 100.0,
#   'tamin': 13.6,
#   'ta': 13.7,
#   'tamax': 13.7},
#  {'idema': '1477V',
#   'lon': -8.774642,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 32.0,
#   'vmax': 10.7,
#   'vv': 5.8,
#   'dv': 235.0,
#   'lat': 42.584843,
#   'dmax': 237.0,
#   'ubi': 'VILAGARCIA DE AROUSA',
#   'hr': 98.0,
#   'tamin': 14.9,
#   'ta': 15.4,
#   'tamax': 15.4},
#  {'idema': '1484C',
#   'lon': -8.615833,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.8,
#   'alt': 108.0,
#   'vmax': 11.6,
#   'vv': 2.3,
#   'dv': 184.0,
#   'lat': 42.43833,
#   'dmax': 170.0,
#   'ubi': 'PONTEVEDRA',
#   'pres': 1002.0,
#   'hr': 98.0,
#   'stdvv': 1.0,
#   'ts': 14.6,
#   'pres_nmar': 1015.4,
#   'tamin': 14.8,
#   'ta': 14.8,
#   'tamax': 14.8,
#   'tpr': 14.5,
#   'vis': 3.8,
#   'stddv': 31.0,
#   'inso': 0.0,
#   'tss5cm': 13.6,
#   'pacutp': 1.01,
#   'tss20cm': 13.1},
#  {'idema': '1489A',
#   'lon': -8.451243,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 3.4,
#   'alt': 395.0,
#   'vmax': 9.2,
#   'vv': 3.8,
#   'dv': 243.0,
#   'lat': 42.40705,
#   'dmax': 207.0,
#   'ubi': 'A LAMA',
#   'hr': 96.0,
#   'tamin': 13.0,
#   'ta': 13.2,
#   'tamax': 13.2},
#  {'idema': '1495',
#   'lon': -8.623765,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 2.5,
#   'alt': 261.0,
#   'vmax': 11.8,
#   'vv': 6.1,
#   'dv': 200.0,
#   'lat': 42.238617,
#   'dmax': 200.0,
#   'ubi': 'VIGO/PEINADOR',
#   'pres': 986.5,
#   'hr': 96.0,
#   'stdvv': 0.7,
#   'ts': 14.1,
#   'pres_nmar': 1017.0,
#   'tamin': 14.1,
#   'ta': 14.2,
#   'tamax': 14.2,
#   'tpr': 13.6,
#   'stddv': 7.0,
#   'inso': 0.0},
#  {'idema': '1496X',
#   'lon': -8.724167,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.2,
#   'alt': 120.0,
#   'vmax': 7.6,
#   'vv': 3.7,
#   'dv': 219.0,
#   'lat': 42.230556,
#   'dmax': 272.0,
#   'ubi': 'VIGO-O CASTRO',
#   'hr': 100.0,
#   'tamin': 14.8,
#   'ta': 14.8,
#   'tamax': 15.0},
#  {'idema': '1505',
#   'lon': -7.457222,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.2,
#   'alt': 445.0,
#   'vmax': 9.5,
#   'vv': 4.5,
#   'dv': 210.0,
#   'lat': 43.11139,
#   'dmax': 223.0,
#   'ubi': 'LUGO/ROZAS',
#   'pres': 962.2,
#   'hr': 96.0,
#   'stdvv': 1.7,
#   'ts': 11.9,
#   'pres_nmar': 1014.4,
#   'tamin': 11.8,
#   'ta': 12.1,
#   'tamax': 12.1,
#   'tpr': 11.4,
#   'vis': 4.1,
#   'stddv': 17.0,
#   'inso': 0.0,
#   'tss5cm': 10.4,
#   'pacutp': 0.29,
#   'tss20cm': 10.3},
#  {'idema': '1518A',
#   'lon': -7.5525,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.4,
#   'alt': 442.0,
#   'vmax': 4.8,
#   'vv': 1.5,
#   'dv': 189.0,
#   'lat': 42.998333,
#   'dmax': 195.0,
#   'ubi': 'LUGO-COL.FINGOI',
#   'hr': 96.0,
#   'tamin': 11.7,
#   'ta': 11.9,
#   'tamax': 11.9},
#  {'idema': '1521I',
#   'lon': -7.499579,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 403.0,
#   'lat': 42.845276,
#   'ubi': 'O PARAMO',
#   'hr': 85.0,
#   'tamin': 13.7,
#   'ta': 13.8,
#   'tamax': 13.8},
#  {'idema': '1521X',
#   'lon': -7.18517,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 1080.0,
#   'vmax': 13.7,
#   'vv': 4.5,
#   'dv': 208.0,
#   'lat': 42.86377,
#   'dmax': 205.0,
#   'ubi': 'BECERREA-PENAMAIOR',
#   'hr': 100.0,
#   'tamin': 8.7,
#   'ta': 8.9,
#   'tamax': 8.9},
#  {'idema': '1535I',
#   'lon': -7.704599,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 552.0,
#   'vv': 6.0,
#   'dv': 221.0,
#   'lat': 42.63472,
#   'ubi': 'EVC_O SAVIÑAO',
#   'pres': 951.0,
#   'hr': 99.0,
#   'tamin': 11.6,
#   'ta': 11.8,
#   'tamax': 11.8,
#   'tpr': 11.7,
#   'rviento': 247.0},
#  {'idema': '1541B',
#   'lon': -6.333886,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.6,
#   'alt': 958.0,
#   'vmax': 10.4,
#   'vv': 3.6,
#   'dv': 195.0,
#   'lat': 42.928886,
#   'dmax': 192.0,
#   'ubi': 'VILLABLINO',
#   'hr': 94.0,
#   'tamin': 8.7,
#   'ta': 8.7,
#   'tamax': 8.9},
#  {'idema': '1542',
#   'lon': -6.414164,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.4,
#   'alt': 1530.0,
#   'vmax': 10.4,
#   'vv': 1.7,
#   'dv': 144.0,
#   'lat': 42.994164,
#   'dmax': 317.0,
#   'ubi': 'PUERTO DE LEITARIEGOS',
#   'pres': 845.5,
#   'hr': 92.0,
#   'ts': 1.0,
#   'tamin': 5.8,
#   'ta': 5.8,
#   'tamax': 7.4,
#   'tpr': 4.6,
#   'vis': 0.5,
#   'inso': 0.0,
#   'tss5cm': 1.8,
#   'geo850': {'value': 1487.4, 'present': True}},
#  {'idema': '1549',
#   'lon': -6.6,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 534.0,
#   'vmax': 3.3,
#   'vv': 0.7,
#   'dv': 96.0,
#   'lat': 42.56389,
#   'dmax': 333.0,
#   'ubi': 'PONFERRADA',
#   'pres': 954.2,
#   'hr': 82.0,
#   'stdvv': 0.2,
#   'ts': 10.5,
#   'pres_nmar': 1016.9,
#   'tamin': 11.5,
#   'ta': 11.5,
#   'tamax': 12.0,
#   'tpr': 8.5,
#   'vis': 20.0,
#   'stddv': 54.0,
#   'inso': 0.0,
#   'tss5cm': 9.9,
#   'pacutp': 0.0,
#   'tss20cm': 9.9},
#  {'idema': '1561I',
#   'lon': -6.673564,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.8,
#   'alt': 770.0,
#   'lat': 42.76604,
#   'ubi': 'VILLAR DE OTERO (LOS TROBOS)',
#   'hr': 94.0,
#   'tamin': 9.2,
#   'ta': 9.2,
#   'tamax': 9.3},
#  {'idema': '1583X',
#   'lon': -6.99314,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 315.0,
#   'lat': 42.41562,
#   'ubi': 'O BARCO DE VALDEORRAS',
#   'hr': 68.0,
#   'tamin': 14.6,
#   'ta': 14.7,
#   'tamax': 14.7},
#  {'idema': '1631E',
#   'lon': -7.282498,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 840.0,
#   'vmax': 11.5,
#   'vv': 3.3,
#   'dv': 243.0,
#   'lat': 42.339447,
#   'dmax': 217.0,
#   'ubi': 'POBRA DE TRIVES SAN MAMEDE',
#   'pres': 920.2,
#   'hr': 79.0,
#   'ts': 10.3,
#   'tamin': 11.1,
#   'ta': 11.2,
#   'tamax': 11.3,
#   'tpr': 7.7,
#   'inso': 0.0,
#   'tss5cm': 8.6,
#   'psoltp': 0.0,
#   'pliqt': 0.0,
#   'geo925': 796.5},
#  {'idema': '1639X',
#   'lon': -7.383609,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 990.0,
#   'vmax': 14.7,
#   'vv': 8.9,
#   'dv': 205.0,
#   'lat': 42.260277,
#   'dmax': 172.0,
#   'ubi': 'CHANDREXA DE QUEIXA',
#   'hr': 93.0,
#   'tamin': 9.3,
#   'ta': 9.5,
#   'tamax': 9.5},
#  {'idema': '1658',
#   'lon': -7.191741,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.6,
#   'alt': 612.0,
#   'lat': 42.58853,
#   'ubi': 'FOLGOSO DO COUREL',
#   'hr': 95.0,
#   'tamin': 10.7,
#   'ta': 10.8,
#   'tamax': 10.9},
#  {'idema': '1679A',
#   'lon': -7.510804,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.4,
#   'alt': 291.0,
#   'vmax': 0.7,
#   'vv': 0.2,
#   'dv': 107.0,
#   'lat': 42.53177,
#   'dmax': 95.0,
#   'ubi': 'MONFORTE DE LEMOS',
#   'hr': 93.0,
#   'tamin': 12.3,
#   'ta': 12.3,
#   'tamax': 12.3},
#  {'idema': '1690A',
#   'lon': -7.859722,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 143.0,
#   'vmax': 4.6,
#   'vv': 1.7,
#   'dv': 143.0,
#   'lat': 42.32528,
#   'dmax': 150.0,
#   'ubi': 'OURENSE',
#   'pres': 998.2,
#   'hr': 81.0,
#   'stdvv': 1.0,
#   'ts': 12.9,
#   'pres_nmar': 1015.8,
#   'tamin': 15.0,
#   'ta': 15.1,
#   'tamax': 15.1,
#   'tpr': 11.9,
#   'vis': 20.0,
#   'stddv': 22.0,
#   'inso': 0.0,
#   'tss5cm': 12.8,
#   'pacutp': 0.0,
#   'tss20cm': 12.6},
#  {'idema': '1696O',
#   'lon': -8.277961,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 2.4,
#   'alt': 610.0,
#   'lat': 42.468056,
#   'ubi': 'BEARIZ',
#   'hr': 100.0,
#   'tamin': 11.7,
#   'ta': 11.9,
#   'tamax': 11.9},
#  {'idema': '1700X',
#   'lon': -8.0925,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.6,
#   'alt': 400.0,
#   'vmax': 1.4,
#   'vv': 0.0,
#   'dv': 0.0,
#   'lat': 42.42139,
#   'dmax': 149.0,
#   'ubi': 'O CARBALLIÑO',
#   'hr': 98.0,
#   'tamin': 12.4,
#   'ta': 12.5,
#   'tamax': 12.5,
#   'tpr': 12.2,
#   'rviento': 1.0},
#  {'idema': '1701X',
#   'lon': -8.129121,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.4,
#   'alt': 112.0,
#   'vmax': 9.6,
#   'vv': 4.6,
#   'dv': 254.0,
#   'lat': 42.29988,
#   'dmax': 237.0,
#   'ubi': 'RIBADAVIA',
#   'hr': 100.0,
#   'tamin': 13.7,
#   'ta': 14.0,
#   'tamax': 14.0},
#  {'idema': '1706A',
#   'lon': -7.796051,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 492.0,
#   'lat': 42.182903,
#   'ubi': 'ALLARIZ-RIMELO',
#   'hr': 84.0,
#   'tamin': 12.8,
#   'ta': 12.8,
#   'tamax': 12.8},
#  {'idema': '1719',
#   'lon': -8.281009,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 2.4,
#   'alt': 560.0,
#   'lat': 42.217995,
#   'ubi': 'A CAÑIZA',
#   'hr': 100.0,
#   'tamin': 11.5,
#   'ta': 11.7,
#   'tamax': 11.7},
#  {'idema': '1723X',
#   'lon': -8.4927,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 90.0,
#   'lat': 42.182224,
#   'ubi': 'PONTEAREAS-CANEDO',
#   'tamin': 14.4,
#   'ta': 14.6,
#   'tamax': 14.6},
#  {'idema': '1730E',
#   'lon': -8.847444,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 55.0,
#   'lat': 41.94398,
#   'ubi': 'O ROSAL',
#   'hr': 95.0,
#   'tamin': 14.9,
#   'ta': 15.0,
#   'tamax': 15.0},
#  {'idema': '1735X',
#   'lon': -7.733611,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 616.0,
#   'vmax': 3.9,
#   'vv': 1.2,
#   'dv': 138.0,
#   'lat': 42.079166,
#   'dmax': 180.0,
#   'ubi': 'XINZO DE LIMIA',
#   'hr': 82.0,
#   'tamin': 10.7,
#   'ta': 11.1,
#   'tamax': 11.2,
#   'tpr': 8.1,
#   'rviento': 62.0},
#  {'idema': '1738U',
#   'lon': -7.988838,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 1.4,
#   'alt': 730.0,
#   'lat': 41.934116,
#   'ubi': 'MUIÑOS-PRADO',
#   'hr': 96.0,
#   'tamin': 10.6,
#   'ta': 10.8,
#   'tamax': 10.8},
#  {'idema': '1740',
#   'lon': -4.12433,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 150.0,
#   'vmax': 3.0,
#   'vv': 2.0,
#   'dv': 164.0,
#   'lat': 43.37724,
#   'dmax': 155.0,
#   'ubi': 'ALTAMIRA',
#   'hr': 55.0,
#   'tamin': 14.5,
#   'ta': 14.5,
#   'tamax': 14.8},
#  {'idema': '2005Y',
#   'lon': -2.782777,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 1197.0,
#   'lat': 41.967773,
#   'ubi': 'VINUESA',
#   'hr': 83.0,
#   'tamin': 7.1,
#   'ta': 7.1,
#   'tamax': 7.2},
#  {'idema': '2017Y',
#   'lon': -2.494163,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 1260.0,
#   'vmax': 13.3,
#   'vv': 7.5,
#   'dv': 258.0,
#   'lat': 41.99583,
#   'dmax': 260.0,
#   'ubi': 'BARRIOMARTIN-EL ROBLEDO',
#   'hr': 79.0,
#   'tamin': 6.6,
#   'ta': 6.6,
#   'tamax': 6.9},
#  {'idema': '2030',
#   'lon': -2.483063,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 1082.0,
#   'vmax': 13.5,
#   'vv': 6.5,
#   'dv': 262.0,
#   'lat': 41.775017,
#   'dmax': 253.0,
#   'ubi': 'SORIA',
#   'pres': 893.8,
#   'hr': 85.0,
#   'stdvv': 1.8,
#   'ts': 7.4,
#   'tamin': 7.7,
#   'ta': 7.7,
#   'tamax': 7.9,
#   'tpr': 5.3,
#   'vis': 20.0,
#   'stddv': 16.0,
#   'inso': 0.0,
#   'tss5cm': 7.5,
#   'pacutp': 0.0,
#   'tss20cm': 7.7,
#   'geo850': {'value': 1495.6, 'present': True}},
#  {'idema': '2044B',
#   'lon': -2.507534,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 1100.0,
#   'vmax': 11.6,
#   'vv': 7.1,
#   'dv': 259.0,
#   'lat': 41.600582,
#   'dmax': 265.0,
#   'ubi': 'LUBIA-CEDER',
#   'hr': 89.0,
#   'tamin': 7.0,
#   'ta': 7.0,
#   'tamax': 7.1},
#  {'idema': '2048A',
#   'lon': -2.420281,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 978.0,
#   'vmax': 12.3,
#   'vv': 7.3,
#   'dv': 260.0,
#   'lat': 41.41944,
#   'dmax': 260.0,
#   'ubi': 'MORON DE ALMAZAN ',
#   'hr': 80.0,
#   'tamin': 8.1,
#   'ta': 8.3,
#   'tamax': 8.4},
#  {'idema': '2059B',
#   'lon': -2.783338,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 1042.0,
#   'vmax': 11.7,
#   'vv': 6.7,
#   'dv': 280.0,
#   'lat': 41.34972,
#   'dmax': 272.0,
#   'ubi': 'LA RIBA DE ESCALOTE',
#   'hr': 77.0,
#   'tamin': 7.5,
#   'ta': 8.0,
#   'tamax': 8.1},
#  {'idema': '2084Y',
#   'lon': -3.047008,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 960.0,
#   'lat': 41.721848,
#   'ubi': 'UCERO',
#   'hr': 87.0,
#   'tamin': 7.8,
#   'ta': 7.8,
#   'tamax': 8.1},
#  {'idema': '2092',
#   'lon': -3.086949,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 932.0,
#   'vmax': 10.8,
#   'vv': 4.4,
#   'dv': 266.0,
#   'lat': 41.589443,
#   'dmax': 262.0,
#   'ubi': 'BURGO DE OSMA-POZUELOS',
#   'hr': 79.0,
#   'tamin': 8.1,
#   'ta': 8.4,
#   'tamax': 8.4},
#  {'idema': '2096B',
#   'lon': -3.251385,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 1150.0,
#   'vmax': 14.2,
#   'vv': 8.6,
#   'dv': 280.0,
#   'lat': 41.373608,
#   'dmax': 290.0,
#   'ubi': 'LICERAS-CAÑADA DEHESA',
#   'hr': 83.0,
#   'tamin': 7.1,
#   'ta': 7.3,
#   'tamax': 7.3},
#  {'idema': '2106B',
#   'lon': -3.381929,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 955.0,
#   'vmax': 10.5,
#   'vv': 2.5,
#   'dv': 273.0,
#   'lat': 41.745846,
#   'dmax': 262.0,
#   'ubi': 'CORUÑA DEL CONDE',
#   'hr': 87.0,
#   'tamin': 7.4,
#   'ta': 7.4,
#   'tamax': 7.7},
#  {'idema': '2117D',
#   'lon': -3.742777,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 790.0,
#   'vmax': 11.6,
#   'vv': 3.4,
#   'dv': 240.0,
#   'lat': 41.665836,
#   'dmax': 227.0,
#   'ubi': 'ARANDA DE DUERO',
#   'pres': 927.9,
#   'hr': 72.0,
#   'ts': 7.8,
#   'tamin': 8.6,
#   'ta': 8.6,
#   'tamax': 8.8,
#   'tpr': 3.8,
#   'vis': 13.1,
#   'inso': 0.0,
#   'tss5cm': 7.9,
#   'psoltp': 0.0,
#   'pliqt': 0.0,
#   'geo925': 815.9},
#  {'idema': '2135A',
#   'lon': -3.507234,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 993.0,
#   'vmax': 11.9,
#   'vv': 7.8,
#   'dv': 230.0,
#   'lat': 41.372757,
#   'dmax': 232.0,
#   'ubi': 'FRESNO DE CANTIESPINO',
#   'hr': 86.0,
#   'tamin': 7.8,
#   'ta': 8.0,
#   'tamax': 8.0},
#  {'idema': '2140A',
#   'lon': -3.785871,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 1135.0,
#   'vmax': 14.4,
#   'vv': 10.5,
#   'dv': 236.0,
#   'lat': 41.464554,
#   'dmax': 237.0,
#   'ubi': 'ALDEANUEVA DE SERREZUELA-EL CERRO',
#   'hr': 95.0,
#   'tamin': 6.5,
#   'ta': 6.5,
#   'tamax': 6.8},
#  {'idema': '2150H',
#   'lon': -3.475165,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 1798.0,
#   'vmax': 17.1,
#   'vv': 5.5,
#   'dv': 17.0,
#   'lat': 41.19193,
#   'dmax': 238.0,
#   'ubi': 'LA PINILLA  ESTACIÓN DE ESQUÍ',
#   'pres': 821.9,
#   'hr': 98.0,
#   'ts': 2.9,
#   'tamin': 2.1,
#   'ta': 2.1,
#   'tamax': 2.3,
#   'tpr': 1.9,
#   'vis': 0.2,
#   'inso': 0.0,
#   'tss5cm': 3.1,
#   'psoltp': 0.0,
#   'pliqt': 0.0,
#   'geo850': {'value': 1526.4, 'present': True}},
#  {'idema': '2166Y',
#   'lon': -4.124787,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 756.0,
#   'lat': 41.593098,
#   'ubi': 'PEÑAFIEL(FABRICA DE QUESOS)',
#   'hr': 84.0,
#   'tamin': 8.8,
#   'ta': 8.8,
#   'tamax': 9.1},
#  {'idema': '2172Y',
#   'lon': -4.405497,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 725.0,
#   'vmax': 6.6,
#   'vv': 3.7,
#   'dv': 261.0,
#   'lat': 41.611877,
#   'dmax': 252.0,
#   'ubi': 'SARDÓN DE DUERO',
#   'hr': 88.0,
#   'tamin': 8.8,
#   'ta': 8.9,
#   'tamax': 9.0},
#  {'idema': '2182C',
#   'lon': -3.790216,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 1107.0,
#   'vmax': 6.4,
#   'vv': 3.7,
#   'dv': 244.0,
#   'lat': 41.13386,
#   'dmax': 257.0,
#   'ubi': 'RADES',
#   'hr': 87.0,
#   'tamin': 7.3,
#   'ta': 7.3,
#   'tamax': 7.3},
#  {'idema': '2192C',
#   'lon': -4.26545,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 795.0,
#   'vmax': 4.4,
#   'vv': 1.7,
#   'dv': 223.0,
#   'lat': 41.383553,
#   'dmax': 217.0,
#   'ubi': 'CUELLAR',
#   'hr': 92.0,
#   'tamin': 7.8,
#   'ta': 7.8,
#   'tamax': 8.8},
#  {'idema': '2235U',
#   'lon': -4.520031,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 1140.0,
#   'vmax': 10.8,
#   'vv': 4.6,
#   'dv': 244.0,
#   'lat': 42.87062,
#   'dmax': 226.0,
#   'ubi': 'CERVERA DE PISUERGA',
#   'pres': 885.9,
#   'hr': 83.0,
#   'ts': 6.6,
#   'tamin': 7.1,
#   'ta': 7.4,
#   'tamax': 7.4,
#   'tpr': 4.6,
#   'vis': 20.0,
#   'inso': 0.0,
#   'tss5cm': 6.1,
#   'psoltp': 0.0,
#   'pliqt': 0.0,
#   'geo850': {'value': 1479.6, 'present': True}},
#  {'idema': '2243A',
#   'lon': -4.277134,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 910.0,
#   'vmax': 7.4,
#   'vv': 2.8,
#   'dv': 251.0,
#   'lat': 42.79806,
#   'dmax': 255.0,
#   'ubi': 'AGUILAR DE CAMPOO',
#   'hr': 89.0,
#   'tamin': 8.2,
#   'ta': 8.2,
#   'tamax': 8.2},
#  {'idema': '2276B',
#   'lon': -4.575109,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 908.0,
#   'vmax': 11.3,
#   'vv': 6.3,
#   'dv': 240.0,
#   'lat': 42.568817,
#   'dmax': 245.0,
#   'ubi': 'VILLAELES DE VALDAVIA',
#   'hr': 94.0,
#   'tamin': 7.2,
#   'ta': 7.2,
#   'tamax': 7.3},
#  {'idema': '2285B',
#   'lon': -4.001111,
#   'fint': '2021-12-28T03:00:00',
#   'prec': 0.0,
#   'alt': 869.0,
#   'vmax': 12.1,
#   'vv': 8.8,
#   'dv': 239.0,
#   'lat': 42.523888,
#   'dmax': 230.0,
#   'ubi': 'VILLADIEGO (DEPÓSITO DE AGUA)',
#   'hr': 95.0,
#   'tamin': 8.0,
#   'ta': 8.0,
#   'tamax': 8.2},
#  ...]

# %%
predicciones = pd.DataFrame(resultado_real.json())
predicciones.head()
# Out:
#    idema       lon                 fint  prec    alt  vmax   vv     dv  \
# 0  0009X  0.963335  2021-12-28T02:00:00   0.0  406.0  12.3  5.4  272.0
# 1  0016A  1.178894  2021-12-28T02:00:00   0.0   71.0  13.4  7.7  270.0
# 2  0034X  1.260838  2021-12-28T02:00:00   0.0  233.0   NaN  NaN    NaN
# 3  0042Y  1.249167  2021-12-28T02:00:00   0.0   55.0   9.2  3.3  274.0
# 4  0061X  1.519269  2021-12-28T02:00:00   0.0  632.0  14.9  9.2  281.0
#
#          lat   dmax  ... pacutp  vvu  stdvvu  stddvu  dmaxu  tss20cm  geo850  \
# 0  41.213894  257.0  ...    NaN  NaN     NaN     NaN    NaN      NaN     NaN
# 1  41.149720  270.0  ...    NaN  NaN     NaN     NaN    NaN      NaN     NaN
# 2  41.293053    NaN  ...    NaN  NaN     NaN     NaN    NaN      NaN     NaN
# 3  41.123894  260.0  ...    NaN  NaN     NaN     NaN    NaN      NaN     NaN
# 4  41.417053  277.0  ...    NaN  NaN     NaN     NaN    NaN      NaN     NaN
#
#    geo925  nieve  geo700
# 0     NaN    NaN     NaN
# 1     NaN    NaN     NaN
# 2     NaN    NaN     NaN
# 3     NaN    NaN     NaN
# 4     NaN    NaN     NaN
#
# [5 rows x 39 columns]

# %%
predicciones.shape
# Out:
# (17914, 39)

# %%
df.columns
# Out:
# Index(['latitud', 'id_old', 'url', 'latitud_dec', 'altitud', 'capital',
#        'num_hab', 'zona_comarcal', 'destacada', 'nombre', 'longitud_dec', 'id',
#        'longitud'],
#       dtype='object')

# %%
predicciones.columns
# Out:
# Index(['idema', 'lon', 'fint', 'prec', 'alt', 'vmax', 'vv', 'dv', 'lat',
#        'dmax', 'ubi', 'hr', 'tamin', 'ta', 'tamax', 'pres', 'stdvv', 'ts',
#        'pres_nmar', 'tpr', 'vis', 'stddv', 'inso', 'tss5cm', 'psoltp', 'pliqt',
#        'rviento', 'vmaxu', 'dvu', 'pacutp', 'vvu', 'stdvvu', 'stddvu', 'dmaxu',
#        'tss20cm', 'geo850', 'geo925', 'nieve', 'geo700'],
#       dtype='object')

# %% [markdown]
# ### Ejercicio 5: Obtén la predicción para el municipio de Coruña
#
# #### Obtener el id del municipio de Oleiros
# #### Obtener la predicción ¿Cómo se le pasa el código de municipio?

# %%
import requests
import pandas

coruna = df[(df['capital'].str.contains('Coru')) & (df['id_old'].str.contains('15'))]
coruna
# Out:
#                latitud id_old               url  latitud_dec altitud  \
# 2354  43º22'12.455148"  15001  coruna-a-id15030  43.37012643      21
#
#         capital num_hab zona_comarcal destacada     nombre longitud_dec  \
# 2354  Coruña, A  244810        711501         1  Coruña, A  -8.39114853
#
#            id          longitud
# 2354  id15030  -8º23'28.134708"

# %%
coruna_id = list(coruna['id'].str.replace('id',''))[0]
coruna_id
# Out:
# '15030'

# %%
res = requests.get(ruta_base_aemet + '/api/prediccion/especifica/municipio/diaria/{}'.format(coruna_id), headers=headers)
resultado = res.json()
res = requests.get(resultado['datos'])
coruna_pred = res.json()[0]

# %%
coruna_pred=coruna_pred['prediccion']
coruna_pred
# Out:
# {'dia': [{'probPrecipitacion': [{'value': 0, 'periodo': '00-24'},
#     {'value': 0, 'periodo': '00-12'},
#     {'value': 0, 'periodo': '12-24'},
#     {'value': 0, 'periodo': '00-06'},
#     {'value': 0, 'periodo': '06-12'},
#     {'value': 0, 'periodo': '12-18'},
#     {'value': 5, 'periodo': '18-24'}],
#    'cotaNieveProv': [{'value': '', 'periodo': '00-24'},
#     {'value': '', 'periodo': '00-12'},
#     {'value': '', 'periodo': '12-24'},
#     {'value': '', 'periodo': '00-06'},
#     {'value': '', 'periodo': '06-12'},
#     {'value': '', 'periodo': '12-18'},
#     {'value': '', 'periodo': '18-24'}],
#    'estadoCielo': [{'value': '', 'periodo': '00-24', 'descripcion': ''},
#     {'value': '', 'periodo': '00-12', 'descripcion': ''},
#     {'value': '', 'periodo': '12-24', 'descripcion': ''},
#     {'value': '', 'periodo': '00-06', 'descripcion': ''},
#     {'value': '', 'periodo': '06-12', 'descripcion': ''},
#     {'value': '', 'periodo': '12-18', 'descripcion': ''},
#     {'value': '16n', 'periodo': '18-24', 'descripcion': 'Cubierto'}],
#    'viento': [{'direccion': '', 'velocidad': 0, 'periodo': '00-24'},
#     {'direccion': '', 'velocidad': 0, 'periodo': '00-12'},
#     {'direccion': '', 'velocidad': 0, 'periodo': '12-24'},
#     {'direccion': '', 'velocidad': 0, 'periodo': '00-06'},
#     {'direccion': '', 'velocidad': 0, 'periodo': '06-12'},
#     {'direccion': 'S', 'velocidad': 25, 'periodo': '12-18'},
#     {'direccion': 'S', 'velocidad': 20, 'periodo': '18-24'}],
#    'rachaMax': [{'value': '', 'periodo': '00-24'},
#     {'value': '', 'periodo': '00-12'},
#     {'value': '', 'periodo': '12-24'},
#     {'value': '', 'periodo': '00-06'},
#     {'value': '', 'periodo': '06-12'},
#     {'value': '', 'periodo': '12-18'},
#     {'value': '', 'periodo': '18-24'}],
#    'temperatura': {'maxima': 18,
#     'minima': 16,
#     'dato': [{'value': 0, 'hora': 6},
#      {'value': 0, 'hora': 12},
#      {'value': 16, 'hora': 18},
#      {'value': 16, 'hora': 24}]},
#    'sensTermica': {'maxima': 18,
#     'minima': 15,
#     'dato': [{'value': 0, 'hora': 6},
#      {'value': 0, 'hora': 12},
#      {'value': 16, 'hora': 18},
#      {'value': 16, 'hora': 24}]},
#    'humedadRelativa': {'maxima': 90,
#     'minima': 80,
#     'dato': [{'value': 0, 'hora': 6},
#      {'value': 0, 'hora': 12},
#      {'value': 80, 'hora': 18},
#      {'value': 90, 'hora': 24}]},
#    'uvMax': 1,
#    'fecha': '2021-12-28T00:00:00'},
#   {'probPrecipitacion': [{'value': 50, 'periodo': '00-24'},
#     {'value': 25, 'periodo': '00-12'},
#     {'value': 0, 'periodo': '12-24'},
#     {'value': 0, 'periodo': '00-06'},
#     {'value': 0, 'periodo': '06-12'},
#     {'value': 0, 'periodo': '12-18'},
#     {'value': 0, 'periodo': '18-24'}],
#    'cotaNieveProv': [{'value': '', 'periodo': '00-24'},
#     {'value': '', 'periodo': '00-12'},
#     {'value': '', 'periodo': '12-24'},
#     {'value': '', 'periodo': '00-06'},
#     {'value': '', 'periodo': '06-12'},
#     {'value': '', 'periodo': '12-18'},
#     {'value': '', 'periodo': '18-24'}],
#    'estadoCielo': [{'value': '16',
#      'periodo': '00-24',
#      'descripcion': 'Cubierto'},
#     {'value': '16', 'periodo': '00-12', 'descripcion': 'Cubierto'},
#     {'value': '15', 'periodo': '12-24', 'descripcion': 'Muy nuboso'},
#     {'value': '16n', 'periodo': '00-06', 'descripcion': 'Cubierto'},
#     {'value': '16', 'periodo': '06-12', 'descripcion': 'Cubierto'},
#     {'value': '15', 'periodo': '12-18', 'descripcion': 'Muy nuboso'},
#     {'value': '17n', 'periodo': '18-24', 'descripcion': 'Nubes altas'}],
#    'viento': [{'direccion': 'S', 'velocidad': 20, 'periodo': '00-24'},
#     {'direccion': 'S', 'velocidad': 20, 'periodo': '00-12'},
#     {'direccion': 'S', 'velocidad': 20, 'periodo': '12-24'},
#     {'direccion': 'S', 'velocidad': 20, 'periodo': '00-06'},
#     {'direccion': 'S', 'velocidad': 20, 'periodo': '06-12'},
#     {'direccion': 'S', 'velocidad': 15, 'periodo': '12-18'},
#     {'direccion': 'S', 'velocidad': 15, 'periodo': '18-24'}],
#    'rachaMax': [{'value': '35', 'periodo': '00-24'},
#     {'value': '35', 'periodo': '00-12'},
#     {'value': '35', 'periodo': '12-24'},
#     {'value': '', 'periodo': '00-06'},
#     {'value': '35', 'periodo': '06-12'},
#     {'value': '', 'periodo': '12-18'},
#     {'value': '', 'periodo': '18-24'}],
#    'temperatura': {'maxima': 18,
#     'minima': 15,
#     'dato': [{'value': 16, 'hora': 6},
#      {'value': 18, 'hora': 12},
#      {'value': 16, 'hora': 18},
#      {'value': 15, 'hora': 24}]},
#    'sensTermica': {'maxima': 18,
#     'minima': 15,
#     'dato': [{'value': 16, 'hora': 6},
#      {'value': 18, 'hora': 12},
#      {'value': 16, 'hora': 18},
#      {'value': 15, 'hora': 24}]},
#    'humedadRelativa': {'maxima': 95,
#     'minima': 70,
#     'dato': [{'value': 90, 'hora': 6},
#      {'value': 70, 'hora': 12},
#      {'value': 70, 'hora': 18},
#      {'value': 75, 'hora': 24}]},
#    'uvMax': 1,
#    'fecha': '2021-12-29T00:00:00'},
#   {'probPrecipitacion': [{'value': 0, 'periodo': '00-24'},
#     {'value': 0, 'periodo': '00-12'},
#     {'value': 0, 'periodo': '12-24'}],
#    'cotaNieveProv': [{'value': '', 'periodo': '00-24'},
#     {'value': '', 'periodo': '00-12'},
#     {'value': '', 'periodo': '12-24'}],
#    'estadoCielo': [{'value': '12',
#      'periodo': '00-24',
#      'descripcion': 'Poco nuboso'},
#     {'value': '14', 'periodo': '00-12', 'descripcion': 'Nuboso'},
#     {'value': '11', 'periodo': '12-24', 'descripcion': 'Despejado'}],
#    'viento': [{'direccion': 'S', 'velocidad': 10, 'periodo': '00-24'},
#     {'direccion': 'S', 'velocidad': 15, 'periodo': '00-12'},
#     {'direccion': 'S', 'velocidad': 10, 'periodo': '12-24'}],
#    'rachaMax': [{'value': '', 'periodo': '00-24'},
#     {'value': '', 'periodo': '00-12'},
#     {'value': '', 'periodo': '12-24'}],
#    'temperatura': {'maxima': 19, 'minima': 14, 'dato': []},
#    'sensTermica': {'maxima': 20, 'minima': 13, 'dato': []},
#    'humedadRelativa': {'maxima': 90, 'minima': 55, 'dato': []},
#    'uvMax': 1,
#    'fecha': '2021-12-30T00:00:00'},
#   {'probPrecipitacion': [{'value': 0, 'periodo': '00-24'},
#     {'value': 0, 'periodo': '00-12'},
#     {'value': 0, 'periodo': '12-24'}],
#    'cotaNieveProv': [{'value': '', 'periodo': '00-24'},
#     {'value': '', 'periodo': '00-12'},
#     {'value': '', 'periodo': '12-24'}],
#    'estadoCielo': [{'value': '17',
#      'periodo': '00-24',
#      'descripcion': 'Nubes altas'},
#     {'value': '17', 'periodo': '00-12', 'descripcion': 'Nubes altas'},
#     {'value': '17', 'periodo': '12-24', 'descripcion': 'Nubes altas'}],
#    'viento': [{'direccion': 'S', 'velocidad': 20, 'periodo': '00-24'},
#     {'direccion': 'S', 'velocidad': 20, 'periodo': '00-12'},
#     {'direccion': 'S', 'velocidad': 25, 'periodo': '12-24'}],
#    'rachaMax': [{'value': '', 'periodo': '00-24'},
#     {'value': '40', 'periodo': '00-12'},
#     {'value': '35', 'periodo': '12-24'}],
#    'temperatura': {'maxima': 20, 'minima': 14, 'dato': []},
#    'sensTermica': {'maxima': 20, 'minima': 14, 'dato': []},
#    'humedadRelativa': {'maxima': 65, 'minima': 55, 'dato': []},
#    'uvMax': 1,
#    'fecha': '2021-12-31T00:00:00'},
#   {'probPrecipitacion': [{'value': 85}],
#    'cotaNieveProv': [{'value': ''}],
#    'estadoCielo': [{'value': '25', 'descripcion': 'Muy nuboso con lluvia'}],
#    'viento': [{'direccion': 'S', 'velocidad': 25}],
#    'rachaMax': [{'value': '45'}],
#    'temperatura': {'maxima': 20, 'minima': 15, 'dato': []},
#    'sensTermica': {'maxima': 20, 'minima': 15, 'dato': []},
#    'humedadRelativa': {'maxima': 80, 'minima': 55, 'dato': []},
#    'uvMax': 1,
#    'fecha': '2022-01-01T00:00:00'},
#   {'probPrecipitacion': [{'value': 90}],
#    'cotaNieveProv': [{'value': ''}],
#    'estadoCielo': [{'value': '24', 'descripcion': 'Nuboso con lluvia'}],
#    'viento': [{'direccion': 'SO', 'velocidad': 20}],
#    'rachaMax': [{'value': '55'}],
#    'temperatura': {'maxima': 18, 'minima': 14, 'dato': []},
#    'sensTermica': {'maxima': 18, 'minima': 14, 'dato': []},
#    'humedadRelativa': {'maxima': 95, 'minima': 80, 'dato': []},
#    'fecha': '2022-01-02T00:00:00'},
#   {'probPrecipitacion': [{'value': 70}],
#    'cotaNieveProv': [{'value': ''}],
#    'estadoCielo': [{'value': '26', 'descripcion': 'Cubierto con lluvia'}],
#    'viento': [{'direccion': 'SO', 'velocidad': 15}],
#    'rachaMax': [{'value': ''}],
#    'temperatura': {'maxima': 16, 'minima': 12, 'dato': []},
#    'sensTermica': {'maxima': 16, 'minima': 12, 'dato': []},
#    'humedadRelativa': {'maxima': 95, 'minima': 80, 'dato': []},
#    'fecha': '2022-01-03T00:00:00'}]}

# %%
coruna_pred['dia'][0]
# Out:
# {'probPrecipitacion': [{'value': 0, 'periodo': '00-24'},
#   {'value': 0, 'periodo': '00-12'},
#   {'value': 0, 'periodo': '12-24'},
#   {'value': 0, 'periodo': '00-06'},
#   {'value': 0, 'periodo': '06-12'},
#   {'value': 0, 'periodo': '12-18'},
#   {'value': 5, 'periodo': '18-24'}],
#  'cotaNieveProv': [{'value': '', 'periodo': '00-24'},
#   {'value': '', 'periodo': '00-12'},
#   {'value': '', 'periodo': '12-24'},
#   {'value': '', 'periodo': '00-06'},
#   {'value': '', 'periodo': '06-12'},
#   {'value': '', 'periodo': '12-18'},
#   {'value': '', 'periodo': '18-24'}],
#  'estadoCielo': [{'value': '', 'periodo': '00-24', 'descripcion': ''},
#   {'value': '', 'periodo': '00-12', 'descripcion': ''},
#   {'value': '', 'periodo': '12-24', 'descripcion': ''},
#   {'value': '', 'periodo': '00-06', 'descripcion': ''},
#   {'value': '', 'periodo': '06-12', 'descripcion': ''},
#   {'value': '', 'periodo': '12-18', 'descripcion': ''},
#   {'value': '16n', 'periodo': '18-24', 'descripcion': 'Cubierto'}],
#  'viento': [{'direccion': '', 'velocidad': 0, 'periodo': '00-24'},
#   {'direccion': '', 'velocidad': 0, 'periodo': '00-12'},
#   {'direccion': '', 'velocidad': 0, 'periodo': '12-24'},
#   {'direccion': '', 'velocidad': 0, 'periodo': '00-06'},
#   {'direccion': '', 'velocidad': 0, 'periodo': '06-12'},
#   {'direccion': 'S', 'velocidad': 25, 'periodo': '12-18'},
#   {'direccion': 'S', 'velocidad': 20, 'periodo': '18-24'}],
#  'rachaMax': [{'value': '', 'periodo': '00-24'},
#   {'value': '', 'periodo': '00-12'},
#   {'value': '', 'periodo': '12-24'},
#   {'value': '', 'periodo': '00-06'},
#   {'value': '', 'periodo': '06-12'},
#   {'value': '', 'periodo': '12-18'},
#   {'value': '', 'periodo': '18-24'}],
#  'temperatura': {'maxima': 18,
#   'minima': 16,
#   'dato': [{'value': 0, 'hora': 6},
#    {'value': 0, 'hora': 12},
#    {'value': 16, 'hora': 18},
#    {'value': 16, 'hora': 24}]},
#  'sensTermica': {'maxima': 18,
#   'minima': 15,
#   'dato': [{'value': 0, 'hora': 6},
#    {'value': 0, 'hora': 12},
#    {'value': 16, 'hora': 18},
#    {'value': 16, 'hora': 24}]},
#  'humedadRelativa': {'maxima': 90,
#   'minima': 80,
#   'dato': [{'value': 0, 'hora': 6},
#    {'value': 0, 'hora': 12},
#    {'value': 80, 'hora': 18},
#    {'value': 90, 'hora': 24}]},
#  'uvMax': 1,
#  'fecha': '2021-12-28T00:00:00'}

# %% [markdown]
# # Scraping de datos
#
# El siguiente escalón en la lista de métodos para extraer información de páginas web es el scraping de datos.
#
# Con esta técnica, accedemos a una página web y leemos la información que queda visible para un usuario final. Es un método muy poco eficiente y requiere mucho más trabajo que el acceso a un API pero también permite acceder a datos que, de otra forma sería imposible recopilar como, por ejemplo, el precio de los productos de nuestros competidores en un mercado.
#
# Para ello podemos intentar varias técnicas quedándonos con la que sea más sencillo implementar:
#  - Tratar de descargar el contenido de la web y dárselo a **pandas**
#  - Scrapear los datos que necesitamos
#  - Simular un navegador e ir scrapeando los datos que necesitamos
#
# En esta sesión solo veremos las dos primeras, la tercera requiere instalar varias utilidades en el ordenador y no siempre funciona bien.
#
# ## Descargar el contenido y pasárselo a Pandas
#
# En ocasiones, una página web puede no querer colaborar con Pandas y decide no devolverle información, por ejemplo, si vamos a la web:
#   [Finanzas yahoo - BTC vs USD](https://finance.yahoo.com/quote/BTC-USD/history/)
#
# Podemos ver una web normal con información de cotización del Bitcoin en Dólares.
#
# Sin embargo, si se la pedimos a Pandas algo no funciona bien:

# %%
#pd.read_html('https://finance.yahoo.com/quote/BTC-USD/history/')

# %% [markdown]
# Pandas dice que no hay ninguna web con esa dirección.
#
# Podemos probar si requests se lleva mejor con esta página:

# %%
x = requests.get('https://finance.yahoo.com/quote/BTC-USD/history/')
x.content
# Out:
# b'<!DOCTYPE html>\n  <html lang="en-us"><head>\n  <meta http-equiv="content-type" content="text/html; charset=UTF-8">\n      <meta charset="utf-8">\n      <title>Yahoo</title>\n      <meta name="viewport" content="width=device-width,initial-scale=1,minimal-ui">\n      <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">\n      <style>\n  html {\n      height: 100%;\n  }\n  body {\n      background: #fafafc url(https://s.yimg.com/nn/img/sad-panda-201402200631.png) 50% 50%;\n      background-size: cover;\n      height: 100%;\n      text-align: center;\n      font: 300 18px "helvetica neue", helvetica, verdana, tahoma, arial, sans-serif;\n  }\n  table {\n      height: 100%;\n      width: 100%;\n      table-layout: fixed;\n      border-collapse: collapse;\n      border-spacing: 0;\n      border: none;\n  }\n  h1 {\n      font-size: 42px;\n      font-weight: 400;\n      color: #400090;\n  }\n  p {\n      color: #1A1A1A;\n  }\n  #message-1 {\n      font-weight: bold;\n      margin: 0;\n  }\n  #message-2 {\n      display: inline-block;\n      *display: inline;\n      zoom: 1;\n      max-width: 17em;\n      _width: 17em;\n  }\n      </style>\n  <script>\n    document.write(\'<img src="//geo.yahoo.com/b?s=1197757129&t=\'+new Date().getTime()+\'&src=aws&err_url=\'+encodeURIComponent(document.URL)+\'&err=%<pssc>&test=\'+encodeURIComponent(\'%<{Bucket}cqh[:200]>\')+\'" width="0px" height="0px"/>\');var beacon = new Image();beacon.src="//bcn.fp.yahoo.com/p?s=1197757129&t="+new Date().getTime()+"&src=aws&err_url="+encodeURIComponent(document.URL)+"&err=%<pssc>&test="+encodeURIComponent(\'%<{Bucket}cqh[:200]>\');\n  </script>\n  </head>\n  <body>\n  <!-- status code : 404 -->\n  <!-- Not Found on Server -->\n  <table>\n  <tbody><tr>\n      <td>\n      <img src="https://s.yimg.com/rz/p/yahoo_frontpage_en-US_s_f_p_205x58_frontpage.png" alt="Yahoo Logo">\n      <h1 style="margin-top:20px;">Will be right back...</h1>\n      <p id="message-1">Thank you for your patience.</p>\n      <p id="message-2">Our engineers are working quickly to resolve the issue.</p>\n      </td>\n  </tr>\n  </tbody></table>\n  </body></html>'

# %% [markdown]
# Sin entrar a evaluar el contenido en sí mismo, vemos que el método ha fallado.
#
# Si para la página inicial de Google necesitamos 5 páginas de papel parece obvio que, para la cotización de Bitcoin de varios días, necesitaremos más texto que el que nos ha devuelto esta Yahoo.
#
# En este caso, la experiencia al tratar de extraer datos de páginas web es importante y nos dice que, lo más probable, es que Yahoo se esté dando cuenta de que no estamos accediendo desde un navegador de verdad y por eso no quiera mostrar la información real.
#
# Podemos prometerle a Yahoo que, realmente, aunque parezcamos código de Python, somos un navegador Google Chrome. En este caso es necesario darle esa información por escrito en forma de **headers** que, como ya hemos visto, son la forma que tenemos de decirle a un servidor web cosas de nosotros mismos (nuestros metadatos).
#
# En este caso  pondremos un User-Agent (el identificador del navegador) obtenido de: https://www.whatismybrowser.com/guides/the-latest-user-agent/chrome Aunque, la forma más segura de obtener un User-Agent actualizado, es mediante F12 en Chrome.
#
# Utilizar un User-Agent nos hará pasarnos por el navegador que nosotros queramos, cuando una página web nos deniega el acceso, cambiar de User-Agent suele ayudar a que piense que somos alguien diferente.

# %%
import requests
import pandas as pd
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.93 Safari/537.36'}
x = requests.get('https://finance.yahoo.com/quote/BTC-USD/history/', headers=headers)

pd.read_html(x.content)[0]
# Out:
#                                                   Date  \
# 0                                         Dec 29, 2021
# 1                                         Dec 28, 2021
# 2                                         Dec 27, 2021
# 3                                         Dec 26, 2021
# 4                                         Dec 25, 2021
# ..                                                 ...
# 96                                        Sep 24, 2021
# 97                                        Sep 23, 2021
# 98                                        Sep 22, 2021
# 99                                        Sep 21, 2021
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 0                                             47576.86
# 1                                                    -
# 2                                             50802.61
# 3                                             50428.69
# 4                                             50854.92
# ..                                                 ...
# 96                                            44894.30
# 97                                            43560.30
# 98                                            40677.95
# 99                                            43012.23
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   High  \
# 0                                             47982.23
# 1                                                    -
# 2                                             51956.33
# 3                                             51196.38
# 4                                             51176.60
# ..                                                 ...
# 96                                            45080.49
# 97                                            44942.18
# 98                                            43978.62
# 99                                            43607.61
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                    Low  \
# 0                                             47576.86
# 1                                                    -
# 2                                             50499.47
# 3                                             49623.11
# 4                                             50236.71
# ..                                                 ...
# 96                                            40936.56
# 97                                            43109.34
# 98                                            40625.63
# 99                                            39787.61
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Close*  \
# 0                                             47982.23
# 1                                                    -
# 2                                             50640.42
# 3                                             50809.52
# 4                                             50429.86
# ..                                                 ...
# 96                                            42839.75
# 97                                            44895.10
# 98                                            43574.51
# 99                                            40693.68
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                            Adj Close**  \
# 0                                             47982.23
# 1                                                    -
# 2                                             50640.42
# 3                                             50809.52
# 4                                             50429.86
# ..                                                 ...
# 96                                            42839.75
# 97                                            44895.10
# 98                                            43574.51
# 99                                            40693.68
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Volume
# 0                                          32707647488
# 1                                                    -
# 2                                          24324345758
# 3                                          20964372926
# 4                                          19030650914
# ..                                                 ...
# 96                                         42839345714
# 97                                         34244064430
# 98                                         38139709246
# 99                                         48701090088
# 100  *Close price adjusted for splits.**Adjusted cl...
#
# [101 rows x 7 columns]

# %% [markdown]
# Parece que, para obtener datos de Yahoo, ha sido suficiente con esto.

# %% [markdown]
# ### Ejercicio 6, mayor diferencial en Ethereum
#
# Partiendo del ejemplo anterior, descarga los datos de cotización de **Ethereum** (ETH) frente a Euro (EUR) y localiza el día en el que el diferencial entre el High y el Low ha sido más alto.

# %%
import requests
import pandas as pd
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.93 Safari/537.36'}
x = requests.get('https://finance.yahoo.com/quote/ETH-USD/history/', headers=headers)

eth = pd.read_html(x.content)[0]
eth
# Out:
#                                                   Date  \
# 0                                         Dec 29, 2021
# 1                                         Dec 28, 2021
# 2                                         Dec 27, 2021
# 3                                         Dec 26, 2021
# 4                                         Dec 25, 2021
# ..                                                 ...
# 96                                        Sep 24, 2021
# 97                                        Sep 23, 2021
# 98                                        Sep 22, 2021
# 99                                        Sep 21, 2021
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   Open  \
# 0                                              3793.41
# 1                                                    -
# 2                                              4064.75
# 3                                              4094.15
# 4                                              4049.78
# ..                                                 ...
# 96                                             3154.56
# 97                                             3077.97
# 98                                             2763.21
# 99                                             2977.31
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                   High  \
# 0                                              3826.90
# 1                                                    -
# 2                                              4126.00
# 3                                              4105.02
# 4                                              4138.56
# ..                                                 ...
# 96                                             3159.64
# 97                                             3173.54
# 98                                             3089.08
# 99                                             3101.70
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                    Low  \
# 0                                              3793.41
# 1                                                    -
# 2                                              4033.49
# 3                                              4013.03
# 4                                              4027.93
# ..                                                 ...
# 96                                             2747.34
# 97                                             3038.10
# 98                                             2741.44
# 99                                             2676.41
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Close*  \
# 0                                              3826.90
# 1                                                    -
# 2                                              4037.55
# 3                                              4067.33
# 4                                              4093.28
# ..                                                 ...
# 96                                             2931.67
# 97                                             3155.52
# 98                                             3077.87
# 99                                             2764.43
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                            Adj Close**  \
# 0                                              3826.90
# 1                                                    -
# 2                                              4037.55
# 3                                              4067.33
# 4                                              4093.28
# ..                                                 ...
# 96                                             2931.67
# 97                                             3155.52
# 98                                             3077.87
# 99                                             2764.43
# 100  *Close price adjusted for splits.**Adjusted cl...
#
#                                                 Volume
# 0                                          16977080320
# 1                                                    -
# 2                                          11424360002
# 3                                          11197244172
# 4                                          10894785525
# ..                                                 ...
# 96                                         25595422789
# 97                                         18516291047
# 98                                         23742102645
# 99                                         30405062665
# 100  *Close price adjusted for splits.**Adjusted cl...
#
# [101 rows x 7 columns]

# %% [markdown]
# ## Scraping de datos: Requests + BeautifulSoup
#
# Hasta ahora hemos utilizado Requests como una forma de interactuar con servidores que tienen información estructurada, ya sea mediante API o mediante tablas.
#
# Sin embargo, la información en Internet no está siempre tan bien organizada y los datos necesitan limpiarse antes de pasarse a pandas.
#
# **BeautifulSoup** es la librería con nombre estúpido que se encargará de ayudarnos en esta tarea.
#
# BeautifulSoup nos ayudará a navegar en todo el conjunto de etiquetas que forman una página web y que, en la peor época en cuánto a estándares de internet, se llamó **tag-soup**.

# %% [markdown]
# Podemos ver el código que forma una página web, si vamos a "www.elconfidencial.com" y pulsamos F12 (en chrome), se abre una ventana con el siguiente aspecto:
#
# ![Dev_tools](./images/Dev-tools.png)
#
# Si pulsamos en el botón en la flecha situada arriba a la izquierda en la imagen anterior y en un titular del periódico:
#
# ![titular](./images/seleccionar_titular.png)
#
#
# nos abre la siguiente información:
#
# ![Dev tools2](./images/Dev-tools2.png)
#
# Aquí, podemos ver las etiquetas (entre símbolos de mayor y menor) que componen la "sopa" a la que hace referencia BeautifulSoup.
#
# Entre toda la maraña de cosas que salen podemos fijarnos en ```<h3 class="art-tit" typetitle="tsmall">```, sin entrar en detalles del código html, la referencia ```h3``` quiere decir que es un encabezado y, la **clase** nos dice el aspecto que tiene (la clase de un elemento de un página web decide su color, tipo de fuente, espaciado, ... todas sus características visuales).
#
# En este caso vamos a utilizar esa clase **art-tit** para intentar extraer todos los titulares de la página principal de ElConfidencial:

# %%
import requests

el_confidencial = requests.get('https://www.elconfidencial.com')
pagina_principal = el_confidencial.content

print(f'La página principal tiene: {len(pagina_principal)} caracteres, los 1000 primeros son:\n\n {pagina_principal[:1000]}')
# Out:
# La página principal tiene: 423757 caracteres, los 1000 primeros son:
#
#  b'<!DOCTYPE html><html lang="es"><head><link rel="dns-prefetch" href="https://bc.marfeelcache.com" /><link rel="preload" as="script" href="https://bc.marfeelcache.com/statics/marfeel/gardac-sync.js" crossorigin="crossorigin" /><script data-mrf-script="garda" data-mrf-dt="1" data-mrf-host="titania.marfeel.com" src="https://bc.marfeelcache.com/statics/marfeel/gardac-sync.js"></script><script type="application/json" id="EC_hosts">{"name": "El confidencial","id": "1","enviroment": "production","host": "www.elconfidencial.com","api": "api.elconfidencial.com","secure": "secure.elconfidencial.com","image": ""}</script><meta http-equiv="Content-Type" content="text/html; charset=utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><!--[if IE 8]><script src="/javascript/v2/plugins/html5-shim/html5shiv-printshiv.js"></script><![endif]--><title>El Confidencial - El diario de los lectores influyentes</title><meta name="msapplication-config" content="none"/><meta name="verify-v1" content="zaF'

# %% [markdown]
# Para trabajar con estos 450.000 caracteres, delegaremos en BeautifulSoup:

# %%
from bs4 import BeautifulSoup

doc = BeautifulSoup(pagina_principal)

# %% [markdown]
# Esto crea, en nuestro ordenador, un **objeto** de BeautifulSoup al que podemos hacerle peticiones.
#
# Al igual que con las API, hay muchísimas vías que se pueden explorar pero, por centrarnos en una, encontraremos objetos por su clase:

# %%
tit = doc.find_all(attrs={'class':'art-tit'})
tit[:100]
# Out:
# [<h3 class="art-tit fs-60" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Sánchez aleja las restricciones comunes a la espera de otra reunión con las CCAA" href="https://www.elconfidencial.com/espana/2021-12-28/sanchez-restricciones-nochevieja-reunion-ccaa_3350676/" title="Sánchez aleja las restricciones comunes a la espera de otra reunión con las CCAA">Sánchez aleja las restricciones comunes <br/>a la espera de otra reunión con las CCAA</a></h3>,
#  <h3 class="art-tit fs-26" typetitle="tnormal"><a class="art-tit-link tit-color" data-title="España registra un nuevo récord de incidencia (1.360) y otro de contagios (99.671)" href="https://www.elconfidencial.com/espana/2021-12-28/coronavirus-datos-sanidad-incidencia-contagios-fallecimientos-28diciembre_3350837/" title="España registra un nuevo récord de incidencia (1.360) y otro de contagios (99.671)">España registra un nuevo récord de incidencia (1.360) y otro de contagios (99.671)</a></h3>,
#  <h3 class="art-tit fs-26" typetitle="tnormal"><a class="art-tit-link tit-color" data-title="Con la tercera dosis sin poner, cada vez más países se lanzan a por la cuarta" href="https://www.elconfidencial.com/mundo/2021-12-28/paises-cuarta-dosis-coronavirus_3350356/" title="Con la tercera dosis sin poner, cada vez más países se lanzan a por la cuarta">Con la tercera dosis sin poner, cada <br/>vez más países se lanzan a por la cuarta</a></h3>,
#  <h3 class="art-tit" typetitle="tnormal"><a class="art-tit-link tit-color" data-title="Directo | Euskadi cierra el ocio a la 1:00: 9 regiones, con límites horarios" href="https://www.elconfidencial.com/espana/2021-12-28/ultima-hora-coronavirus-covid-omicron-restricciones-vacuna-nochevieja_3337652/" title="Directo | Euskadi cierra el ocio a la 1:00: 9 regiones, con límites horarios"><b><br/>Directo | </b>Euskadi cierra el ocio a la 1:00: 9 regiones, con límites horarios</a></h3>,
#  <h3 class="art-tit" typetitle="tnormal"><a class="art-tit-link tit-color" data-title="Madrid y Andalucía apoyan estudiar que se baje la cuarentena" href="https://www.elconfidencial.com/espana/madrid/2021-12-28/la-comunidad-de-madrid-abre-la-puerta-a-reducir-los-10-dias-de-cuarentena_3350430/" title="Madrid y Andalucía apoyan estudiar que se rebaje la cuarentena de 10 días"><br/>Madrid y Andalucía apoyan estudiar que se rebaje la cuarentena de 10 días</a></h3>,
#  <h3 class="art-tit" typetitle="tnormal"><a class="art-tit-link tit-color" data-title="Despido de sanitarios pese al menor déficit" href="https://www.elconfidencial.com/economia/2021-12-28/pandemia-ccaa-gastos-sanitario-despidos-deficit_3350231/" title="Las comunidades despedirán a miles de sanitarios pese al menor déficit">Las comunidades despedirán a miles de sanitarios pese al menor déficit</a></h3>,
#  <h3 class="art-tit fs-40" typetitle="tmedium"><a class="art-tit-link tit-color" data-title="El Gobierno da tres meses a las empresas para adoptar la nueva regla de temporalidad" href="https://www.elconfidencial.com/espana/2021-12-28/el-gobierno-da-tres-meses-a-las-empresas-para-adoptar-la-nueva-regla-de-temporalidad_3350494/" title="Moncloa da tres meses a las empresas para que adopten la nueva regla de temporalidad">Moncloa da tres meses a las empresas para que adopten la nueva regla de temporalidad</a></h3>,
#  <h3 class="art-tit fs-24" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Un Gobierno agotadoy el primer mitinelectoral de Sánchez" href="https://blogs.elconfidencial.com/espana/notebook/2021-12-28/fin-legislatura-presupuestos-mitin-sanchez_3350040/" title="Un Gobierno agotadoy el primer mitinelectoral de Sánchez"><i>Un Gobierno agotado<br/>y el primer mitin<br/>electoral de Sánchez</i></a></h3>,
#  <h3 class="art-tit fs-27" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Sánchez saca los PGE entre serios avisos de sus socios por la reforma laboral" href="https://www.elconfidencial.com/espana/2021-12-28/sanchez-pge-reforma-laboral-congreso_3350506/" title="El presidente saca los PGE entre serios avisos de sus socios por la reforma laboral">El presidente saca los PGE entre serios avisos de sus socios por la reforma laboral</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="ERC busca acomodo para Trapero tras haberle destituido" href="https://www.elconfidencial.com/espana/cataluna/2021-12-28/erc-acomodo-trapero-mossos-tras-destituido_3350678/" title="ERC busca ahora un acomodo a Trapero en los Mossos tras haberlo destituido">ERC busca ahora un acomodo a Trapero <br/>en los Mossos tras haberlo destituido</a></h3>,
#  <h3 class="art-tit fs-27" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="La Justicia belga rechaza la entrega de Valtònyc a España" href="https://www.elconfidencial.com/espana/2021-12-28/justicia-belga-rechaza-entrega-valtonyc-espana-delito-amenazas_3350345/" title="La Justicia belga rechaza la entrega del rapero Valtònyc a España por amenazas">La Justicia belga rechaza la entrega del rapero Valtònyc a España por amenazas</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="El Gobierno condecora a 23 exministros como Gallardón, Iglesias y Ábalos" href="https://www.elconfidencial.com/espana/2021-12-28/gobierno-condecora-23-exministros_3350806/" title="El Gobierno condecora a 23 exministros: Iglesias, Gallardón, Ábalos...">El Gobierno condecora <br/>a 23 exministros: Iglesias, Gallardón, Ábalos...</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="El Estado podrá disponer de recursos estratégicos en caso de emergencia" href="https://www.elconfidencial.com/espana/2021-12-28/estado-ley-seguridad-nacional-recursos-estrategidos_3350832/" title="El Estado podrá disponer de recursos estratégicos en caso de emergencia">El Estado podrá disponer de recursos estratégicos en caso de emergencia</a></h3>,
#  <h3 class="art-tit" typetitle="tnormal"><a class="art-tit-link tit-color" data-title="Las zonas rurales: entre la fatalidad y la beligerancia" href="https://www.elconfidencial.com/espana/2021-12-28/espana-vacia-fatalidad-beligerancia_3340080/" title="Viaje a las zonas rurales despobladas: entre la fatalidad y la beligerancia">Viaje a las zonas rurales despobladas: entre la fatalidad y la beligerancia</a></h3>,
#  <h3 class="art-tit fs-27" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Cs 'protege' a la consejera andaluza imputada hasta confirmar los hechos" href="https://www.elconfidencial.com/espana/andalucia/2021-12-28/ciudadanos-andalucia-imputacion-carmen-crespo-pp_3350433/" title="Cs protege a la consejera andaluza imputada hasta confirmar los hechos">Cs 'protege' a la consejera andaluza imputada hasta confirmar los hechos</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="El Gobierno deja en un limbo jurídico el archipiélago español de las Chafarinas" href="https://www.elconfidencial.com/espana/2021-12-28/gobierno-inocentada-pp-limbo-juridico-archipielago-espanol-chafarinas-marruecos-piscifactoria_3350432/" title="Moncloa deja en un limbo jurídico el archipiélago español de las Chafarinas">Moncloa deja en un limbo jurídico el archipiélago español de las Chafarinas</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="La AUGC se querella contra dos diputados de Vox en Ceuta por &amp;quot;insultos gravísimos&amp;quot;" href="https://www.elconfidencial.com/espana/2021-12-28/guardia-civil-querella-vox-ceuta-insultos_3350848/" title="La AUGC se querella contra dos diputados de Vox en Ceuta por insultos gravísimos">La AUGC se querella contra dos diputados de Vox en Ceuta por "insultos gravísimos"</a></h3>,
#  <h3 class="art-tit fs-23" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Fallece el empresario José María Aldaya, secuestrado por ETA en 1995" href="https://www.elconfidencial.com/espana/pais-vasco/2021-12-28/muere-aldaya-secuestrado-eta_3350843/" title="Muere el empresario José María Aldaya, secuestrado por ETA en el año 1995">Muere el empresario José María Aldaya, secuestrado por ETA en el año 1995</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Víctimas piden prohibir la marcha de apoyo a Parot y a otros dos etarras" href="https://www.elconfidencial.com/espana/pais-vasco/2021-12-28/victimas-piden-prohibir-marcha-apoyo-parot-eta_3350814/" title="Víctimas piden prohibir la marcha de apoyo a Henri Parot y a otros dos etarras">Víctimas piden prohibir la marcha de apoyo a Henri Parot y a otros dos etarras</a></h3>,
#  <h3 class="art-tit fs-23" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Medel aprueba sus consejeros con un tercio del patronato en contra" href="https://www.elconfidencial.com/empresas/2021-12-28/medel-aprueba-consejeros-unicaja-tercio-patronato-contra_3350657/" title="Braulio Medel aprueba sus consejeros con un tercio del patronato en contra">Braulio Medel aprueba sus consejeros con un tercio del patronato en contra</a></h3>,
#  <h3 class="art-tit fs-26" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Los dueños de Mayoral suben al 7,6% y piden una silla" href="https://www.elconfidencial.com/empresas/2021-12-28/duenos-mayoral-suben-unicaja-reclaman-silla-consejo_3350537/" title="Los dueños de Mayoral suben al 7,6% en el banco y reclaman una silla del consejo">Los dueños de Mayoral suben al 7,6% en el banco y reclaman una silla del consejo</a></h3>,
#  <h3 class="art-tit fs-27" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Por qué los españoles se van de Erasmus a Polonia y los alemanes a Irlanda" href="https://www.elconfidencial.com/mundo/europa/2021-12-28/erasmus-dos-velocidades-programa-ue-desigualdad_3348913/" title="Por qué los españoles se van de Erasmus a Polonia y los alemanes a Irlanda">Por qué los españoles se van de Erasmus <br/>a Polonia y los alemanes a Irlanda</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="España remite su plan para la PAC: 47.724 M hasta 2027" href="https://www.elconfidencial.com/economia/2021-12-28/plan-pac-bruselas-consejo-ministros_3350498/" title="España remite a Bruselas su plan para la PAC, dotado con 47.724 millones hasta 2027">España remite a Bruselas su plan para la PAC, dotado con 47.724 millones hasta 2027</a></h3>,
#  <h3 class="art-tit fs-23" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Varo y la rescatada Pachá se asocian para montar el mayor club de lujo de España" href="https://www.elconfidencial.com/empresas/2021-12-28/rosauro-varo-pacha-mayor-club-lujo-espana_3349954/" title="Varo y la rescatada Pachá se asocian para montar el mayor club de lujo español">Varo y la rescatada Pachá se asocian para montar el mayor club de lujo español</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Telefónica: golpe de 1.500 M por recortar 2.700 empleos " href="https://www.elconfidencial.com/empresas/2021-12-28/telefonica-recorte-empleos-coste_3350394/" title="Telefónica asume un golpe de 1.500 millones por el recorte de 2.700 empleos ">Telefónica asume un golpe de 1.500 millones por el recorte de 2.700 empleos </a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Mayor transparencia, escucha activa... Los retos de las empresas en 2022" href="https://www.elconfidencial.com/empresas/2021-12-28/propositos-ano-nuevo-bra-empresas-2022_3348712/" title="Mayor transparencia, escucha activa... Los retos de las empresas en 2022">Mayor transparencia, escucha activa... Los retos de las empresas en 2022</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="La fiebre solar de Florentino Pérez llega a Valencia" href="https://www.elconfidencial.com/empresas/2021-12-28/florentino-perez-fotovoltaica-requena-alicante-acs_3350105/" title="Primero Alicante, ahora Requena: la fiebre solar de Florentino Pérez llega a Valencia">Primero Alicante, ahora Requena: la fiebre solar de Florentino Pérez llega a Valencia</a></h3>,
#  <h3 class="art-tit fs-26" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Descartan la explosión como causa de las muertes en un bar de Parla" href="https://www.elconfidencial.com/espana/madrid/2021-12-28/dos-muertos-bar-parla-madrid-explosion_3350681/" title="Descartan la explosión como causa de las dos muertes en Parla tras hallar restos de sangre">Descartan la explosión como causa de las dos muertes en Parla tras hallar restos de sangre</a></h3>,
#  <h3 class="art-tit fs-26" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Un arcoíris de drogas para las zonas de ambiente de Torremolinos" href="https://www.elconfidencial.com/espana/andalucia/2021-12-28/drogas-policia-torremolinos-malaga_3350550/" title="Cocaína rosa, éxtasis marrón: arcoíris de drogas para las zonas gais de Torremolinos">Cocaína rosa, éxtasis marrón: arcoíris de drogas para las zonas gais de Torremolinos</a></h3>,
#  <h3 class="art-tit fs-23" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="OTAN pide a Rusia una reunión el 12 de enero por Ucrania" href="https://www.elconfidencial.com/mundo/europa/2021-12-28/otan-rusia-amenaza-invasion-ucrania-reunion_3350810/" title="La OTAN pide a Rusia una reunión el 12 de enero por la amenaza a Ucrania">La OTAN pide a Rusia una reunión el 12 de enero por la amenaza a Ucrania</a></h3>,
#  <h3 class="art-tit fs-27" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Bromas para mandar por WhatsApp en el día de los Inocentes" href="https://www.elconfidencial.com/alma-corazon-vida/2021-12-28/bromas-whatsapp-santos-inocentes_2888208/" title="Siete bromas que puedes enviar por WhatsApp durante el día de los Inocentes">Siete bromas que puedes enviar por WhatsApp durante el día de los Inocentes</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Dos detenidos por la muerte del ex-CEO de Barreras en el Hotel Palace de Madrid" href="https://www.elconfidencial.com/espana/madrid/2021-12-28/detenidos-homicidio-hotel-palace-de-madrid_3350370/" title="Dos detenidos por la muerte del ex-CEO de Barreras en el Palace">Dos detenidos por la muerte del ex-CEO de Barreras en el Palace</a></h3>,
#  <h3 class="art-tit fs-26" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Desvelan digitalmente los secretos de la momia del faraón Amenhotep I" href="https://www.elconfidencial.com/cultura/2021-12-28/descubre-los-secretos-de-una-momia_3350320/" title="Desvelan los secretos de la momia del faraón Amenhotep I desenvolviéndola digitalmente">Desvelan los secretos de la momia del faraón Amenhotep I "desenvolviéndola" digitalmente</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="¿Burbuja en China? 27 años de ingresos para comprar casa" href="https://www.elconfidencial.com/mercados/2021-12-28/burbuja-inmobiliaria-china-mutuactivos-bra_3349978/" title="¿Burbuja en China? 27 años de ingresos para comprar una casa">¿Burbuja en China? 27 años de ingresos para comprar una casa</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Bardem y Amaral premiados con la Medalla Bellas Artes" href="https://www.elconfidencial.com/cultura/2021-12-28/bardem-amaral-premio-medalla-oro-bellas-artes_3350682/" title="Javier Bardem y Amaral premiados con la Medalla de Oro de las Bellas Artes">Javier Bardem y Amaral premiados con la Medalla de Oro de las Bellas Artes</a></h3>,
#  <h3 class="art-tit fs-24" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Debo dos meses de hipoteca después de 16 años pagando y ahora no tengo ingresos" href="https://blogs.elconfidencial.com/vivienda/consultorio-inmobiliario/2021-12-28/hipoteca-morosidad-embargo-deudas_3348395/" title="Debo dos meses de hipoteca después de 16 años y no tengo ingresos">Debo dos meses de hipoteca después de 16 años y no tengo ingresos</a></h3>,
#  <h3 class="art-tit fs-23" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Vittoria de Saboya:  los 18 de una 'reina' sin trono, pero con corona de 'influencer'" href="https://www.vanitatis.elconfidencial.com/casas-reales/2021-12-28/vittoria-saboya-reina-sin-trono-influencer_3350402/" title="Vittoria de Saboya: los 18 de una reina sin trono, pero con corona de influencer">Vittoria de Saboya: los 18 de una 'reina' sin trono, pero con corona de 'influencer'</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="La &amp;#039;newsletter&amp;#039; de EC Jurídico: las mejores noticias, en tu móvil" href="https://www.elconfidencial.com/juridico/2021-09-21/suscribete-newsletter-ec-juridico-informaciones_3288366/" title="Suscríbete a la newsletter de EC Jurídico: la mejor información, en tu móvil">Suscríbete a la 'newsletter' de EC Jurídico: la mejor información, en tu móvil</a></h3>,
#  <h3 class="art-tit fs-26" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="OHLA alcanza máximos tras recibir 162 M de la CAM" href="https://www.elconfidencial.com/empresas/2021-12-28/ohla-cam-tren-navalcarnero_3350431/" title="OHLA alcanza máximos en la pandemia tras recibir 162 M de la Comunidad de Madrid">OHLA alcanza máximos en la pandemia tras recibir 162 M de la Comunidad de Madrid</a></h3>,
#  <h3 class="art-tit fs-22" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="El mineral de hierro se hunde ante la caída en China" href="https://www.elconfidencial.com/mercados/2021-12-28/el-precio-del-mineral-de-hierro-se-desploma-ante-el-descenso-de-la-produccion-en-china_3350649/" title="El mineral de hierro se hunde ante la caída de la producción en China">El mineral de hierro se hunde ante la caída de la producción en China</a></h3>,
#  <h3 class="art-tit fs-23" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Cepsa ficha a la directora financiera de Gestamp" href="https://www.elconfidencial.com/empresas/2021-12-28/cepsa-ficha-a-la-directora-financiera-de-gestamp_3350663/" title="Cepsa ficha a la directora financiera de Gestamp">Cepsa ficha a la directora financiera de Gestamp</a></h3>,
#  <h3 class="art-tit fs-23" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Cómo combate LaLiga la piratería audiovisual" href="https://www.elconfidencial.com/economia/2021-12-28/pirateria-laliga-futbol-emisiones-deportivas-bra_3345398/" title="Cómo combate LaLiga la piratería audiovisual">Cómo combate LaLiga la piratería audiovisual</a></h3>,
#  <h3 class="art-tit fs-22" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="El auge de las megaempresas, ¿malo para los inversores?" href="https://www.elconfidencial.com/mercados/the-wall-street-journal/2021-12-28/mercados-megaempresas-apple-amazon-inversores_3349918/" title="El auge de las megaempresas: ¿malo para los inversores?">El auge de las megaempresas: ¿malo para los inversores?</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Lío en la abogacía: la salida del socio de Ashurst para fichar por Eversheds" href="https://www.elconfidencial.com/juridico/2021-12-28/polemica-salida-socio-ashurst-ficha-eversheds_3349884/" title="Lío en la abogacía: la polémica salida del socio de Ashurst para fichar por Eversheds">Lío en la abogacía: la polémica salida del socio de Ashurst para fichar por Eversheds</a></h3>,
#  <h3 class="art-tit fs-20" typetitle="tnormal"><a class="art-tit-link tit-color" data-title='Adán: "Es populista pedir un Registro Mercantil gratuito"' href="https://www.elconfidencial.com/juridico/2021-12-28/entrevista-maria-emilia-adan_3349772/" title="Adán: Es populista pedir un Registro Mercantil gratuito">Adán: "Es populista pedir un Registro Mercantil gratuito"</a></h3>,
#  <h3 class="art-tit fs-20" typetitle="tnormal"><a class="art-tit-link tit-color" data-title="Uría Menéndez nombra seis nuevos socios" href="https://www.elconfidencial.com/juridico/2021-12-28/uria-menendez-nombra-seis-nuevos-socios_3350074/" title="Uría Menéndez nombraseis nuevos socios"><h1 class="landscapePhotoRight__title">Uría Menéndez nombra<br/>seis nuevos socios</h1></a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="China acusa a SpaceX de poner en peligro su estación espacial" href="https://www.elconfidencial.com/tecnologia/novaceno/2021-12-28/china-acusa-spacex-poner-peligro-estacion-espacial_3350435/" title="China acusa a SpaceX de poner en peligro su estación espacial">China acusa a SpaceX de poner <br/>en peligro su estación espacial</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="La 'Dama de Hierro' que puede tumbar a Macron no se apellida Le Pen" href="https://www.elconfidencial.com/mundo/europa/2021-12-28/valerie-pecresse-francia-elecciones-rival-macron_3343559/" title="La Dama de Hierro que puedetumbar a Macron no se apellida Le Pen">La 'Dama de Hierro' que puede<br/>tumbar a Macron no se apellida Le Pen</a></h3>,
#  <h3 class="art-tit" typetitle="tnormal"><a class="art-tit-link tit-color" data-title="Pepa Rus: &quot;Es difícil desprenderse de la Macu de 'Aída'... por suerte&quot;" href="https://www.elconfidencial.com/cultura/2021-12-28/pepa-rus-teatro-macu-aida_3348843/" title="Pepa Rus: Es difícil desprenderse de la Macu de Aída... por suerte">Pepa Rus: "Es difícil desprenderse <br/>de la Macu de 'Aída'... por suerte"</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Tres claves para recuperar tu sexualidad en Navidad" href="https://www.alimente.elconfidencial.com/bienestar/2021-12-28/claves-recuperar-sexualidad-navidad_3349438/" title="Tres claves para recuperartu sexualidad en Navidad">Tres claves para recuperar<br/>tu sexualidad en Navidad</a></h3>,
#  <h3 class="art-tit fs-20" typetitle="tnormal"><a class="art-tit-link tit-color" data-title="Las sopas depurativas para eliminar los excesos " href="https://www.alimente.elconfidencial.com/nutricion/2021-12-28/sopas-depurativas-excesos-culinarios_1620705/" title="Las sopas depurativas que eliminan los excesos ">Las sopas depurativas <br/>que eliminan los excesos </a></h3>,
#  <h3 class="art-tit fs-20" typetitle="tnormal"><a class="art-tit-link tit-color" data-title="Una pastilla para el dolor sin efectos secundarios" href="https://www.alimente.elconfidencial.com/bienestar/2021-12-28/llega-un-nuevo-analgesico-y-antiinflamatorio-pero-sin-efectos-secundarios_3349951/" title="Una pastilla para el dolor sin efectos secundarios">Una pastilla para el dolor <br/>sin efectos secundarios</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Ni 'aliens' ni apocalipsis: por esto está el cielo morado en Madrid" href="https://www.elconfidencial.com/espana/madrid/2021-12-28/cielo-morado-en-madrid-ni-alliens-ni-fenomenos-apocalipticos_3350277/" title="Ni aliens ni fenómenos apocalípticos: por esto está el cielo morado en Madrid">Ni 'aliens' ni fenómenos apocalípticos: por esto está <br/>el cielo morado en Madrid</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title='Estafa en Nochevieja: "Pagué 105€ y no tengo las entradas"' href="https://www.elconfidencial.com/espana/madrid/2021-12-27/estafa-entradas-nochevieja-incertidumbre_3350006/" title="Incertidumbre y estafa en las fiestas de Nochevieja: Pagué 105€ y no tengo las entradas">Incertidumbre y estafa en las fiestas de Nochevieja: "Pagué 105€ y no tengo las entradas"</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Navidades con cine de espíritu lisérgico en la Filmoteca " href="https://www.elconfidencial.com/espana/madrid/2021-12-28/navidad-cine-animacion-filmoteca_3350255/" title="La película que ha estado oculta durante 69 años se proyectará en la Filmoteca">La película que ha estado oculta durante 69 años se proyectará en la Filmoteca</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="En el Ártico, las lluvias serán más comunes que las nevadas" href="https://www.elconfidencial.com/medioambiente/clima/2021-12-28/artico-lluvias-nevadas-cambio-climatico_3350007/" title="En el Ártico lloverá por primera vez en lugares donde solo caían nevadas">En el Ártico lloverá por primera vez en lugares <br/>donde solo caían nevadas</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Muere Edward O. Wilson, padre de la biología moderna" href="https://www.elconfidencial.com/medioambiente/naturaleza/2021-12-27/fallece-edward-o-wilson-biologia-biodiversidad_3350035/" title="Muere el naturalista Edward O. Wilson, uno de los padres de la biología moderna">Muere el naturalista Edward O. Wilson, uno de los padres de la biología moderna</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="2021, el año en que se confirmó la emergencia climática" href="https://www.elconfidencial.com/medioambiente/clima/2021-12-28/advertencias-climaticas-2021-retrospectiva_3349998/" title="2021, el año en que las advertencias climáticasse hicieron patentes">2021, el año en que las advertencias climáticas<br/>se hicieron patentes</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Efecto &amp;#039;Dracon&amp;#039;: ¿puede el pacto entre Draghi y Macron redefinir la Unión Europea?" href="https://www.elconfidencial.com/mundo/europa/2021-12-28/pacto-italia-francia-quirinal-draghi-macron-ue_3340393/" title="Efecto Dracon: ¿puede el pacto entre Draghi y Macron redefinir la UE?">Efecto 'Dracon': ¿puede el pacto entre Draghi y Macron redefinir la UE?</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Rusia cierra Memorial, que estudiaba la represión soviética" href="https://www.elconfidencial.com/mundo/2021-12-28/rusia-ordena-el-cierre-de-memorial-la-ong-pro-derechos-humanos-mas-antigua-del-pais_3350446/" title="Rusia ordena el cierre de Memorial, ONG que estudiaba la represión soviética"><br/>Rusia ordena el cierre de Memorial, ONG que estudiaba la represión soviética</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Ni los mormones tienen ya suficientes hijos" href="https://www.elconfidencial.com/mundo/2021-12-27/invierno-demografia-inmigracion_3348651/" title="El invierno de la especie se acelera: ni los mormones tienen ya suficientes hijos">El invierno de la especie se acelera: ni los mormones tienen ya suficientes hijos</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Suben a casi 400 los muertos por el devastador tifón Rai en Filipinas" href="https://www.elconfidencial.com/mundo/2021-12-28/suben-a-casi-400-los-muertos-por-el-devastador-tifon-rai-en-filipinas_3350334/" title="Suben a casi 400 los muertos por el devastador tifón Rai en Filipinas">Suben a casi 400 los muertos por el devastador tifón Rai en Filipinas</a></h3>,
#  <h3 class="art-tit fs-21" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Felices fiestas desde la tierra donde no hay Navidad" href="https://blogs.elconfidencial.com/mundo/en-itinerancia/2021-12-27/como-celebran-la-navidad-en-china-y-asia_3348529/" title="Felices fiestas desde la tierra donde no hay Navidad">Felices fiestas desde la tierra donde no hay Navidad</a></h3>,
#  <h3 class="art-tit fs-21" typetitle="tsmall"><a class="art-tit-link tit-color" data-title='China se niega a convivir con el covid: "¿Qué es ómicron?"' href="https://www.elconfidencial.com/mundo/2021-12-26/china-restricciones-coronavirus-omicron-covid-cero_3348741/" title="China se niega a convivir con el covid: ¿Qué es ómicron?">China se niega a convivir con el covid: "¿Qué es ómicron?"</a></h3>,
#  <h3 class="art-tit fs-21" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Todos los milagros que nos dejamos en Afganistán" href="https://www.elconfidencial.com/mundo/2021-12-26/interpretes-afganos-ejercito-espanol-talibanes_3345514/" title="Lo que nos dejamos en Afganistán: Llegaron la mitad de las familias">Lo que nos dejamos en Afganistán: "Llegaron la mitad de las familias"</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="No me cuentes tantas películas en 2022 " href="https://blogs.elconfidencial.com/cultura/el-erizo-y-el-zorro/2021-12-28/un-2022-menos-ficcion_3349862/" title="No me cuentes tantas películasen 2022 "><i><br/>No me cuentes tantas películas<br/>en 2022 </i></a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Muere a los 58 años el director Jean-Marc Vallée " href="https://www.elconfidencial.com/cultura/2021-12-27/muere-director-jean-marc-vallee-director-big-little-lies-dallas-buyers-club-crazy_3349849/" title="Muere el director Jean-Marc Vallée (Big Little Lies)">Muere el director Jean-Marc Vallée <br/>('Big Little Lies')</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Mucho sexo entre 1912 y 1914... y después, guerra" href="https://blogs.elconfidencial.com/cultura/mala-fama/2021-12-27/stefan-zweig-diarios-guerra-mundial_3344458/" title="Mucho sexo entre 1912 y 1914... y después, guerra">Mucho sexo <br/>entre 1912 y 1914... <br/>y después, guerra</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Canibalismo y magia negra: naufragios de las Flotas de Indias" href="https://www.elconfidencial.com/cultura/2021-12-26/naufragios-flota-indias-canibalismo_3346680/" title="Canibalismo y magia negra: los naufragios de las Flotas de Indias ">Canibalismo y magia negra: los naufragios de las Flotas de Indias </a></h3>,
#  <h3 class="art-tit fs-36" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Homeopatía para empresas: los 'gurús' que ganan millones vendiendo incompetencia" href="https://blogs.elconfidencial.com/tecnologia/tribuna/2021-12-27/homeopatia-placebos-gurus-consultoria-productividad_3350078/" title="Homeopatía para empresas: los gurús que ganan millones vendiendo incompetencia"><i>Homeopatía para empresas: los 'gurús' que ganan millones vendiendo incompetencia</i></a></h3>,
#  <h3 class="art-tit fs-26" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="El engaño de una pareja malagueña con los pasaportes covid" href="https://www.elconfidencial.com/tecnologia/2021-12-27/certificado-covid-falso-venta-antivacunas-c2inboss-mjj-csg_3348010/" title="El engaño de una pareja malagueña que vende falsos certificados covid por 350€">El engaño de una pareja malagueña que vende falsos certificados covid por 350€</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="El invento que nos acerca a las centrales eléctricas espaciales" href="https://www.elconfidencial.com/tecnologia/novaceno/2021-12-27/invento-centrales-electricas-espaciales_3350066/" title="El invento que nos acerca a las centrales eléctricas espaciales">El invento que nos acerca a las centrales eléctricas espaciales</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Así serán los siguientes 1.000 años de la humanidad" href="https://www.elconfidencial.com/tecnologia/novaceno/2021-12-27/asi-seran-siguientes-1-000-anos-humanidad_3349275/" title="Así serán los siguientes 1.000 años de la humanidad ">Así serán los siguientes 1.000 años de la humanidad </a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Muere Hugo Maradona, hermano de Diego, a los 52 años por un paro cardíaco" href="https://www.elconfidencial.com/deportes/futbol/2021-12-28/muere-hugo-maradona-hermano-diego-paro-cardiaco_3350478/" title="Muere Hugo Maradona, hermano de Diego, a los 52 años tras sufrir un paro cardíaco">Muere Hugo Maradona, hermano de Diego, a los 52 años tras sufrir un paro cardíaco</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Ya es oficial: Ferran Torres, nuevo jugador del Barça, el elegido para conquistar a Xavi" href="https://www.elconfidencial.com/deportes/futbol/2021-12-28/barca-ferran-torres-xavi-hernandez-guardiola_3350058/" title="Ya es oficial: Ferran Torres, nuevo jugador del Barça, el elegido para conquistar a Xavi">Ya es oficial: Ferran Torres, nuevo jugador del Barça, el elegido para conquistar a Xavi</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title='De los 17 positivos del Rayo Vallecano a Jordi Alba: "Van a jugar los niños de Brunete"' href="https://www.elconfidencial.com/deportes/futbol/liga/2021-12-28/positivos-coronavirus-futbol-espanol-casos_3350397/" title="De los 17 positivos del Rayo Vallecano a Jordi Alba: Van a jugar los niños de Brunete">De los 17 positivos del Rayo Vallecano a Jordi Alba: "Van a jugar los niños de Brunete"</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="A vueltas con la retirada de Lewis Hamilton, protagonista incluso en la derrota" href="https://www.elconfidencial.com/deportes/formula-1/2021-12-28/hamilton-retirada-ecclestone-toto-wolf-formula-1_3350244/" title="A vueltas con la retirada de Lewis Hamilton, protagonista incluso en la derrota">A vueltas con la retirada de Lewis Hamilton, protagonista incluso en la derrota</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="¿Qué tiene de especial el &amp;#039;invento francés&amp;#039; del Dakar para gustar tanto en España?" href="https://www.elconfidencial.com/deportes/formula-1/2021-12-28/dakar-sainz-audi-automovilismo-carrera_3350287/" title="¿Qué tiene de especial el 'invento francés' del Dakar para gustar tanto en España?">¿Qué tiene de especial el 'invento francés' del Dakar para gustar tanto en España?</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Los 10 coches de ocasión favoritos de los españoles en 2021" href="https://www.elconfidencial.com/motor/industria/2021-12-28/ganvam-usados-ocasion-vo-espana-golf-ibiza-leon_3350135/" title="Los 10 coches de ocasión más comprados por los españoles en 2021">Los 10 coches de ocasión más comprados por los españoles en 2021</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Probamos el Porsche Taycan Sport Turismo: matrícula" href="https://www.elconfidencial.com/motor/electricos/2021-12-27/porsche-taycan-sport-turismo-gts-electrico-autonomia_3349421/" title="Probamos el Porsche Taycan Sport Turismo: matrícula">Probamos el Porsche Taycan Sport Turismo: matrícula</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Los 22 coches más seguros probados en 2021 por Euro NCAP" href="https://www.elconfidencial.com/motor/trafico/2021-12-27/seguridad-coches-euroncap-proteccion-vehiculos_3349630/" title="Los 22 coches más seguros probados en 2021 por Euro NCAP">Los 22 coches más seguros probados en 2021 por Euro NCAP</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="El Mercedes-AMG EQS 53 4Matic+ y sus 761 &amp;#039;potros&amp;#039; eléctricos" href="https://www.elconfidencial.com/motor/electricos/2021-12-26/mercedes-benz-amg-eqs-electrico-autonomia_3349423/" title="El Mercedes-AMG EQS 53 4Matic+ y sus 761 potros eléctricos">El Mercedes-AMG EQS 53 4Matic+ y sus 761 'potros' eléctricos</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="La Guardia Civil de Tráfico estrena 301 SUV de motor diésel" href="https://www.elconfidencial.com/motor/trafico/2021-12-28/guardia-civil-trafico-alfa-romeo-stelvio-diesel-patrulla_3350091/" title="La Guardia Civil de Tráfico sí cree en los modelos diésel: 301 unidades del Stelvio">La Guardia Civil de Tráfico sí cree en los modelos diésel: <br/>301 unidades del Stelvio</a></h3>,
#  <h3 class="art-tit fs-24" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Catherine Duleep Singh, la princesa sufragista y lesbiana" href="https://www.elconfidencial.com/alma-corazon-vida/2021-12-28/sufragista-lesbiana-princesa-catherine-duleep-singh_3348093/" title="Una sufragista lesbiana en la corte victoriana: la historia de Catherine Duleep ">Una sufragista lesbiana en la corte victoriana: la historia de Catherine Duleep </a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="El águila de sangre: la tortura vikinga más dolorosa era real" href="https://www.elconfidencial.com/alma-corazon-vida/2021-12-28/el-aguila-de-sangre-tortura-dolorosa-vikinga_3345290/" title="El águila de sangre: la tortura vikinga más dolorosa sí era real">El águila de sangre: <br/>la tortura vikinga más dolorosa sí era real</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="El truco del cerebro para no colapsar en lugares concurridos" href="https://www.elconfidencial.com/alma-corazon-vida/2021-12-28/truco-de-tu-cerebro-para-no-colapsar_3345342/" title="El truco de tu cerebro para no colapsar en lugares concurridos">El truco de tu cerebro para no colapsar en lugares concurridos</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Los cinco verdaderos trucos para dejar de procrastinar" href="https://www.elconfidencial.com/alma-corazon-vida/2021-12-28/cinco-trucos-verdaderos-no-procrastinar_3220228/" title="Los cinco verdaderos trucos para dejar de procrastinar">Los cinco verdaderos trucos para dejar <br/>de procrastinar</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Las predicciones de Nostradamus para 2022: malas noticias" href="https://www.elconfidencial.com/alma-corazon-vida/2021-12-28/nefastas-5-profecias-nostradamus-para-2022_3350532/" title="Las predicciones de Nostradamus para 2022: hay malas noticias">Las predicciones de Nostradamus para 2022: hay malas noticias</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Los 4 hábitos que más dañan tu salud pasados los 60 años" href="https://www.elconfidencial.com/alma-corazon-vida/2021-12-28/4-habitos-que-mas-danan-tu-salud-60-anos_3345382/" title="Los 4 hábitos que más dañan tu salud cuando pasas los 60 años">Los 4 hábitos que más dañan tu salud cuando pasas los 60 años</a></h3>,
#  <h3 class="art-tit fs-23" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Cómo estudiar letras te puede ayudar en un entorno cada vez más digital " href="https://www.elconfidencial.com/alma-corazon-vida/educacion/2021-12-28/formacion-tech-programacion-tecnologia-bra_3344316/" title="Cómo estudiar letras te puede ayudar en un entorno digital ">Cómo estudiar letras te puede ayudar en un entorno digital </a></h3>,
#  <h3 class="art-tit fs-22" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="La receta de Extremadura para alcanzar la neutralidad energética" href="https://www.elconfidencial.com/medioambiente/energia/2021-12-28/eficiencia-energetica-renovables-extremadura-bra_3349916/" title="La receta de Extremadura para alcanzar la neutralidad energética">La receta de Extremadura para alcanzar la neutralidad energética</a></h3>,
#  <h3 class="art-tit fs-22" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Este 'spot' te explica por qué debes conectar con los demás esta Navidad" href="https://www.elconfidencial.com/sociedad/2021-12-27/navidad-telefonica-conectar-sentir-spot-bra_3344688/" title="Este spot te explica por qué debes conectar con los demás en Navidad">Este 'spot' te explica por qué debes conectar con los demás en Navidad</a></h3>,
#  <h3 class="art-tit fs-23" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Belén se marcha de &amp;#039;Sálvame&amp;#039; por un golpe bajo de Kiko " href="https://www.elconfidencial.com/television/programas-tv/2021-12-28/salvame-belen-esteban-abandona-plato-kiko-jimenez_3350689/" title="Belén se marcha de Sálvame por un golpe bajo de Kiko Jiménez">Belén se marcha de 'Sálvame' por un golpe bajo de Kiko Jiménez</a></h3>,
#  <h3 class="art-tit fs-22" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Arús, rey de la mañana por primera vez en su historia" href="https://www.elconfidencial.com/television/programas-tv/2021-12-28/alfonso-arus-aruseros-el-programa-de-ana-rosa-rey_3350439/" title="Arús aprovecha la baja de AR: nuevo rey de la mañana">Arús aprovecha la baja de AR: nuevo 'rey de la mañana'</a></h3>,
#  <h3 class="art-tit fs-23" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Insólito plantón a su cita en &amp;#039;First Dates&amp;#039;: &amp;quot;Es el karma&amp;quot;" href="https://www.elconfidencial.com/television/programas-tv/2021-12-28/first-dates-planton-cita-karma-gastroenteritis_3350586/" title="Insólito plantón a su cita en First Dates: Ha sido el karma">Insólito plantón a su cita en 'First Dates': "Ha sido el karma"</a></h3>,
#  <h3 class="art-tit fs-22" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="'FD': repasito sobre  feminismo de un hombre a una mujer " href="https://www.elconfidencial.com/television/programas-tv/2021-12-28/machista-feminista-first-dates-santiago-alicia_3350400/" title="FD: un hombre da un repaso sobre feminismo a su cita">'FD': un hombre da un repaso sobre feminismo a su cita</a></h3>,
#  <h3 class="art-tit fs-23" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Patiño arrincona a Julián Muñoz antes de su especial en T5" href="https://www.elconfidencial.com/television/programas-tv/2021-12-28/maria-patino-opinion-entrevista-julian-munoz-telecinco_3350643/" title="Patiño arrincona a Julián Muñoz ante su especial sobre Pantoja">Patiño arrincona a Julián Muñoz ante su especial sobre Pantoja</a></h3>,
#  <h3 class="art-tit fs-22" typetitle="tsmall"><a class="art-tit-link tit-color" data-title='Julián Muñoz usa T5 para su "venganza" contra Isabel Pantoja' href="https://www.elconfidencial.com/television/programas-tv/2021-12-28/julian-munoz-docuserie-telecinco-isabel-pantoja_3350418/" title="Julián usa Telecinco para su venganza contra Pantoja">Julián usa Telecinco para su "venganza" contra Pantoja</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Marcus Brandler, cada vez más integrado en la vida de Rocasolano" href="https://www.vanitatis.elconfidencial.com/casas-reales/2021-12-28/marcus-brandler-novio-paloma-rocasolano-telma-ortiz_3350353/" title="Marcus Brandler, cada vez más integrado en la vida de Rocasolano y Telma Ortiz">Marcus Brandler, cada vez más integrado en la vida de Rocasolano y Telma Ortiz</a></h3>,
#  <h3 class="art-tit" typetitle="tsmall"><a class="art-tit-link tit-color" data-title="Así ha sido el concierto homenaje a Carlos Marín" href="https://www.vanitatis.elconfidencial.com/famosos/2021-12-28/carlos-marin-il-divo-concierto-homenaje-grupo_3350582/" title="Así ha sido el concierto homenaje a Carlos Marín">Así ha sido el concierto homenaje a Carlos Marín</a></h3>]

# %%
titulos = [x.text for x in doc.find_all(attrs={'class':'art-tit'})]
titulos[:10]
# Out:
# ['Sánchez aleja las restricciones comunes a\xa0la espera de otra reunión con las CCAA',
#  'España registra un nuevo récord de incidencia (1.360) y otro de contagios (99.671)',
#  'Con la tercera dosis sin poner, cada vez más países se lanzan a por la cuarta',
#  'Directo | Euskadi cierra\xa0el ocio a la 1:00: 9 regiones, con límites horarios',
#  'Madrid y Andalucía apoyan estudiar que se rebaje la cuarentena de 10 días',
#  'Las comunidades despedirán a miles de sanitarios pese al menor déficit',
#  'Moncloa da tres meses a las empresas para que adopten la nueva regla de temporalidad',
#  'Un Gobierno agotadoy el primer mitinelectoral de Sánchez',
#  'El presidente saca los PGE entre serios avisos de sus socios por la reforma laboral',
#  'ERC busca ahora un acomodo a Trapero en los Mossos tras haberlo destituido']

# %%
len(titulos)
# Out:
# 111

# %% [markdown]
# Vemos que, con este código tan "sencillo" (son solo 7 líneas de código) hemos extraído todos los titulares que había hoy en el periódico.
#
# Podemos hacer algo un poco más interesante, por ejemplo, leer los precios de Tous, para ello utilizaremos la página base:
#
# https://www.tous.com/eu-en/jewelry/best-sellers/c/2026
#
# Y se la pasaremos a BeautifulSoup.
#
# Utilizaremos las herramientas de desarrollo de Google Chrome al mismo tiempo que el código Python para extraer lo que necesitamos
#
# ### Ejercicio 7. Obtén los descriptivos de los productos de la web de Tous
#
# #### Obtener la clase que tiene la descripción de los productos
# #### Pasárselo a BeautifulSoup para que nos extraiga los descriptivos

# %%
url = 'https://www.tous.com/eu-en/jewelry/best-sellers/c/2026'
doc = BeautifulSoup(requests.get(url).content)

# %%
desc = [x.text for x in doc.find_all(attrs={'class':'product-card'})]
nombre = []
for i in desc:
    nombre.append(i.replace('\n    ','').replace('materials','').replace('ENGRAVABLE','').strip())
nombre
# Out:
# ['Silver Vermeil TOUS Basics bear Hoop earrings       50\xa0€',
#  'Silver Vermeil Cool Joy Earrings       70\xa0€',
#  'Silver Vermeil Cool Joy Earrings set       65\xa0€',
#  'Silver vermeil Cool Joy Set   2 products',
#  'Silver TOUS Straight Earrings with Pearls       60\xa0€',
#  'Silver TOUS Straight Earrings with Pearls       52\xa0€',
#  'Silver Vermeil Cool Joy Necklace with Gemstones       130\xa0€',
#  'Cool Joy Set - Straight gemstones  2 products',
#  'Silver Vermeil Cool Joy Earcuff with Gemstones       50\xa0€',
#  'Magic Nature Necklaces Set        70\xa0€',
#  'Silver Vermeil TOUS Good Vibes four-leaf clover Bracelet with multicolored Cord         75\xa0€',
#  'Silver TOUS Good Vibes flower Bracelet with red Cord         65\xa0€',
#  'Rose Vermeil Silver Super Power Earrings with Turquoise       60\xa0€',
#  'Rose Vermeil Silver Super Power Earrings with Gemstones       99\xa0€',
#  'Rose Vermeil Silver Super Power Necklace with Gemstones       80\xa0€',
#  'Rose Vermeil Silver Super Power Bracelet with Gemstones       90\xa0€']

# %%
lst=[]
for i in nombre:
    k = i.split('       ')
    lst.append(k)
df = pd.DataFrame(lst,columns=['Desc','Price'])

# %%
df
# Out:
#                                                  Desc   Price
# 0       Silver Vermeil TOUS Basics bear Hoop earrings    50 €
# 1                    Silver Vermeil Cool Joy Earrings    70 €
# 2                Silver Vermeil Cool Joy Earrings set    65 €
# 3            Silver vermeil Cool Joy Set   2 products    None
# 4           Silver TOUS Straight Earrings with Pearls    60 €
# 5           Silver TOUS Straight Earrings with Pearls    52 €
# 6     Silver Vermeil Cool Joy Necklace with Gemstones   130 €
# 7       Cool Joy Set - Straight gemstones  2 products    None
# 8      Silver Vermeil Cool Joy Earcuff with Gemstones    50 €
# 9                          Magic Nature Necklaces Set    70 €
# 10  Silver Vermeil TOUS Good Vibes four-leaf clove...    75 €
# 11  Silver TOUS Good Vibes flower Bracelet with re...    65 €
# 12  Rose Vermeil Silver Super Power Earrings with ...    60 €
# 13  Rose Vermeil Silver Super Power Earrings with ...    99 €
# 14  Rose Vermeil Silver Super Power Necklace with ...    80 €
# 15  Rose Vermeil Silver Super Power Bracelet with ...    90 €

# %% [markdown]
# Con los nombres obtenidos lo que necesitamos es ir un paso más allá y obtener también los precios.
#
# Para ello lo que vamos a hacer es buscar un "contenedor" que tenga tanto el descriptivo como el precio:
#
# En este caso, el contenedor que tiene nombre y precio del producto tiene una clase llamada "product-card":

# %% [markdown]
# ### Ejercicio 8. Obtén todos los productos de las siguientes páginas (productivizar el scraping)

# %%
paginas = {
    'Best_sellers': 'https://www.tous.com/eu-en/jewelry/best-sellers/c/2026',
    'Earrings': 'https://www.tous.com/eu-en/jewelry/earrings/c/6',
    'Piercings': 'https://www.tous.com/eu-en/jewelry/piercings/c/4433',
    'Bracelets': 'https://www.tous.com/eu-en/jewelry/bracelets/c/3',
    'Rings': 'https://www.tous.com/eu-en/jewelry/jewelry-rings/c/5',
    'Necklaces': 'https://www.tous.com/eu-en/jewelry/necklaces/c/7',
    'Pendants': 'https://www.tous.com/eu-en/jewelry/pendants/c/10',
    'Chains': 'https://www.tous.com/eu-en/jewelry/chains/c/11',
    'Diamonds': 'https://www.tous.com/eu-en/jewelry/diamonds/c/4358'
}

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd


lst=[]
for p in paginas:
    
    doc = BeautifulSoup(requests.get(paginas[p]).content)
    desc = [x.text for x in doc.find_all(attrs={'class':'product-card'})]

    nombre = []
    for i in desc:
        nombre.append(i.replace('\n    ','').replace('materials','').replace('ENGRAVABLE','').replace('ADD','').strip())
        
    
    for i in nombre:
        k = i.split('       ')
        lst.append(k)

# %%
dfs = pd.DataFrame(lst)
dfs.columns = ['Nombre','Precio','Extra']
dfs.drop('Extra',axis=1,inplace=True)

# %%
dfs.head()
# Out:
#                                           Nombre Precio
# 0  Silver Vermeil TOUS Basics bear Hoop earrings   50 €
# 1               Silver Vermeil Cool Joy Earrings   70 €
# 2           Silver Vermeil Cool Joy Earrings set   65 €
# 3       Silver vermeil Cool Joy Set   2 products   None
# 4      Silver TOUS Straight Earrings with Pearls   60 €

# %% [markdown]
# ## Aspectos Éticos / legales del Scraping
#
# El scraping de datos está en una zona un tanto gris en cuánto a legalidad. Por una parte estamos accediendo a información que el dueño ofrece de forma gratuita por internet pero, por otra, si realizamos demasiadas peticiones de datos (demasiadas peticiones por segundo) podríamos afectar al rendimiento de la página respecto al resto de usuarios de la página.
#
# En general, antes de scrapear datos, debemos comprobar si existen otros métodos para obtenerlos que sean menos intrusivos y, en caso de no existir, tratar de realizar un scraping respetuoso con los servicios del proveedor de datos.

# %% [markdown]
# ## Scraping con navegador
#
# Por último, algunas páginas web no responden a peticiones de requests o, la página obtenida no tiene todos los datos que tiene la página original.
#
# En muchas ocasiones esto se debe a que la página a la que intentamos acceder requiere la ejecución de código JavaScript en nuestro navegador.
#
# Por ejemplo, si vamos a AirBnB y pedimos los datos de una casa con requests, veremos que casi ninguna de las clases que aparecen en las herramientas de desarrollo de chrome está en la respuesta obtenida por requests.
#
# AirBnB "monta" la página en nuestro navegador en función de sus características, tamaño de pantalla, tipo de dispositivo (tablet, móvil...) y, para ello, utiliza Javascript.
#
# Aunque en el máster no se ve cómo hacer este scraping (configurar el motor de control del navegador puede llevar mucho tiempo), intentaremos ver una demostración de cómo funcionan estos programas:

# %% [markdown]
# # Acceso a una base de datos desde Python
#
# Por último, el origen de datos más frecuente para trabajar en Python es una base de datos.
#
# Python tiene un estándar de acceso a bases de datos que simplifica el trabajar con diferentes motores pero, a la hora de la verdad, pequeñas diferencias en su funcionamiento hacen que el día a día sea bastante latoso.
#
# Puesto que el trabajo del analista de datos es principalmente basado en DataFrames de Pandas, en HINTD hemos creado una librería de acceso a la base de datos que nos ayuda a interactuar con diferentes bases de datos.
#
# Su código compelto son las siguientes 183 filas:

# %%
class ConfiguracionConexion:
    BD_ORACLE = "Oracle"
    BD_MSSQL = "Microsoft"
    BD_DB2 = "DB2"
    
    def __init__(self, entorno, user, pwd, server, service, database, port=None):
        """
        Inicializa la configuración de un acceso a una base de datos.
        
        Entorno: admite tres tipos diferentes de bases de datos, Oracle, Microsoft SQL y DB2
        User: Nombre de usuario para conectarnos a la base de datos
        Pwd: contraseña de acceso
        Server: Servidor (IP o nombre) en el que está la base de datos
        Service: Nombre del servicio en Oracle, base de datos en IBM o instancia en MSSQL
        Database: Nombre de la base de datos a la que nos queremos conectar
        Port: puerto del servidor en el que está la base de datos.
        
        """
        self.entorno = entorno
        self.user = user
        self.pwd = pwd
        self.server = server
        self.service = service
        self.database = database
        self.port = port
        if self.port == None:
            if self.entorno == ConfiguracionConexion.BD_ORACLE:
                self.port = 1521
            elif self.entorno == ConfiguracionConexion.BD_MSSQL:
                self.port = 1433
            elif self.entorno == ConfiguracionConexion.BD_DB2:
                self.port = 50001
    
    def get_connection(self):
        if self.entorno == ConfiguracionConexion.BD_ORACLE:
            import cx_Oracle
            return cx_Oracle.connect(f'{self.user}/{self.pwd}@{self.server}:{self.port}/{self.service}')
        if self.entorno == ConfiguracionConexion.BD_MSSQL:
            import pymssql
            return pymssql.connect(server=f'{self.server}', port=f'{self.port}', database=f'{self.database}', 
                                   user=f'{self.user}', password=f'{self.pwd}')
        if self.entorno == ConfiguracionConexion.BD_DB2:
            import ibm_db_dbi
            return ibm_db_dbi.connect(f'HOSTNAME={self.server};PORT={self.port};UID={self.user};PWD={self.pwd};'+
                                      f'Database={self.service};Security=ssl', '', '')
            

class AccessDB:
    def __init__(self, configuracion):
        self.configuracion = configuracion
        self.entorno = configuracion.entorno

    def get_connection(self):
        return self.configuracion.get_connection()
    
    def execute(self, query):
        con = self.get_connection()
        cur = con.cursor()
        try:
            cur.execute(query)
            con.commit()
            cur.close()
            con.close()
        except Exception as e:
            con.rollback()
            con.close()
            raise e
    
    def execute_non_query(self, query):
        self.execute(query)

    def get(self, query):
        con = self.get_connection()
        cur = con.cursor()
        cur.execute(query, args)
        data = cur.fetchall()
        cur.close()
        con.close()
        return data

    def get_scalar(self, query):
        data = self.get(query)
        return data[0][0]
    
    def get_dictionary(self, query):
        con = self.get_connection()
        cur = con.cursor()
        cur.execute(query)
        data = cur.fetchall()
        names = [x[0] for x in cur.description]
        data = [dict(zip(names, d)) for d in data]
        cur.close()
        con.close()
        return data

    def get_dataframe(self, query):
        import pandas as pd
        return pd.DataFrame(self.get_dictionary(query))
    
    def get_data_progresivo(self, query, bloque=100, debug=True):
        if debug:
            import datetime as dtt
        data = []
        con = self.get_connection()
        cur = con.cursor()
        if debug: 
            inicio = dtt.datetime.now()
            print(f'{inicio.isoformat()}: iniciando.')
        cur.execute(query)        
        while True:
            new_data = cur.fetchmany(bloque)
            data.extend(new_data[:])
            if not new_data or len(new_data) < bloque:
                break
            if debug: 
                fin = dtt.datetime.now()
                velocidad = bloque / (fin - inicio).total_seconds()
                print(f'\t{fin.isoformat()}: obtenidos {bloque} registros a {velocidad} registros por segundo, acumulado: {len(data)} registros')
        cols = [x[0] for x in cur.description]
        cur.close()
        con.close()
        del cur
        del con
        return data, cols
    
    def get_dictionary_progresivo(self, query,bloque=100, debug=True):
        data, cols = self.get_data_progresivo( query, bloque, debug)
        return [dict(zip(cols, d)) for d in data]
    
    
    def get_dataframe_progresivo(self, query, bloque=100, debug=True):
        import pandas as pd
        return pd.DataFrame(self.get_dictionary_progresivo(query, bloque, debug))
    
    def execute_many(self, query, data, table=None):
        con = self.get_connection()
        cur = con.cursor()
        
        if self.entorno == ConfiguracionConexion.BD_ORACLE:
            cur.prepare(query)
            query = None
        try:
            if self.entorno == ConfiguracionConexion.BD_MSSQL:
                con.bulk_copy(table, data, check_constraints=False)
            else:
                cur.executemany(query, data)
        except Exception as e:
            con.rollback()
            con.close()
            raise e
            return
        
        con.commit()
        cur.close()
        con.close()

    def generate_upload_command(self, destination, columns):
        if self.entorno == ConfiguracionConexion.BD_ORACLE:
            usuario = user if usuario == None else usuario
            return "INSERT INTO {0} ({1}) VALUES ({2})".format(
                        destination, # Tabla destino
                        ','.join(columns), 
                        ','.join([':' + x for x in columns]))
        elif self.entorno == ConfiguracionConexion.BD_MSSQL:
            return "INSERT INTO {0} ({1}) VALUES ({2})".format(
                    destination,
                    ','.join(columns),
                    ','.join(['%s' for _ in columns])
                )
        
    def upload_data_frame(self, dataframe, destino):
        import pandas as pd
        comando = self.generate_upload_command(destino, dataframe.columns)
        df_ = dataframe.copy()
        for x in df_.columns:
            df_[x] = df_[x].astype(object)
        df_ = df_.where(pd.notnull(df_), None)
              
        if self.entorno == ConfiguracionConexion.BD_ORACLE:
            self.execute_many(comando, dataframe_.to_dict(orient='records'))
            
        elif self.entorno == ConfiguracionConexion.BD_MSSQL:
            self.execute_many(comando, [tuple(x.values()) for x in df_.to_dict(orient='records')], table=destino)

# %% [markdown]
# Su funcionamiento es el siguiente.
#
# 1. Crear un objeto ConfiguracionConexion que nos dice a qué tipo de base de datos nos vamos a conectar y establece algunos parámetros específicos.
# 2. Crear un objeto AccessDB con la configuración de la conexión
# 3. Interacturas con la base de datos
#
# La separación del código en dos clases permite reutilizar conexiones y cambiar el acceso de una base de datos a otra fácilmente.

# %% [markdown]
# Una vez creado el acceso a la base de datos podemos llamar a diferentes métodos:
#  - ```execute```: Ejecuta un comando en la base de datos y no espera respuesta (útil para delete, update,...)
#  - ```get```: Ejecuta un select en la base de datos y devuelve el resultado
#  - ```get_scalar```: Ejecuta un select en la base de datos y devuelve únicamente la primera columna de la primera fila (útil para conteos)
#  - ```get_dictionary```: Ejecuta un select en la base de datos y lo devuelve en forma de diccionario
#  - ```get_dataframe```: Ejecuta un select en la base de datos y lo devuelve como DataFrame de pandas
#  - ```get_xxx_progresivo```: Versiones progresivas de las funciones get que van informando del progreso de la lectura
#  - ```upload_dataframe```: Acepta un dataframe y una tabla de destino y genera un comando SQL que mapea nombres del dataframe a nombres de columnas (es necesario que en la tabla existan esas columnas y se llamen igual) y sube los datos.
#
# Esta librería está preparada para trabajar con:
#  - Microsoft SQL
#  - Oracle
#  - IBM DB2
#
# Aunque, para ello, requiere que estén instaladas las librerías necesarias en el equipo:
#  - MSSQL: pymssql
#  - Oracle: cx_Oracle
#  - DB2: imb_db_dbi
#
# Podemos probar la librería leyendo los datos de Nemiña:

# %%
acceso_mds = ConfiguracionConexion(entorno = ConfiguracionConexion.BD_MSSQL,
                                  user = 'estudiante',
                                  pwd = 'uvh8DNU7BDBa8T',
                                  server='mds.hintd.net',
                                  service='',
                                  database='master')

# %%
mds =AccessDB(acceso_mds)

# %%
df = mds.get_dataframe('''SELECT * FROM nemina.DBO.DATOS_BASE WHERE FY_ID = 2019''')

# %%
df
# Out:
#     PEDIDO_ID  FY_ID PRODUCTO_ID     ZONA_ID  CLIENTE_ID      TONELADAS  \
# 0      P-0302   2019       Setas      Coruña          17  42.8000000000
# 1      P-0303   2019       Setas      Coruña          11  45.2000000000
# 2      P-0304   2019       Setas     Ourense          28  41.4000000000
# 3      P-0305   2019       Algas      Coruña          18  42.4000000000
# 4      P-0306   2019       Setas     Ourense          24  33.3000000000
# ..        ...    ...         ...         ...         ...            ...
# 194    P-0496   2019       Setas      Coruña          37  44.8000000000
# 195    P-0497   2019       Algas        Lugo          17  43.6000000000
# 196    P-0498   2019       Setas      Coruña           7  42.4000000000
# 197    P-0499   2019       Setas      Coruña          38  42.4000000000
# 198    P-0500   2019       Setas  Pontevedra          25  34.0000000000
#
#          INGRESOS_EUR
# 0    32870.0000000000
# 1    34352.0000000000
# 2    26522.0000000000
# 3    25949.0000000000
# 4    21312.0000000000
# ..                ...
# 194  35123.0000000000
# 195  26945.0000000000
# 196  32224.0000000000
# 197  33581.0000000000
# 198  23964.0000000000
#
# [199 rows x 7 columns]

# %% [markdown]
# # Ejercicio compendio
#
# Obtén los datos de cotización de Bitcoin a Euros desde el 23 de Septiembre al 31 de Diciembre de 2019 utilizando la siguiente URL:

# %%
url_tc = 'https://finance.yahoo.com/quote/BTC-EUR/history?period1=1568851200&period2=1577750400&interval=1d&filter=history&frequency=1d&includeAdjustedClose=true'

# %% [markdown]
# Descarga también los datos de venta de nemiña entre esos meses y aplica, para cada venta de los meses entre septiembre y diciembre, el tipo de cambio medio de EUR a BTC para tener, junto con el importe de cada factura, su importe equivalente en BTC.
#
# Por último sube los datos a una tabla llamada: DATOS_BASE_ALUMNOS que contiene las siguientes columnas:
#  - ALUMNO: tu nombre
#  - PEDIDO_ID: el original
#  - FY_ID: original
#  - PRODUCTO_ID: original
#  - ZONA_ID: original
#  - CLIENTE_ID: original
#  - TONELADAS: original
#  - INGRESOS_EUR: original
#  - TASA_DE_CAMBIO_BTC: Tasa de cambio a aplicar
#  - INGRESOS_BTC: converesión de INGRESOS_EUR a BTC según el tipo de cambio medio

# %%
import requests
import pandas as pd
import numpy as np
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.93 Safari/537.36'}
x = requests.get(url_tc, headers=headers)

btc = pd.read_html(x.content)[0]

# %%
btc = btc.head(btc.shape[0]-1)
btc['Open'] = btc['Open'].astype(float)
btc_mean = round(btc['Open'].mean(),2)
btc_mean
# Out:
# 7308.59

# %%
df['TASA_DE_CAMBIO_BTC'] = np.where(df['FY_ID']==2019,btc_mean,0)
df['INGRESOS_BTC'] = np.where(df['FY_ID']==2019,round(df['INGRESOS_EUR'].astype(float) * (1/df['TASA_DE_CAMBIO_BTC']),2),0)
df
# Out:
#     PEDIDO_ID  FY_ID PRODUCTO_ID     ZONA_ID  CLIENTE_ID      TONELADAS  \
# 0      P-0302   2019       Setas      Coruña          17  42.8000000000
# 1      P-0303   2019       Setas      Coruña          11  45.2000000000
# 2      P-0304   2019       Setas     Ourense          28  41.4000000000
# 3      P-0305   2019       Algas      Coruña          18  42.4000000000
# 4      P-0306   2019       Setas     Ourense          24  33.3000000000
# ..        ...    ...         ...         ...         ...            ...
# 194    P-0496   2019       Setas      Coruña          37  44.8000000000
# 195    P-0497   2019       Algas        Lugo          17  43.6000000000
# 196    P-0498   2019       Setas      Coruña           7  42.4000000000
# 197    P-0499   2019       Setas      Coruña          38  42.4000000000
# 198    P-0500   2019       Setas  Pontevedra          25  34.0000000000
#
#          INGRESOS_EUR  TASA_DE_CAMBIO_BTC  INGRESOS_BTC
# 0    32870.0000000000             7308.59          4.50
# 1    34352.0000000000             7308.59          4.70
# 2    26522.0000000000             7308.59          3.63
# 3    25949.0000000000             7308.59          3.55
# 4    21312.0000000000             7308.59          2.92
# ..                ...                 ...           ...
# 194  35123.0000000000             7308.59          4.81
# 195  26945.0000000000             7308.59          3.69
# 196  32224.0000000000             7308.59          4.41
# 197  33581.0000000000             7308.59          4.59
# 198  23964.0000000000             7308.59          3.28
#
# [199 rows x 9 columns]

# %%
mds.upload_data_frame(df,"nemina.DBO.DATOS_BASE_ALUMNOS")
