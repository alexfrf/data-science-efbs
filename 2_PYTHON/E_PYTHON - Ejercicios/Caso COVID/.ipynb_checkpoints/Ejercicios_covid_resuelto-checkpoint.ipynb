# %% [markdown]
# # Introducción

# %% [markdown]
# Cuando nos enfrentamos a un conjunto de datos desconocido, los pasos a seguir para explorarlo siguen siempre una estructura bastante similar:
#
# 1. Comprobar las dimensiones del dataframe (o en general conjunto de datos), ¿cuántas filas tenemos? ¿cuántas columnas?
#
#
# 2. La siguiente pregunta que podemos hacernos es: ¿necesito todos los datos?
#
#     2.1 Sobre todo en conjuntos de datos grandes es útil tener delimitado el horizonte de datos que necesitamos. Por ejemplo, si voy a hacer un análisis de ventas de una tienda online, probablemente no necesite un histórico de 10 años, sino que me bastará con 2 años. Esto reducirá bastante el tiempo de ejecución del análisis.
#
#     2.2 Por otra parte, en cuanto a las columnas, puede que cuente con 60 columnas que describan la realidad que estoy estudiando, pero realmente para el análisis que quiero realizar solo necesite utilizar 10. Por tanto, lo adecuado es seleccionar únicamente esas columnas que en principio son importantes (aunque luego cambie de idea), de manera que quede un dataframe más manejable, tanto para la memoria del ordenador como para nosotros mismos.
#
#
# 3. Renombrar las columnas con nombres más intuitivos y reconocibles para nosotros.
#
#
# 4. Comprobar si en las columnas importantes contamos con un gran número de valores nulos o si se encuentran en el formato adecuado.
#
#
# 5. Comprobar los rangos de valores entre los que se mueven las variables del dataframe con alguna visualización.

# %% [markdown]
# # Caso práctico: datos relacionados con el covid-19
#
# ## Análisis exploratorio
#
# En el csv ```owid-covid-data-updated.csv```, obtenido de https://github.com/owid/covid-19-data/tree/master/public/data, se encuentra una recopilación de datos de diferentes países a nivel diario de variables relacionadas con el covid-19 (número de infectados, número de muertes, número de vacunados, etc...)
#
# Se proporciona un csv de datos y otro de explicación de los campos; además, existe un excel con el mismo contenido que el csv.
#
# Lo primero que vamos a hacer es seguir los pasos descritos anteriormente para hacer un primer análisis exploratorio. Después, una vez tengamos los datos listos, se propondrán unas preguntas relacionadas con el covid-19.

# %%
import pandas as pd
import datetime

pd.options.display.max_rows = 100
pd.options.display.max_columns = 100

df = pd.read_csv('./Data/owid-covid-data-updated.csv')

# %%
# Guardamos una copia del DataFrame original sin modificar por si es necesario más adelante
df_original = df.copy()

# %%
df.shape
# Out:
# (131526, 67)

# %% [markdown]
# Vemos que tiene 67 columnas, podemos encontrar una descripción de todas ellas en:
# https://github.com/owid/covid-19-data/blob/master/public/data/owid-covid-codebook.csv
#
# Las traemos a nuestro cuaderno con ```read_html```

# %%
columnas = pd.read_html('https://github.com/owid/covid-19-data/blob/master/public/data/owid-covid-codebook.csv')[0]
columnas
# Out:
#     Unnamed: 0                                      column  \
# 0          NaN                                    iso_code
# 1          NaN                                   continent
# 2          NaN                                    location
# 3          NaN                                        date
# 4          NaN                                 total_cases
# 5          NaN                                   new_cases
# 6          NaN                          new_cases_smoothed
# 7          NaN                                total_deaths
# 8          NaN                                  new_deaths
# 9          NaN                         new_deaths_smoothed
# 10         NaN                     total_cases_per_million
# 11         NaN                       new_cases_per_million
# 12         NaN              new_cases_smoothed_per_million
# 13         NaN                    total_deaths_per_million
# 14         NaN                      new_deaths_per_million
# 15         NaN             new_deaths_smoothed_per_million
# 16         NaN                           reproduction_rate
# 17         NaN                                icu_patients
# 18         NaN                    icu_patients_per_million
# 19         NaN                               hosp_patients
# 20         NaN                   hosp_patients_per_million
# 21         NaN                       weekly_icu_admissions
# 22         NaN           weekly_icu_admissions_per_million
# 23         NaN                      weekly_hosp_admissions
# 24         NaN          weekly_hosp_admissions_per_million
# 25         NaN                                 total_tests
# 26         NaN                                   new_tests
# 27         NaN                    total_tests_per_thousand
# 28         NaN                      new_tests_per_thousand
# 29         NaN                          new_tests_smoothed
# 30         NaN             new_tests_smoothed_per_thousand
# 31         NaN                               positive_rate
# 32         NaN                              tests_per_case
# 33         NaN                                 tests_units
# 34         NaN                          total_vaccinations
# 35         NaN                           people_vaccinated
# 36         NaN                     people_fully_vaccinated
# 37         NaN                              total_boosters
# 38         NaN                            new_vaccinations
# 39         NaN                   new_vaccinations_smoothed
# 40         NaN              total_vaccinations_per_hundred
# 41         NaN               people_vaccinated_per_hundred
# 42         NaN         people_fully_vaccinated_per_hundred
# 43         NaN                  total_boosters_per_hundred
# 44         NaN       new_vaccinations_smoothed_per_million
# 45         NaN              new_people_vaccinated_smoothed
# 46         NaN  new_people_vaccinated_smoothed_per_hundred
# 47         NaN                            stringency_index
# 48         NaN                                  population
# 49         NaN                          population_density
# 50         NaN                                  median_age
# 51         NaN                               aged_65_older
# 52         NaN                               aged_70_older
# 53         NaN                              gdp_per_capita
# 54         NaN                             extreme_poverty
# 55         NaN                       cardiovasc_death_rate
# 56         NaN                         diabetes_prevalence
# 57         NaN                              female_smokers
# 58         NaN                                male_smokers
# 59         NaN                      handwashing_facilities
# 60         NaN                  hospital_beds_per_thousand
# 61         NaN                             life_expectancy
# 62         NaN                     human_development_index
# 63         NaN                            excess_mortality
# 64         NaN                 excess_mortality_cumulative
# 65         NaN        excess_mortality_cumulative_absolute
# 66         NaN     excess_mortality_cumulative_per_million
#
#                                                source            category  \
# 0      International Organization for Standardization              Others
# 1                                   Our World in Data              Others
# 2                                   Our World in Data              Others
# 3                                   Our World in Data              Others
# 4   COVID-19 Data Repository by the Center for Sys...     Confirmed cases
# 5   COVID-19 Data Repository by the Center for Sys...     Confirmed cases
# 6   COVID-19 Data Repository by the Center for Sys...     Confirmed cases
# 7   COVID-19 Data Repository by the Center for Sys...    Confirmed deaths
# 8   COVID-19 Data Repository by the Center for Sys...    Confirmed deaths
# 9   COVID-19 Data Repository by the Center for Sys...    Confirmed deaths
# 10  COVID-19 Data Repository by the Center for Sys...     Confirmed cases
# 11  COVID-19 Data Repository by the Center for Sys...     Confirmed cases
# 12  COVID-19 Data Repository by the Center for Sys...     Confirmed cases
# 13  COVID-19 Data Repository by the Center for Sys...    Confirmed deaths
# 14  COVID-19 Data Repository by the Center for Sys...    Confirmed deaths
# 15  COVID-19 Data Repository by the Center for Sys...    Confirmed deaths
# 16  Arroyo Marioli et al. (2020). https://doi.org/...   Reproduction rate
# 17  European CDC for EU countries, government sour...      Hospital & ICU
# 18  European CDC for EU countries, government sour...      Hospital & ICU
# 19  European CDC for EU countries, government sour...      Hospital & ICU
# 20  European CDC for EU countries, government sour...      Hospital & ICU
# 21  European CDC for EU countries, government sour...      Hospital & ICU
# 22  European CDC for EU countries, government sour...      Hospital & ICU
# 23  European CDC for EU countries, government sour...      Hospital & ICU
# 24  European CDC for EU countries, government sour...      Hospital & ICU
# 25                        National government reports  Tests & positivity
# 26                        National government reports  Tests & positivity
# 27                        National government reports  Tests & positivity
# 28                        National government reports  Tests & positivity
# 29                        National government reports  Tests & positivity
# 30                        National government reports  Tests & positivity
# 31                        National government reports  Tests & positivity
# 32                        National government reports  Tests & positivity
# 33                        National government reports  Tests & positivity
# 34                        National government reports        Vaccinations
# 35                        National government reports        Vaccinations
# 36                        National government reports        Vaccinations
# 37                        National government reports        Vaccinations
# 38                        National government reports        Vaccinations
# 39                        National government reports        Vaccinations
# 40                        National government reports        Vaccinations
# 41                        National government reports        Vaccinations
# 42                        National government reports        Vaccinations
# 43                        National government reports        Vaccinations
# 44                        National government reports        Vaccinations
# 45                        National government reports        Vaccinations
# 46                        National government reports        Vaccinations
# 47  Oxford COVID-19 Government Response Tracker, B...    Policy responses
# 48  United Nations, Department of Economic and Soc...              Others
# 49  World Bank World Development Indicators, sourc...              Others
# 50  UN Population Division, World Population Prosp...              Others
# 51  World Bank World Development Indicators based ...              Others
# 52  United Nations, Department of Economic and Soc...              Others
# 53  World Bank World Development Indicators, sourc...              Others
# 54  World Bank World Development Indicators, sourc...              Others
# 55  Global Burden of Disease Collaborative Network...              Others
# 56  World Bank World Development Indicators, sourc...              Others
# 57  World Bank World Development Indicators, sourc...              Others
# 58  World Bank World Development Indicators, sourc...              Others
# 59                 United Nations Statistics Division              Others
# 60  OECD, Eurostat, World Bank, national governmen...              Others
# 61  James C. Riley, Clio Infra, United Nations Pop...              Others
# 62        United Nations Development Programme (UNDP)              Others
# 63  Human Mortality Database (2021), World Mortali...    Excess mortality
# 64  Human Mortality Database (2021), World Mortali...    Excess mortality
# 65  Human Mortality Database (2021), World Mortali...    Excess mortality
# 66  Human Mortality Database (2021), World Mortali...    Excess mortality
#
#                                           description
# 0     ISO 3166-1 alpha-3 – three-letter country codes
# 1              Continent of the geographical location
# 2                               Geographical location
# 3                                 Date of observation
# 4                   Total confirmed cases of COVID-19
# 5                     New confirmed cases of COVID-19
# 6    New confirmed cases of COVID-19 (7-day smoothed)
# 7                 Total deaths attributed to COVID-19
# 8                   New deaths attributed to COVID-19
# 9   New deaths attributed to COVID-19 (7-day smoot...
# 10  Total confirmed cases of COVID-19 per 1,000,00...
# 11  New confirmed cases of COVID-19 per 1,000,000 ...
# 12  New confirmed cases of COVID-19 (7-day smoothe...
# 13  Total deaths attributed to COVID-19 per 1,000,...
# 14  New deaths attributed to COVID-19 per 1,000,00...
# 15  New deaths attributed to COVID-19 (7-day smoot...
# 16  Real-time estimate of the effective reproducti...
# 17  Number of COVID-19 patients in intensive care ...
# 18  Number of COVID-19 patients in intensive care ...
# 19  Number of COVID-19 patients in hospital on a g...
# 20  Number of COVID-19 patients in hospital on a g...
# 21  Number of COVID-19 patients newly admitted to ...
# 22  Number of COVID-19 patients newly admitted to ...
# 23  Number of COVID-19 patients newly admitted to ...
# 24  Number of COVID-19 patients newly admitted to ...
# 25                           Total tests for COVID-19
# 26  New tests for COVID-19 (only calculated for co...
# 27          Total tests for COVID-19 per 1,000 people
# 28            New tests for COVID-19 per 1,000 people
# 29  New tests for COVID-19 (7-day smoothed). For c...
# 30  New tests for COVID-19 (7-day smoothed) per 1,...
# 31  The share of COVID-19 tests that are positive,...
# 32  Tests conducted per new confirmed case of COVI...
# 33  Units used by the location to report its testi...
# 34  Total number of COVID-19 vaccination doses adm...
# 35  Total number of people who received at least o...
# 36  Total number of people who received all doses ...
# 37  Total number of COVID-19 vaccination booster d...
# 38  New COVID-19 vaccination doses administered (o...
# 39  New COVID-19 vaccination doses administered (7...
# 40  Total number of COVID-19 vaccination doses adm...
# 41  Total number of people who received at least o...
# 42  Total number of people who received all doses ...
# 43  Total number of COVID-19 vaccination booster d...
# 44  New COVID-19 vaccination doses administered (7...
# 45  Daily number of people receiving their first v...
# 46  Daily number of people receiving their first v...
# 47  Government Response Stringency Index: composit...
# 48  Population (latest available values). See http...
# 49  Number of people divided by land area, measure...
# 50  Median age of the population, UN projection fo...
# 51  Share of the population that is 65 years and o...
# 52  Share of the population that is 70 years and o...
# 53  Gross domestic product at purchasing power par...
# 54  Share of the population living in extreme pove...
# 55  Death rate from cardiovascular disease in 2017...
# 56  Diabetes prevalence (% of population aged 20 t...
# 57  Share of women who smoke, most recent year ava...
# 58  Share of men who smoke, most recent year avail...
# 59  Share of the population with basic handwashing...
# 60  Hospital beds per 1,000 people, most recent ye...
# 61                   Life expectancy at birth in 2019
# 62  A composite index measuring average achievemen...
# 63  Percentage difference between the reported num...
# 64  Percentage difference between the cumulative n...
# 65  Cumulative difference between the reported num...
# 66  Cumulative difference between the reported num...

# %%
df.head(10)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# 5      AFG      Asia  Afghanistan  2020-02-29          5.0        0.0
# 6      AFG      Asia  Afghanistan  2020-03-01          5.0        0.0
# 7      AFG      Asia  Afghanistan  2020-03-02          5.0        0.0
# 8      AFG      Asia  Afghanistan  2020-03-03          5.0        0.0
# 9      AFG      Asia  Afghanistan  2020-03-04          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                 NaN           NaN         NaN                  NaN
# 1                 NaN           NaN         NaN                  NaN
# 2                 NaN           NaN         NaN                  NaN
# 3                 NaN           NaN         NaN                  NaN
# 4                 NaN           NaN         NaN                  NaN
# 5               0.714           NaN         NaN                  0.0
# 6               0.714           NaN         NaN                  0.0
# 7               0.000           NaN         NaN                  0.0
# 8               0.000           NaN         NaN                  0.0
# 9               0.000           NaN         NaN                  0.0
#
#    total_cases_per_million  new_cases_per_million  \
# 0                    0.126                  0.126
# 1                    0.126                  0.000
# 2                    0.126                  0.000
# 3                    0.126                  0.000
# 4                    0.126                  0.000
# 5                    0.126                  0.000
# 6                    0.126                  0.000
# 7                    0.126                  0.000
# 8                    0.126                  0.000
# 9                    0.126                  0.000
#
#    new_cases_smoothed_per_million  total_deaths_per_million  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# 5                           0.018                       NaN
# 6                           0.018                       NaN
# 7                           0.000                       NaN
# 8                           0.000                       NaN
# 9                           0.000                       NaN
#
#    new_deaths_per_million  new_deaths_smoothed_per_million  reproduction_rate  \
# 0                     NaN                              NaN                NaN
# 1                     NaN                              NaN                NaN
# 2                     NaN                              NaN                NaN
# 3                     NaN                              NaN                NaN
# 4                     NaN                              NaN                NaN
# 5                     NaN                              0.0                NaN
# 6                     NaN                              0.0                NaN
# 7                     NaN                              0.0                NaN
# 8                     NaN                              0.0                NaN
# 9                     NaN                              0.0                NaN
#
#    icu_patients  icu_patients_per_million  hosp_patients  \
# 0           NaN                       NaN            NaN
# 1           NaN                       NaN            NaN
# 2           NaN                       NaN            NaN
# 3           NaN                       NaN            NaN
# 4           NaN                       NaN            NaN
# 5           NaN                       NaN            NaN
# 6           NaN                       NaN            NaN
# 7           NaN                       NaN            NaN
# 8           NaN                       NaN            NaN
# 9           NaN                       NaN            NaN
#
#    hosp_patients_per_million  weekly_icu_admissions  \
# 0                        NaN                    NaN
# 1                        NaN                    NaN
# 2                        NaN                    NaN
# 3                        NaN                    NaN
# 4                        NaN                    NaN
# 5                        NaN                    NaN
# 6                        NaN                    NaN
# 7                        NaN                    NaN
# 8                        NaN                    NaN
# 9                        NaN                    NaN
#
#    weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 0                                NaN                     NaN
# 1                                NaN                     NaN
# 2                                NaN                     NaN
# 3                                NaN                     NaN
# 4                                NaN                     NaN
# 5                                NaN                     NaN
# 6                                NaN                     NaN
# 7                                NaN                     NaN
# 8                                NaN                     NaN
# 9                                NaN                     NaN
#
#    weekly_hosp_admissions_per_million  new_tests  total_tests  \
# 0                                 NaN        NaN          NaN
# 1                                 NaN        NaN          NaN
# 2                                 NaN        NaN          NaN
# 3                                 NaN        NaN          NaN
# 4                                 NaN        NaN          NaN
# 5                                 NaN        NaN          NaN
# 6                                 NaN        NaN          NaN
# 7                                 NaN        NaN          NaN
# 8                                 NaN        NaN          NaN
# 9                                 NaN        NaN          NaN
#
#    total_tests_per_thousand  new_tests_per_thousand  new_tests_smoothed  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN                 NaN
# 2                       NaN                     NaN                 NaN
# 3                       NaN                     NaN                 NaN
# 4                       NaN                     NaN                 NaN
# 5                       NaN                     NaN                 NaN
# 6                       NaN                     NaN                 NaN
# 7                       NaN                     NaN                 NaN
# 8                       NaN                     NaN                 NaN
# 9                       NaN                     NaN                 NaN
#
#    new_tests_smoothed_per_thousand  positive_rate  tests_per_case tests_units  \
# 0                              NaN            NaN             NaN         NaN
# 1                              NaN            NaN             NaN         NaN
# 2                              NaN            NaN             NaN         NaN
# 3                              NaN            NaN             NaN         NaN
# 4                              NaN            NaN             NaN         NaN
# 5                              NaN            NaN             NaN         NaN
# 6                              NaN            NaN             NaN         NaN
# 7                              NaN            NaN             NaN         NaN
# 8                              NaN            NaN             NaN         NaN
# 9                              NaN            NaN             NaN         NaN
#
#    total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# 0                 NaN                NaN                      NaN
# 1                 NaN                NaN                      NaN
# 2                 NaN                NaN                      NaN
# 3                 NaN                NaN                      NaN
# 4                 NaN                NaN                      NaN
# 5                 NaN                NaN                      NaN
# 6                 NaN                NaN                      NaN
# 7                 NaN                NaN                      NaN
# 8                 NaN                NaN                      NaN
# 9                 NaN                NaN                      NaN
#
#    total_boosters  new_vaccinations  new_vaccinations_smoothed  \
# 0             NaN               NaN                        NaN
# 1             NaN               NaN                        NaN
# 2             NaN               NaN                        NaN
# 3             NaN               NaN                        NaN
# 4             NaN               NaN                        NaN
# 5             NaN               NaN                        NaN
# 6             NaN               NaN                        NaN
# 7             NaN               NaN                        NaN
# 8             NaN               NaN                        NaN
# 9             NaN               NaN                        NaN
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
# 5                             NaN                            NaN
# 6                             NaN                            NaN
# 7                             NaN                            NaN
# 8                             NaN                            NaN
# 9                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 0                                  NaN                         NaN
# 1                                  NaN                         NaN
# 2                                  NaN                         NaN
# 3                                  NaN                         NaN
# 4                                  NaN                         NaN
# 5                                  NaN                         NaN
# 6                                  NaN                         NaN
# 7                                  NaN                         NaN
# 8                                  NaN                         NaN
# 9                                  NaN                         NaN
#
#    new_vaccinations_smoothed_per_million  new_people_vaccinated_smoothed  \
# 0                                    NaN                             NaN
# 1                                    NaN                             NaN
# 2                                    NaN                             NaN
# 3                                    NaN                             NaN
# 4                                    NaN                             NaN
# 5                                    NaN                             NaN
# 6                                    NaN                             NaN
# 7                                    NaN                             NaN
# 8                                    NaN                             NaN
# 9                                    NaN                             NaN
#
#    new_people_vaccinated_smoothed_per_hundred  stringency_index  population  \
# 0                                         NaN              8.33  39835428.0
# 1                                         NaN              8.33  39835428.0
# 2                                         NaN              8.33  39835428.0
# 3                                         NaN              8.33  39835428.0
# 4                                         NaN              8.33  39835428.0
# 5                                         NaN              8.33  39835428.0
# 6                                         NaN             27.78  39835428.0
# 7                                         NaN             27.78  39835428.0
# 8                                         NaN             27.78  39835428.0
# 9                                         NaN             27.78  39835428.0
#
#    population_density  median_age  aged_65_older  aged_70_older  \
# 0              54.422        18.6          2.581          1.337
# 1              54.422        18.6          2.581          1.337
# 2              54.422        18.6          2.581          1.337
# 3              54.422        18.6          2.581          1.337
# 4              54.422        18.6          2.581          1.337
# 5              54.422        18.6          2.581          1.337
# 6              54.422        18.6          2.581          1.337
# 7              54.422        18.6          2.581          1.337
# 8              54.422        18.6          2.581          1.337
# 9              54.422        18.6          2.581          1.337
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
# 5        1803.987              NaN                597.029
# 6        1803.987              NaN                597.029
# 7        1803.987              NaN                597.029
# 8        1803.987              NaN                597.029
# 9        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
# 5                 9.59             NaN           NaN                  37.746
# 6                 9.59             NaN           NaN                  37.746
# 7                 9.59             NaN           NaN                  37.746
# 8                 9.59             NaN           NaN                  37.746
# 9                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index  \
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
# 5                         0.5            64.83                    0.511
# 6                         0.5            64.83                    0.511
# 7                         0.5            64.83                    0.511
# 8                         0.5            64.83                    0.511
# 9                         0.5            64.83                    0.511
#
#    excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                   NaN                          NaN
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                                   NaN                          NaN
# 5                                   NaN                          NaN
# 6                                   NaN                          NaN
# 7                                   NaN                          NaN
# 8                                   NaN                          NaN
# 9                                   NaN                          NaN
#
#    excess_mortality  excess_mortality_cumulative_per_million
# 0               NaN                                      NaN
# 1               NaN                                      NaN
# 2               NaN                                      NaN
# 3               NaN                                      NaN
# 4               NaN                                      NaN
# 5               NaN                                      NaN
# 6               NaN                                      NaN
# 7               NaN                                      NaN
# 8               NaN                                      NaN
# 9               NaN                                      NaN

# %%
df.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  1.240430e+05  124038.000000       123055.000000  1.137760e+05
# mean   1.497116e+06    6023.821942         6022.723928  3.558549e+04
# std    7.374487e+06   29341.002245        28779.872563  1.507346e+05
# min    1.000000e+00  -74347.000000        -6223.000000  1.000000e+00
# 25%    2.791000e+03       3.000000           10.857000  8.500000e+01
# 50%    2.991200e+04     104.000000          131.143000  7.810000e+02
# 75%    2.795840e+05    1073.000000         1133.714000  6.915250e+03
# max    1.193515e+08  599598.000000       498046.857000  1.864689e+06
#
#           new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  113972.000000        123055.000000            123371.000000
# mean      124.161838           114.429913             21774.424712
# std       530.373608           494.495600             35434.124835
# min     -1918.000000          -232.143000                 0.001000
# 25%         0.000000             0.143000               491.159000
# 50%         2.000000             2.000000              3607.828000
# 75%        21.000000            18.429000             28512.681000
# max     10965.000000          8306.143000            253504.891000
#
#        new_cases_per_million  new_cases_smoothed_per_million  \
# count          123366.000000                   122388.000000
# mean               93.695085                       93.450607
# std               216.097109                      183.633753
# min             -3125.829000                     -272.971000
# 25%                 0.368000                        1.805000
# 50%                11.928000                       17.202000
# 75%                90.994250                      101.451250
# max              8028.027000                     3544.004000
#
#        total_deaths_per_million  new_deaths_per_million  \
# count             113117.000000           113313.000000
# mean                 437.137651                1.639923
# std                  700.347860                4.212536
# min                    0.000000              -75.911000
# 25%                   13.023000                0.000000
# 50%                   92.512000                0.164000
# 75%                  592.707000                1.440000
# max                 6041.083000              203.513000
#
#        new_deaths_smoothed_per_million  reproduction_rate  icu_patients  \
# count                    122388.000000      104450.000000  16821.000000
# mean                          1.508654           0.994861    689.247250
# std                           3.175088           0.342599   2200.173235
# min                         -10.844000          -0.030000      0.000000
# 25%                           0.004000           0.820000     25.000000
# 50%                           0.224000           1.000000    124.000000
# 75%                           1.458000           1.170000    502.000000
# max                          94.804000           5.920000  28891.000000
#
#        icu_patients_per_million  hosp_patients  hosp_patients_per_million  \
# count              16821.000000   19273.000000               19273.000000
# mean                  22.421594    3427.664245                 160.006042
# std                   24.782063    9530.850094                 214.808018
# min                    0.000000       0.000000                   0.000000
# 25%                    3.965000     109.000000                  23.039000
# 50%                   13.195000     533.000000                  71.482000
# 75%                   33.853000    2382.000000                 206.493000
# max                  192.642000  133268.000000                1544.082000
#
#        weekly_icu_admissions  weekly_icu_admissions_per_million  \
# count            1326.000000                        1326.000000
# mean              243.251885                          17.727974
# std               506.153187                          32.867430
# min                 0.000000                           0.000000
# 25%                 8.000000                           1.813000
# 50%                36.000000                           6.546500
# 75%               205.750000                          18.642250
# max              4002.000000                         279.504000
#
#        weekly_hosp_admissions  weekly_hosp_admissions_per_million  \
# count             2188.000000                         2188.000000
# mean              2571.202011                           88.467100
# std               8645.157715                          142.621039
# min                  0.000000                            0.000000
# 25%                 51.750000                           11.845000
# 50%                315.000000                           38.623000
# 75%               1569.750000                          111.022000
# max             116243.000000                         1365.540000
#
#           new_tests   total_tests  total_tests_per_thousand  \
# count  5.620700e+04  5.623900e+04              56239.000000
# mean   5.528097e+04  1.109020e+07                564.970158
# std    1.836667e+05  4.132599e+07               1370.921297
# min    1.000000e+00  0.000000e+00                  0.000000
# 25%    2.274500e+03  2.906880e+05                 26.519000
# 50%    8.630000e+03  1.480047e+06                135.159000
# 75%    3.286250e+04  6.245240e+06                520.319500
# max    3.740296e+06  6.519501e+08              19398.999000
#
#        new_tests_per_thousand  new_tests_smoothed  \
# count            56207.000000        6.788500e+04
# mean                 2.707255        5.206310e+04
# std                  7.360560        1.646080e+05
# min                  0.000000        0.000000e+00
# 25%                  0.214000        2.359000e+03
# 50%                  0.814000        8.937000e+03
# 75%                  2.484000        3.482900e+04
# max                534.013000        3.080396e+06
#
#        new_tests_smoothed_per_thousand  positive_rate  tests_per_case  \
# count                     67885.000000   63803.000000    63163.000000
# mean                          2.577163       0.086656      153.402587
# std                           6.091611       0.096047      732.940933
# min                           0.000000       0.000000        1.000000
# 25%                           0.237000       0.016600        7.900000
# 50%                           0.881000       0.050700       19.400000
# 75%                           2.552000       0.124800       57.500000
# max                          93.164000       0.970400    50000.000000
#
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        3.455500e+04       3.296700e+04             3.025400e+04
# mean         7.856405e+07       4.149554e+07             2.906388e+07
# std          3.589877e+08       1.919177e+08             1.394351e+08
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          4.035510e+05       2.817810e+05             1.699840e+05
# 50%          2.925667e+06       1.941565e+06             1.338784e+06
# 75%          1.658009e+07       1.000408e+07             7.465896e+06
# max          5.655998e+09       2.986243e+09             2.392503e+09
#
#        total_boosters  new_vaccinations  new_vaccinations_smoothed  \
# count    8.435000e+03      2.862500e+04               6.240700e+04
# mean     3.035973e+06      7.058545e+05               3.361467e+05
# std      1.181592e+07      2.736466e+06               1.831366e+06
# min      1.000000e+00      0.000000e+00               0.000000e+00
# 25%      8.900000e+01      6.059000e+03               1.047000e+03
# 50%      4.180000e+04      3.563900e+04               8.308000e+03
# 75%      9.970095e+05      2.085600e+05               5.689400e+04
# max      1.671545e+08      4.319539e+07               3.333729e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    34555.000000                   32967.000000
# mean                        56.427299                      32.093922
# std                         53.036983                      26.987819
# min                          0.000000                       0.000000
# 25%                          7.980000                       5.950000
# 50%                         40.620000                      26.920000
# 75%                         98.095000                      56.400000
# max                        303.220000                     121.770000
#
#        people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# count                         30254.000000                 8435.000000
# mean                             25.859018                    3.514605
# std                              24.988119                    7.452678
# min                               0.000000                    0.000000
# 25%                               3.180000                    0.000000
# 50%                              17.510000                    0.090000
# 75%                              46.017500                    3.440000
# max                             118.340000                   63.110000
#
#        new_vaccinations_smoothed_per_million  new_people_vaccinated_smoothed  \
# count                           62407.000000                    6.126200e+04
# mean                             3404.039290                    1.717932e+05
# std                              4086.169027                    1.497751e+06
# min                                 0.000000                    0.000000e+00
# 25%                               641.000000                    5.320000e+02
# 50%                              2236.000000                    4.349000e+03
# 75%                              4923.000000                    2.877650e+04
# max                            117497.000000                    9.519860e+07
#
#        new_people_vaccinated_smoothed_per_hundred  stringency_index  \
# count                                61262.000000     108134.000000
# mean                                     0.174398         55.910908
# std                                      0.274257         20.585439
# min                                      0.000000          0.000000
# 25%                                      0.030000         41.670000
# 50%                                      0.094000         56.480000
# 75%                                      0.233000         71.760000
# max                                     11.750000        100.000000
#
#          population  population_density     median_age  aged_65_older  \
# count  1.305360e+05       119923.000000  113929.000000  112607.000000
# mean   1.091111e+08          418.684279      30.661534       8.850425
# std    4.605276e+08         1923.441921       9.199242       6.247260
# min    4.700000e+01            0.137000      15.100000       1.144000
# 25%    2.015490e+06           37.728000      22.200000       3.507000
# 50%    9.291000e+06           88.125000      29.900000       6.378000
# 75%    3.534068e+07          212.865000      39.200000      14.312000
# max    4.678445e+09        20546.766000      48.200000      27.049000
#
#        aged_70_older  gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# count  113276.000000   114699.000000     75962.000000          114109.000000
# mean        5.594444    19653.324899        13.348149             256.597808
# std         4.260380    20326.025958        20.092565             114.864903
# min         0.526000      661.240000         0.100000              79.370000
# 25%         2.063000     4466.507000         0.500000             167.295000
# 50%         3.871000    13111.214000         2.200000             243.811000
# 75%         9.167000    27936.896000        21.200000             329.942000
# max        18.493000   116935.600000        77.600000             597.029000
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# count        118148.000000    88223.000000  86875.000000
# mean              8.126951       10.884437     32.905585
# std               4.377814       10.658114     13.774011
# min               0.990000        0.100000      7.700000
# 25%               5.310000        1.900000     21.400000
# 50%               7.170000        6.300000     33.100000
# 75%              10.390000       19.600000     41.500000
# max              30.530000       44.000000     78.100000
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count            56732.000000               103533.000000    122439.000000
# mean                51.061845                    3.071080        73.360498
# std                 32.240056                    2.499901         7.615759
# min                  1.188000                    0.100000        53.280000
# 25%                 19.351000                    1.300000        67.940000
# 50%                 50.540000                    2.400000        74.790000
# 75%                 83.241000                    4.210000        78.880000
# max                100.000000                   13.800000        86.750000
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# count            114233.000000                           4824.000000
# mean                  0.728641                          29547.425166
# std                   0.151181                          77777.784285
# min                   0.394000                         -31959.400000
# 25%                   0.606000                           -138.700000
# 50%                   0.756000                           2644.250000
# 75%                   0.851000                          20705.575000
# max                   0.957000                         984309.300000
#
#        excess_mortality_cumulative  excess_mortality  \
# count                  4824.000000       4824.000000
# mean                      9.269749         16.471095
# std                      17.484440         31.897284
# min                     -27.350000        -95.920000
# 25%                      -0.862500         -0.535000
# 50%                       5.435000          6.980000
# 75%                      13.910000         22.800000
# max                     121.160000        373.940000
#
#        excess_mortality_cumulative_per_million
# count                              4824.000000
# mean                                840.545086
# std                                1255.706740
# min                               -1728.844404
# 25%                                 -38.744593
# 50%                                 380.758506
# 75%                                1397.451388
# max                                7270.553623

# %% [markdown]
# Como se trata de un periodo temporal pequeño y por tanto el número de filas no es muy grande, parece adecuado trabajar con todos los datos que tenemos. Sin embargo, tenemos 67 columnas y con seguridad, no las necesitaremos todas.
#
# A continuación, mediante un diccionario seleccionaremos las columnas con las que nos vamos a quedar y lo usaremos también para renombrarlas.
#
# Esta selección se basa en las preguntas que queremos responder del dataset.
#
# Algunas preguntas que pueden plantearse a estos datos son:
#  - Cómo varía el número de infectados, hospitalizados (en UCI), muertos y vacunados a lo largo del tiempo
#  - ¿Existe relación entre el desarrollo de un país y su índice de vacunación?
#  - ¿Existe relación entre el desarrollo de un país y su índice de mortalidad?

# %%
cols_covid = {
    
    'date': 'DIA_ID',
    'continent': 'CONTINENTE',
    'location': 'PAIS_DESC',
    'icu_patients': 'PACIENTES_UCI',
    'population': 'POBLACION',
    'total_cases': 'CASOS_TOTALES',
    'new_cases_smoothed': 'CASOS_NUEVOS',
    'new_deaths_smoothed': 'MUERTES_NUEVAS',
    'new_vaccinations_smoothed': 'VACUNAS_NUEVAS',
    'people_vaccinated': 'PERSONAS_VACUNADAS',
    'total_vaccinations': 'VACUNAS_TOTALES', 
    'total_deaths': 'MUERTES_TOTALES',
    'human_development_index': 'HDI',
    'gdp_per_capita': 'PIB',
    'median_age': 'EDAD_MEDIA'
    
}

# %%
# Seleccionamos columnas
df = df[cols_covid.keys()]

# Renombramos
df = df.rename(columns = cols_covid)
df
# Out:
#             DIA_ID     CONTINENTE      PAIS_DESC  PACIENTES_UCI    POBLACION  \
# 0       2020-02-24           Asia    Afghanistan            NaN   39835428.0
# 1       2020-02-25           Asia    Afghanistan            NaN   39835428.0
# 2       2020-02-26           Asia    Afghanistan            NaN   39835428.0
# 3       2020-02-27           Asia    Afghanistan            NaN   39835428.0
# 4       2020-02-28           Asia    Afghanistan            NaN   39835428.0
# ...            ...            ...            ...            ...          ...
# 131521  2021-02-27  North America  United States        11716.0  332915074.0
# 131522  2021-02-28  North America  United States        11552.0  332915074.0
# 131523  2021-03-01  North America  United States        11362.0  332915074.0
# 131524  2021-03-02  North America  United States        11040.0  332915074.0
# 131525         NaN      North Ame            NaN            NaN          NaN
#
#         CASOS_TOTALES  CASOS_NUEVOS  MUERTES_NUEVAS  VACUNAS_NUEVAS  \
# 0                 5.0           NaN             NaN             NaN
# 1                 5.0           NaN             NaN             NaN
# 2                 5.0           NaN             NaN             NaN
# 3                 5.0           NaN             NaN             NaN
# 4                 5.0           NaN             NaN             NaN
# ...               ...           ...             ...             ...
# 131521     28666896.0     68945.429        2010.571       2084656.0
# 131522     28718763.0     68084.143        1993.429       2121784.0
# 131523     28773252.0     68034.143        2010.286       2201824.0
# 131524     28830318.0     65898.429        1961.286       2275508.0
# 131525            NaN           NaN             NaN             NaN
#
#         PERSONAS_VACUNADAS  VACUNAS_TOTALES  MUERTES_TOTALES    HDI  \
# 0                      NaN              NaN              NaN  0.511
# 1                      NaN              NaN              NaN  0.511
# 2                      NaN              NaN              NaN  0.511
# 3                      NaN              NaN              NaN  0.511
# 4                      NaN              NaN              NaN  0.511
# ...                    ...              ...              ...    ...
# 131521          55827451.0       86880741.0         513086.0  0.926
# 131522          56370633.0       87736052.0         514193.0  0.926
# 131523          57565701.0       89759847.0         515512.0  0.926
# 131524          59038969.0       92217906.0         517445.0  0.926
# 131525                 NaN              NaN              NaN    NaN
#
#               PIB  EDAD_MEDIA
# 0        1803.987        18.6
# 1        1803.987        18.6
# 2        1803.987        18.6
# 3        1803.987        18.6
# 4        1803.987        18.6
# ...           ...         ...
# 131521  54225.446        38.3
# 131522  54225.446        38.3
# 131523  54225.446        38.3
# 131524  54225.446        38.3
# 131525        NaN         NaN
#
# [131526 rows x 15 columns]

# %% [markdown]
# Por otra parte, también comprobamos los tipos de datos con los que contamos:

# %%
df.dtypes
# Out:
# DIA_ID                 object
# CONTINENTE             object
# PAIS_DESC              object
# PACIENTES_UCI         float64
# POBLACION             float64
# CASOS_TOTALES         float64
# CASOS_NUEVOS          float64
# MUERTES_NUEVAS        float64
# VACUNAS_NUEVAS        float64
# PERSONAS_VACUNADAS    float64
# VACUNAS_TOTALES       float64
# MUERTES_TOTALES       float64
# HDI                   float64
# PIB                   float64
# EDAD_MEDIA            float64
# dtype: object

# %% [markdown]
# Vemos que la fecha no se encuentra en formato ```datetime```, en general eso nos puede afectar más adelante si queremos mostrar los datos ordenados, la corregimos:

# %%
df['DIA_ID'] = pd.to_datetime(df['DIA_ID'], format = '%Y/%m/%d')

# %% [markdown]
# Por otra parte, como comentábamos antes, también es una buena práctica obtener alguna visualización simple de los datos con los que contamos. Por ejemplo, para España podemos ver cómo se comportan los casos nuevos, muertes y vacunas para cada día:

# %%
spain = df.loc[df['PAIS_DESC'] == 'Spain'].copy()
spain.index = spain.DIA_ID

spain[
        ['CASOS_NUEVOS', 'VACUNAS_NUEVAS', 'MUERTES_NUEVAS', 'PACIENTES_UCI']
     ].plot(subplots = True, figsize = (15, 10), )
# Out:
# array([<AxesSubplot:xlabel='DIA_ID'>, <AxesSubplot:xlabel='DIA_ID'>,
#        <AxesSubplot:xlabel='DIA_ID'>, <AxesSubplot:xlabel='DIA_ID'>],
#       dtype=object)

# %% [markdown]
# Algunos factores a tener en cuenta al ver el gráfico:
#  - La vacunación comienza en enero de 2021
#  - Las oleadas COVID son:
#    - 1º: Marzo 2020
#    - 2ª: Junio - Diciembre 2020
#    - 3ª: Enero 2021
#    - 4ª: Abril 2021
#    - 5ª: Julio 2021
#    - 6ª: Diciembre 2021

# %% [markdown]
# Por otra parte, al ver el número de nuevas vacunas se ve una reducción muy drástica en el número de vacunas administradas cuando se termina la segunda dosis de vacunación, podemos ver la población total vacunada con la variable PERSONAS_VACUNADAS:

# %%
spain = df.loc[df['PAIS_DESC'] == 'Spain']
spain.index = spain.DIA_ID

spain[
        ['PERSONAS_VACUNADAS', 'VACUNAS_NUEVAS']
     ].plot(subplots = True, figsize = (15, 10), )
# Out:
# array([<AxesSubplot:xlabel='DIA_ID'>, <AxesSubplot:xlabel='DIA_ID'>],
#       dtype=object)

# %% [markdown]
# En varias de estas gráficas (UCI, personas totales vacunadas), vemos que existen valores faltantes (la línea es discontinua y no 0 como pasa en la gráfica de casos nuevos).
#
# En general, entre las columnas que tienen valores nulos distinguiremos dos casos diferentes:
#
# 1. Columnas que acumulan
# 2. Columnas que tienen valores a nivel día
#
# En el primer caso lo mejor es interpolar los valores para establecer el valor faltante entre los que tengamos.
#
# En el segundo caso lo mejor es rellenar con ceros
#
# Vamos a fijarnos en una columna específica para hacer la interpolación (el relleno con ceros puede hacerse después de todas las interpolaciones con ```df.fillna(0))```
#
# El campo ```PACIENTES_UCI``` en España es especialmente interesante ya que no existe para todos los días de la semana pero sabemos que, para pasar de x a y tiene que pasar por hospitalizados intermedios.

# %%
spain['PACIENTES_UCI'].plot(figsize = (18, 4))
# Out:
# <AxesSubplot:xlabel='DIA_ID'>

# %% [markdown]
# Si únicamente hacemos una interpolación los primeros valores no se cubren:

# %%
spain['PACIENTES_UCI'].interpolate().plot(figsize = (18,4))
# Out:
# <AxesSubplot:xlabel='DIA_ID'>

# %%
spain['PACIENTES_UCI'].interpolate().head(30)
# Out:
# DIA_ID
# 2020-01-18   NaN
# 2020-02-01   NaN
# 2020-02-02   NaN
# 2020-02-03   NaN
# 2020-02-04   NaN
# 2020-02-05   NaN
# 2020-02-06   NaN
# 2020-02-07   NaN
# 2020-02-08   NaN
# 2020-02-09   NaN
# 2020-02-10   NaN
# 2020-02-11   NaN
# 2020-02-12   NaN
# 2020-02-13   NaN
# 2020-02-14   NaN
# 2020-02-15   NaN
# 2020-02-16   NaN
# 2020-02-17   NaN
# 2020-02-18   NaN
# 2020-02-19   NaN
# 2020-02-20   NaN
# 2020-02-21   NaN
# 2020-02-22   NaN
# 2020-02-23   NaN
# 2020-02-24   NaN
# 2020-02-25   NaN
# 2020-02-26   NaN
# 2020-02-27   NaN
# 2020-02-28   NaN
# 2020-02-29   NaN
# Name: PACIENTES_UCI, dtype: float64

# %% [markdown]
# Para que nos interpole tenemos que establecer un valor inicial a 0.
#
# Obtener la primera fila para cada país es sencillo:

# %%
df = df.sort_values(by = ['PAIS_DESC', 'DIA_ID'], ascending = True)
df.groupby(by = ['PAIS_DESC'])[['PAIS_DESC', 'PACIENTES_UCI']].nth(0)
# Out:
#                                  PAIS_DESC  PACIENTES_UCI
# PAIS_DESC
# Afghanistan                    Afghanistan            NaN
# Africa                              Africa            NaN
# Albania                            Albania            NaN
# Algeria                            Algeria            NaN
# Andorra                            Andorra            NaN
# ...                                    ...            ...
# Uganda                              Uganda            NaN
# Ukraine                            Ukraine            NaN
# United Arab Emirates  United Arab Emirates            NaN
# United Kingdom              United Kingdom            NaN
# United States                United States            NaN
#
# [225 rows x 2 columns]

# %% [markdown]
# Pero establecer el primer valor de cada uno a 0 es más complejo:

# %%
df['FILA_GRUPO'] = df.groupby('PAIS_DESC').cumcount()

# Ahora podemos utilizar la columna creada para establecer a 0 la primera entrada de cada país:
df.loc[df['FILA_GRUPO'] == 0, 'PACIENTES_UCI'] = 0

df.groupby(by = ['PAIS_DESC'])[['PAIS_DESC', 'PACIENTES_UCI']].nth(0)
# Out:
#                                  PAIS_DESC  PACIENTES_UCI
# PAIS_DESC
# Afghanistan                    Afghanistan            0.0
# Africa                              Africa            0.0
# Albania                            Albania            0.0
# Algeria                            Algeria            0.0
# Andorra                            Andorra            0.0
# ...                                    ...            ...
# Uganda                              Uganda            0.0
# Ukraine                            Ukraine            0.0
# United Arab Emirates  United Arab Emirates            0.0
# United Kingdom              United Kingdom            0.0
# United States                United States            0.0
#
# [225 rows x 2 columns]

# %% [markdown]
# Ahora podemos interpolar todos los países:

# %%
for x in df['PAIS_DESC'].unique():
    df.loc[df['PAIS_DESC'] == x, 'PACIENTES_UCI'] = df.loc[df['PAIS_DESC'] == x]['PACIENTES_UCI'].interpolate(method = 'linear')

# Tenemos que segmentar por país, si intentamos interpolar todos los países a la vez no es capaz de separarlos correctamente

# %%
df[df['PAIS_DESC'] == 'Spain']['PACIENTES_UCI'].interpolate(method = 'linear').plot(figsize=(16,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Práctica
#
# Una vez manejemos con cierta soltura el dataset, podemos empezar a obtener respuestas a las preguntas que nos hayamos planteado. Aquí se proponen las siguientes:
#
# 1. La tasa de contagio de una enfermedad infecciosa es exponencial, ¿puedes dibujar el número de contagios para España y aquellos países con una población similar (+-20% de la población de España)?
#
#
# 2. Si la tasa de contagio es exponencial, la gráfica que dibuje el logaritmo del número de contagios será lineal, ¿se cumple para los países anteriores?
#
#
# 3. Dibujando la tasa de vacunación para los mismos países ¿es lineal/exponencial?
#
#
# 4. Calcula, para España y cada día en que tengamos datos de vacunación, el tiempo necesario para vacunar a toda la población teniendo en cuenta el ritmo de vacunación acumulado.
#
#
# 5. ¿El ratio de fallecidos varía en función del HDI (Human Development Index)?
#
#
# 6. ¿Coinciden los picos de las olas de nuevos casos para todos los países? Compruébalo, por ejemplo, para los 10 países más poblados de Europa. En caso de que no coincidan, ¿cómo podrías intentar solventar esto? ¿Quizás ajustando todas las curvas al día en el que se detectó el primer caso?
#
#     Si lo anterior no ha funcionado... ¿sería mejor ajustar al primer día en el que se alcanzaron los 150 primeros casos?
#
#
# 7. ¿Existe alguna relación entre la riqueza del país, la edad media de la población y el máximo número de muertes que se han alcanzado en ese país? ¿Cómo podrías representarlo?

# %% [markdown]
# ### Número de contagios para diferentes países

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %% [markdown]
# Lo primero que hacemos es seleccionar aquellos países con una población similar a España:

# %%
population_spain = df.loc[df['PAIS_DESC'] == 'Spain'][['POBLACION']].dropna().iloc[0][0]
x = df.loc[df['POBLACION'].between(population_spain - 0.2*population_spain, population_spain + 0.2*population_spain)]
paises = x['PAIS_DESC'].unique()
paises
# Out:
# array(['Afghanistan', 'Algeria', 'Argentina', 'Canada', 'Colombia',
#        'Iraq', 'Kenya', 'Myanmar', 'Oceania', 'Poland', 'South Korea',
#        'Spain', 'Sudan', 'Uganda', 'Ukraine'], dtype=object)

# %% [markdown]
# Y simplemente obtenemos el gráfico de casos totales para cada día y para cada país, de aquellos que se encuentren en la lista:

# %%
fig, ax = plt.subplots(figsize = (15, 10))
sns.lineplot(data = df.loc[df['PAIS_DESC'].isin(paises)],
             x = "DIA_ID", 
             y = "CASOS_TOTALES", 
             hue = "PAIS_DESC", 
             ax = ax)
# Out:
# <AxesSubplot:xlabel='DIA_ID', ylabel='CASOS_TOTALES'>

# %% [markdown]
# ### Número de contagios en escala logarítimica

# %% [markdown]
# Para contestar a esta pregunta, podemos utilizar dos estrategias:
#
# 1. Calcular el logaritmo de la columna ```CASOS_TOTALES``` y plotear dicha columna.
#
# 2. Utilizar una escala logarítmica en el eje que contenga los datos de ```CASOS_TOTALES```.

# %%
# Método 1

df['LOG_CASOS_TOTALES'] = np.log(df['CASOS_TOTALES'])

fig, ax = plt.subplots(figsize = (15, 10))
g = sns.lineplot(data = df.loc[df['PAIS_DESC'].isin(paises)],
             x = "DIA_ID", 
             y = "LOG_CASOS_TOTALES", 
             hue = "PAIS_DESC", 
             ax = ax)

# %%
# Método 2

fig, ax = plt.subplots(figsize = (15, 10))
g = sns.lineplot(data = df.loc[df['PAIS_DESC'].isin(paises)],
             x = "DIA_ID", 
             y = "CASOS_TOTALES", 
             hue = "PAIS_DESC", 
             ax = ax)

g.set(yscale = 'log')
# Out:
# [None]

# %% [markdown]
# ### Tasa de vacunación

# %% [markdown]
# Para la tasa de vacunación, como ya hicimos antes, primero relleneramos los datos de días faltantes. Sin embargo, en este caso, no estableceremos nosotros un valor a 0.

# %%
for x in df['PAIS_DESC'].unique():
    df.loc[df['PAIS_DESC'] == x, 'PACIENTVACUNAS_TOTALESES_UCI'] = df.loc[df['PAIS_DESC'] == x]['VACUNAS_TOTALES'].interpolate(method = 'linear')

# %%
fig, ax = plt.subplots(figsize = (15, 10))
sns.lineplot(data = df.loc[df['PAIS_DESC'].isin(paises)],
             x = "DIA_ID", 
             y = "VACUNAS_TOTALES", 
             hue = "PAIS_DESC", 
             ax = ax)

g.set(yscale = 'log')
# Out:
# [None]

# %% [markdown]
# ### España, tasa de vacunación

# %% [markdown]
# En primer lugar, filtraremos los datos para quedarnos con España, y con las tres columnas que nos interesan en este caso:

# %%
sp = df.loc[df['PAIS_DESC'] == 'Spain']

tasa_vac_sp = sp.loc[sp['VACUNAS_TOTALES'] > 0, ['DIA_ID', 'VACUNAS_TOTALES', 'POBLACION']]

# %%
tasa_vac_sp
# Out:
#            DIA_ID  VACUNAS_TOTALES   POBLACION
# 117399 2021-01-04          82834.0  46745211.0
# 117400 2021-01-05         139339.0  46745211.0
# 117402 2021-01-07         207323.0  46745211.0
# 117403 2021-01-08         277976.0  46745211.0
# 117406 2021-01-11         406091.0  46745211.0
# ...           ...              ...         ...
# 117729 2021-11-30       76680144.0  46745211.0
# 117730 2021-12-01       76899564.0  46745211.0
# 117731 2021-12-02       77157350.0  46745211.0
# 117735 2021-12-06       77541843.0  46745211.0
# 117737 2021-12-08       77653701.0  46745211.0
#
# [238 rows x 3 columns]

# %% [markdown]
# Después, calculamos la diferencia (en días) entre cada día, y el día en el que empezó la vacunación:

# %%
tasa_vac_sp['DIAS_DESDE'] = (tasa_vac_sp['DIA_ID'] - tasa_vac_sp.loc[tasa_vac_sp['VACUNAS_TOTALES'] > 0]['DIA_ID'].min()).apply(lambda x: x.days +1)

# %% [markdown]
# Después, calcularemos el ritmo de vacunación como las vacunas totales administradas hasta ese día, entre el número de días transcurridos desde que empezó la vacunación:

# %%
tasa_vac_sp['PERSONAS_DIA'] = tasa_vac_sp['VACUNAS_TOTALES'] / tasa_vac_sp['DIAS_DESDE']

# %% [markdown]
# Y finalmente, calculamos el número de días necesarios para vacunar al resto de la población, como ésta entre el ritmo de vacunación:

# %%
tasa_vac_sp['DIAS_NECESARIOS'] = tasa_vac_sp['POBLACION'] / (tasa_vac_sp['PERSONAS_DIA'])

# %%
fig, ax = plt.subplots(figsize = (15, 10))
sns.lineplot(x = 'DIA_ID', y = 'DIAS_NECESARIOS', data = tasa_vac_sp, ax = ax)
# Out:
# <AxesSubplot:xlabel='DIA_ID', ylabel='DIAS_NECESARIOS'>

# %% [markdown]
# ### HDI y muertes

# %% [markdown]
# Para ver si el número de fallecidos se relaciona de alguna manera con el HDI (Human Development Index), buscaremos obtener por país el número de muertes totales y el HDI de dicho país:

# %%
fallecidos = df.groupby('PAIS_DESC')[['MUERTES_TOTALES', 'HDI']].max().dropna()
fallecidos
# Out:
#                       MUERTES_TOTALES    HDI
# PAIS_DESC
# Afghanistan                    7321.0  0.511
# Albania                        3128.0  0.795
# Algeria                        6126.0  0.748
# Andorra                         133.0  0.868
# Angola                         1736.0  0.581
# ...                               ...    ...
# Uganda                         3263.0  0.544
# Ukraine                       95478.0  0.779
# United Arab Emirates           2149.0  0.890
# United Kingdom               146592.0  0.932
# United States                517445.0  0.926
#
# [173 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize = (15, 10))
sns.scatterplot(x = 'HDI', y = 'MUERTES_TOTALES', data = fallecidos, ax = ax)
# Out:
# <AxesSubplot:xlabel='HDI', ylabel='MUERTES_TOTALES'>

# %% [markdown]
# Sin embargo, dado que no todos los países cuenta con la misma población, parece adecuado normalizar el número de muertes totales a la población de cada país:

# %%
df['MUERTES_POB'] = df['MUERTES_TOTALES'] / df['POBLACION']
fallecidos = df.groupby('PAIS_DESC')[['MUERTES_POB', 'HDI']].max().dropna()
fallecidos
# Out:
#                       MUERTES_POB    HDI
# PAIS_DESC
# Afghanistan              0.000184  0.511
# Albania                  0.001089  0.795
# Algeria                  0.000137  0.748
# Andorra                  0.001719  0.868
# Angola                   0.000051  0.581
# ...                           ...    ...
# Uganda                   0.000069  0.544
# Ukraine                  0.002197  0.779
# United Arab Emirates     0.000215  0.890
# United Kingdom           0.002149  0.932
# United States            0.001554  0.926
#
# [173 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize = (15, 10))
sns.scatterplot(x = 'HDI', y = 'MUERTES_POB', data = fallecidos, ax = ax)
# Out:
# <AxesSubplot:xlabel='HDI', ylabel='MUERTES_POB'>

# %% [markdown]
#  Cuanto menos desarrollado es un país... menor tasa de mortalidad?:
#  - ¿Menor densidad de población?
#  - ¿Menor facilidad de transporte?
#  - ¿Menor turismo?
#  - ¿Menor capacidad para contabilizar las víctimas de covid?

# %% [markdown]
# ### Picos de las olas en Europa

# %% [markdown]
# Por último, puede ser interesante ver cómo fue la primera ola de casos detectados en función de cada país. Por centrar nuestra atención en unos pocos, nos centraremos en los 10 países más poblados de Europa.
#
# Para obtener cuales son estos países, simplemente filtramos por la columna ```CONTINENTE``` y nos quedamos con cada país y su población:

# %%
pais_pob = df.loc[df['CONTINENTE'] == 'Europe'][['PAIS_DESC', 'POBLACION']].drop_duplicates()
pais_pob
# Out:
#                      PAIS_DESC    POBLACION
# 1321                   Albania    2872934.0
# 2629                   Andorra      77354.0
# 7838                   Austria    9043072.0
# 11710                  Belarus    9442867.0
# 12361                  Belgium   11632334.0
# 16026   Bosnia and Herzegovina    3263459.0
# 18782                 Bulgaria    6896655.0
# 29596                  Croatia    4081657.0
# 31144                   Cyprus     896005.0
# 31786                  Czechia   10724553.0
# 33081                  Denmark    5813302.0
# 38876                  Estonia    1325188.0
# 42199           Faeroe Islands      49053.0
# 43227                  Finland    5548361.0
# 43908                   France   67564251.0
# 46824                  Germany   83900471.0
# 48143                Gibraltar      33691.0
# 48476                   Greece   10370747.0
# 50742                 Guernsey      63385.0
# 55605                  Hungary    9634162.0
# 56252                  Iceland     343360.0
# 60220                  Ireland    4982904.0
# 60870              Isle of Man      85410.0
# 61852                    Italy   60367471.0
# 63858                   Jersey     101073.0
# 66259                   Kosovo    1782115.0
# 68808                   Latvia    1866934.0
# 71978            Liechtenstein      38254.0
# 72624                Lithuania    2689862.0
# 74618               Luxembourg     634814.0
# 78782                    Malta     516100.0
# 82135                  Moldova    4024025.0
# 82777                   Monaco      39520.0
# 84067               Montenegro     628051.0
# 88368              Netherlands   17173094.0
# 92622          North Macedonia    2082661.0
# 93592                   Norway    5465629.0
# 100382                  Poland   37797000.0
# 101028                Portugal   10167923.0
# 102338                 Romania   19127772.0
# 102991                  Russia  145912022.0
# 106682              San Marino      34010.0
# 109244                  Serbia    6871547.0
# 112049                Slovakia    5460726.0
# 112693                Slovenia    2078723.0
# 117060                   Spain   46745211.0
# 119696                  Sweden   10160159.0
# 120374             Switzerland    8715494.0
# 129112                 Ukraine   43466822.0
# 130440          United Kingdom   68207114.0

# %% [markdown]
# Después, ordenamos los países de forma descendiente en función de su población y nos quedamos con los 10 primeros:

# %%
paises_eu = pais_pob.sort_values(by = 'POBLACION', ascending = False)[0:10]['PAIS_DESC'].to_list()
paises_eu
# Out:
# ['Russia',
#  'Germany',
#  'United Kingdom',
#  'France',
#  'Italy',
#  'Spain',
#  'Ukraine',
#  'Poland',
#  'Romania',
#  'Netherlands']

# %%
fig, ax = plt.subplots(figsize = (15, 10))
sns.lineplot(data = df.loc[(df['PAIS_DESC'].isin(paises_eu)) & (df['DIA_ID'] <= datetime.datetime(2020, 6, 1))],
             x = "DIA_ID", 
             y = "CASOS_NUEVOS", 
             hue = "PAIS_DESC", 
             ax = ax)
# Out:
# <AxesSubplot:xlabel='DIA_ID', ylabel='CASOS_NUEVOS'>

# %% [markdown]
# De esta manera, es un poco complicado comparar cómo fueron las curvas de crecimiento en cada uno de los países considerados.
#
# Lo que podemos hacer es utilizar en el eje x el número de días transcurridos desde que se deteectó el primer positivo. Primero, calculamos este día:

# %%
inicio_covid = df.loc[df['CASOS_NUEVOS'].notna()][['PAIS_DESC', 'DIA_ID']].groupby(['PAIS_DESC']).min().reset_index()
inicio_covid.columns = ['PAIS_DESC', 'MIN_DATE']

df = df.merge(inicio_covid, on = 'PAIS_DESC', how = 'left')

# %%
df.head()
# Out:
#       DIA_ID CONTINENTE    PAIS_DESC  PACIENTES_UCI   POBLACION  \
# 0 2020-02-24       Asia  Afghanistan            0.0  39835428.0
# 1 2020-02-25       Asia  Afghanistan            0.0  39835428.0
# 2 2020-02-26       Asia  Afghanistan            0.0  39835428.0
# 3 2020-02-27       Asia  Afghanistan            0.0  39835428.0
# 4 2020-02-28       Asia  Afghanistan            0.0  39835428.0
#
#    CASOS_TOTALES  CASOS_NUEVOS  MUERTES_NUEVAS  VACUNAS_NUEVAS  \
# 0            5.0           NaN             NaN             NaN
# 1            5.0           NaN             NaN             NaN
# 2            5.0           NaN             NaN             NaN
# 3            5.0           NaN             NaN             NaN
# 4            5.0           NaN             NaN             NaN
#
#    PERSONAS_VACUNADAS  VACUNAS_TOTALES  MUERTES_TOTALES    HDI       PIB  \
# 0                 NaN              NaN              NaN  0.511  1803.987
# 1                 NaN              NaN              NaN  0.511  1803.987
# 2                 NaN              NaN              NaN  0.511  1803.987
# 3                 NaN              NaN              NaN  0.511  1803.987
# 4                 NaN              NaN              NaN  0.511  1803.987
#
#    EDAD_MEDIA  FILA_GRUPO  LOG_CASOS_TOTALES  PACIENTVACUNAS_TOTALESES_UCI  \
# 0        18.6           0           1.609438                           NaN
# 1        18.6           1           1.609438                           NaN
# 2        18.6           2           1.609438                           NaN
# 3        18.6           3           1.609438                           NaN
# 4        18.6           4           1.609438                           NaN
#
#    MUERTES_POB   MIN_DATE
# 0          NaN 2020-02-29
# 1          NaN 2020-02-29
# 2          NaN 2020-02-29
# 3          NaN 2020-02-29
# 4          NaN 2020-02-29

# %% [markdown]
# Calculamos la diferencia en días para cada día:

# %%
df['DIAS_DESDE_INICIO'] = (df['DIA_ID'] - df['MIN_DATE']).dt.days

# %%
fig, ax = plt.subplots(figsize = (15, 10))
sns.lineplot(data = df.loc[(df['PAIS_DESC'].isin(paises_eu)) & (df['DIA_ID'] <= datetime.datetime(2020, 6, 1))],
             x = "DIAS_DESDE_INICIO", 
             y = "CASOS_NUEVOS", 
             hue = "PAIS_DESC", 
             ax = ax)
# Out:
# <AxesSubplot:xlabel='DIAS_DESDE_INICIO', ylabel='CASOS_NUEVOS'>

# %% [markdown]
# Con este cambio no se aprecia una diferencia significativa. Otra idea podría ser establecer como día uno el primer día en el qe se alcanzó un cierto número de casos:

# %%
covid_100_casos = df.loc[(df['CASOS_NUEVOS'] >= 150)][['PAIS_DESC', 'DIA_ID']].groupby(['PAIS_DESC']).min().reset_index()

covid_100_casos.columns = ['PAIS_DESC', 'MIN_DATE_100_CASOS']

df = df.merge(covid_100_casos, on = 'PAIS_DESC', how = 'left')

# %%
df['DIAS_DESDE_100_CASOS'] = (df['DIA_ID'] - df['MIN_DATE_100_CASOS']).dt.days

# %%
fig, ax = plt.subplots(figsize = (15, 10))
data = df.loc[(df['PAIS_DESC'].isin(paises_eu)) & 
              (df['DIA_ID'] >= df['MIN_DATE_100_CASOS']) & 
              (df['DIA_ID'] <= datetime.datetime(2020, 6, 1))]
sns.lineplot(data = data,
             x = "DIAS_DESDE_100_CASOS", 
             y = "CASOS_NUEVOS", 
             hue = "PAIS_DESC", 
             ax = ax)
# Out:
# <AxesSubplot:xlabel='DIAS_DESDE_100_CASOS', ylabel='CASOS_NUEVOS'>

# %% [markdown]
# ### Relación entre la riqueza del país y la media de edad de los nuevos casos

# %% [markdown]
# Por otro lado, podríamos ver si existe una relación entre la riqueza del país, y la media de edad de los casos detectados:

# %%
muertos_max = df[['PAIS_DESC', 'EDAD_MEDIA', 'PIB', 'CASOS_TOTALES']].groupby(['PAIS_DESC']).max().dropna()

# %%
muertos_max.reset_index(inplace = True)

# %%
muertos_max
# Out:
#                 PAIS_DESC  EDAD_MEDIA        PIB  CASOS_TOTALES
# 0             Afghanistan        18.6   1803.987       157585.0
# 1                 Albania        38.0  11803.431       202863.0
# 2                 Algeria        29.1  13913.839       212224.0
# 3                  Angola        16.8   5819.495        65346.0
# 4     Antigua and Barbuda        32.1  21490.943         4151.0
# ..                    ...         ...        ...            ...
# 167                Uganda        16.4   1697.707       127863.0
# 168               Ukraine        41.4   7894.393      3705823.0
# 169  United Arab Emirates        34.0  67293.483       742567.0
# 170        United Kingdom        40.8  39753.244     10722083.0
# 171         United States        38.3  54225.446     28830318.0
#
# [172 rows x 4 columns]

# %%
muertos_max["CASOS_TOTALES"]/1000
# Out:
# 0        157.585
# 1        202.863
# 2        212.224
# 3         65.346
# 4          4.151
#          ...
# 167      127.863
# 168     3705.823
# 169      742.567
# 170    10722.083
# 171    28830.318
# Name: CASOS_TOTALES, Length: 172, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (15, 10))

g = sns.scatterplot(data = muertos_max,             
            x = "PIB", 
            y = "EDAD_MEDIA", 
            s = muertos_max["CASOS_TOTALES"]/10000,
            ax = ax)

g.set_xscale('log')
